# %% [markdown]
# # Slot Filling

# %%
#Mount Google drive
#from google.colab import drive
#drive.mount('/content/drive')

#change current working directory
#%cd "/content/drive/Shareddrives/NLI"

# %%
#!pip install transformers
#!pip install seqeval
#!pip install datasets
#!python3 -m spacy download en_core_web_lg

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertForSequenceClassification, BertTokenizer, BertConfig
from transformers import RobertaForSequenceClassification, RobertaTokenizer, RobertaConfig
from transformers import XLNetForSequenceClassification, XLNetTokenizer, XLNetConfig
from transformers import XLMForSequenceClassification, XLMTokenizer, XLMConfig
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer, DistilBertConfig
from transformers import AlbertForSequenceClassification, AlbertTokenizer, AlbertConfig
from seqeval.metrics import classification_report
from datasets import load_dataset
from datasets import DatasetDict

import nltk
import matplotlib.pyplot as plt

from tqdm import tqdm
from torch import cuda
import re

nltk.download('punkt')

import spacy

nlp = spacy.load("en_core_web_lg")
# Out:
# /home/mister/miniconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [nltk_data] Downloading package punkt to /home/mister/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
DATASET_DIRECTORY = "./../dataset.hf/"
TRAIN_DATA_SAVE_PATH = "utterances_tags/train.json"
TEST_DATA_SAVE_PATH = "utterances_tags/test.json"
VALID_DATA_SAVE_PATH = "utterances_tags/valid.json"

ALWAYS_LOAD_DATASET = False
SAVE_DATASET = True

# %%
import json

def save_variable_to_json(variable, file_path):
    with open(file_path, 'w') as file:
        json.dump(variable, file)

def load_variable_from_json(file_path):
    with open(file_path, 'r') as file:
        variable = json.load(file)
    return variable

# %%
device = 'cuda' if cuda.is_available() else 'cpu'
print(device)
# Out:
# cpu

# %%
# Extracting only hotel and restaurant features from the dataset
def preprocess_split(dataset, split):
    df = dataset[split].to_pandas()
    new_df = pd.DataFrame(columns = df.columns)
    for i in range(len(df)):
        # Taken from notebook, to know which lines to skip
        row = df.loc[i]
        if not any(set(row.turns['frames'][turn_id]['service']).intersection(['hotel', 'restaurant']) for turn_id,utt in enumerate(row.turns['utterance'])):
            continue

        new_df.loc[len(new_df)] = row
    return new_df

# %%
def process_service_list(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service == 'restaurant':
            services.add('restaurant')
        elif service == 'hotel':
            services.add('hotel')
        else:
            services.add('other')
        if len(services) == 3:
            break
    return list(services)

def process_dialogue_act(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service.startswith('Restaurant'):
            services.add(service)
        elif service.startswith('Hotel'):
            services.add(service)
        elif service.startswith('general'):
            services.add(service)
        else:
            services.add('other')
    return list(services)

# %%
def parse(sentence):
    # Tokenize
    sentence = nlp(sentence)
    # Remove stop words
    sentence = " ".join([token.lemma_ for token in sentence])
    
    return sentence

# %%
def extract_token_bio_tags(dataset):
    utterances = [[]]
    tags = [[]]
    count = 0

    for i in tqdm(range(len(dataset))):
        turns = dataset.loc[i].turns
        for j, (utterance, speaker, dialogue_act, frames) in enumerate(zip(turns['utterance'], turns['speaker'], turns['dialogue_acts'], turns['frames'])):
            if speaker != 0:
                continue
            if 'other' in process_service_list(frames['service']):
                continue
            
            if j == 0:
                prev_user_acts = []
                prev_bot_acts = []
            else:
                # Retrieve the previous user utterance and acts
                prev_user_acts = turns['dialogue_acts'][j - 2]['dialog_act']['act_type']
                prev_user_acts = process_dialogue_act(prev_user_acts)

                # Retrieve the previous bot utterance and acts
                prev_bot_acts = turns['dialogue_acts'][j - 1]['dialog_act']['act_type']
                prev_bot_acts = process_dialogue_act(prev_bot_acts)

            current_user_acts = dialogue_act['dialog_act']['act_type']
            current_user_acts = process_dialogue_act(current_user_acts)

            span_info = dialogue_act['span_info']
            act_types = span_info['act_type']
            act_slot_names = span_info['act_slot_name']
            act_slot_values = span_info['act_slot_value']
            span_starts = span_info['span_start']
            span_ends = span_info['span_end']
            slots = {slot_name : {'act_type': act_type, 'start': start, 'end': end} for slot_name, act_type, start, end in zip(act_slot_names, act_types, span_starts, span_ends)}
            
            #Preprocess
            utterances.append([])
            tags.append([])
            count = count+1

            prev_user_acts_str = " , ".join(prev_user_acts)
            prev_bot_acts_str = " , ".join(prev_bot_acts)
            current_user_acts_str = " , ".join(current_user_acts)
            hystory = " | ".join([prev_user_acts_str, prev_bot_acts_str, current_user_acts_str]) + " | "

            for word in hystory.split():
                utterances[count].append(word)
                tags[count].append("O")
            
            last_tag = 0
            for slot_name in slots:
                act_category = slots[slot_name]['act_type'].split("-")[0].lower()

                slot_start, slot_end = slots[slot_name]['start'], slots[slot_name]['end']

                
                #tokens = re.sub("[^a-zA-Z0-9]", " ", utterance[slot_start:slot_end]).lower().split()
                for word in parse(utterance[last_tag:slot_start]).split():
                #for word in re.sub("[^a-zA-Z0-9]", " ", utterance[last_tag:slot_start]).lower().split():
                    utterances[count].append(word)
                    tags[count].append("O")

                tokens = parse(utterance[slot_start:slot_end]).split()
                for j, token in enumerate(tokens):
                    bio_type = 'B-' if j == 0 else 'I-'    
                    utterances[count].append(token) 
                    tags[count].append(bio_type + act_category + '-' + slot_name)
                last_tag = slot_end

            #for word in re.sub("[^a-zA-Z0-9]", " ", utterance[last_tag:]).lower().split():
            for word in parse(utterance[last_tag:]).split():
                    utterances[count].append(word)
                    tags[count].append("O")

    return utterances, tags

# %%
try:
    print('Loading from json...')
    train_words, train_tags = load_variable_from_json(TRAIN_DATA_SAVE_PATH)
    test_words, test_tags = load_variable_from_json(TEST_DATA_SAVE_PATH)
    valid_words, valid_tags = load_variable_from_json(VALID_DATA_SAVE_PATH)
    print('Loaded from json')
except:
    print('Exception occured during loading from json')
    print('Loading dataset...')

    try:
        if ALWAYS_LOAD_DATASET:
            raise Exception('Load data always')
        # Run it only once
        data = DatasetDict.load_from_disk(DATASET_DIRECTORY)
        
    except:
        # Run it only once
        dataset = load_dataset("multi_woz_v22")

        if SAVE_DATASET:
            # Run it only once
            dataset.save_to_disk(DATASET_DIRECTORY)

    print('Preprocessing...')
    train = preprocess_split(data, 'train')
    val = preprocess_split(data, 'validation')
    test = preprocess_split(data, 'test')

    print('Extracting utterances and bio tags...')
    train_words, train_tags = extract_token_bio_tags(train)
    valid_word, valid_tags = extract_token_bio_tags(val)
    test_word, test_tags = extract_token_bio_tags(test)
    
    print('Saving to json...')
    save_variable_to_json([train_words, train_tags] , TRAIN_DATA_SAVE_PATH)
    save_variable_to_json([test_word, test_tags], TEST_DATA_SAVE_PATH)
    save_variable_to_json([valid_word, valid_tags], VALID_DATA_SAVE_PATH)

    print('Saved to json')
# Out:
# Loading from json...
# Loaded from json

# %%
for word, tag in zip(train_words[4:41], train_tags[4:41]):
    print()
    for w, t in zip(word, tag):
        print(w, t)
# Out:
# Restaurant-Request O
# , O
# Hotel-Inform O
# | O
# Hotel-Recommend O
# , O
# Restaurant-Inform O
# | O
# Hotel-Inform O
# | O
# yes O
# . O
# can O
# you O
# book O
# it O
# for O
# I O
# ? O
#
# Hotel-Inform O
# | O
# other O
# | O
# Hotel-Inform O
# | O
# I O
# want O
# to O
# book O
# it O
# for O
# 2 B-hotel-bookstay
# people O
# and O
# 2 B-hotel-bookpeople
# night O
# start O
# from O
# saturday B-hotel-bookday
# . O
#
# | O
# | O
# Hotel-Inform O
# | O
# Guten O
# Tag O
# , O
# I O
# be O
# stay O
# overnight O
# in O
# Cambridge O
# and O
# need O
# a O
# place O
# to O
# sleep O
# . O
# I O
# need O
# free O
# parking O
# and O
# internet O
# . O
#
# Hotel-Inform O
# | O
# Hotel-Inform O
# , O
# Hotel-Select O
# | O
# Hotel-Inform O
# | O
# no O
# , O
# but O
# I O
# would O
# really O
# like O
# to O
# be O
# on O
# the O
# south B-hotel-area
# end O
# of O
# the O
# city O
# . O
# do O
# any O
# of O
# those O
# fit O
# the O
# bill O
# ? O
#
# Hotel-Inform O
# | O
# Restaurant-Request O
# , O
# Hotel-Request O
# | O
# Hotel-Inform O
# , O
# Restaurant-Inform O
# | O
# no O
# I O
# do B-restaurant-pricerange
# n't I-restaurant-pricerange
# care I-restaurant-pricerange
# about O
# the O
# price O
# . O
# which O
# one O
# do O
# you O
# recommend O
# ? O
#
# Hotel-Inform O
# , O
# Restaurant-Inform O
# | O
# Hotel-Inform O
# , O
# Restaurant-Recommend O
# , O
# other O
# | O
# Hotel-Inform O
# | O
# yes O
# , O
# book O
# it O
# for O
# 4 B-hotel-bookstay
# people O
# and O
# 4 B-hotel-bookpeople
# night O
# start O
# from O
# tuesday B-hotel-bookday
# . O
#
# Hotel-Inform O
# | O
# other O
# | O
# Hotel-Inform O
# | O
# how O
# about O
# for O
# 3 B-hotel-bookstay
# night O
# ? O
#
# | O
# | O
# Hotel-Inform O
# | O
# hi O
# there O
# ! O
# can O
# you O
# give O
# I O
# some O
# info O
# on O
# Cityroomz B-hotel-name
# ? O
#
# Hotel-Inform O
# | O
# Hotel-Inform O
# , O
# other O
# | O
# Hotel-Inform O
# | O
# yes O
# please O
# . O
# I O
# need O
# it O
# for O
# 7 B-hotel-bookpeople
# people O
# for O
# 3 B-hotel-bookstay
# night O
# start O
# on O
# tuesday B-hotel-bookday
# . O
#
# Hotel-Inform O
# | O
# other O
# | O
# Hotel-Inform O
# | O
# I O
# would O
# like O
# to O
# book O
# it O
# for O
# 3 B-hotel-bookstay
# night O
# begin O
# on O
# Tuesday O
# . O
#
# Hotel-Inform O
# | O
# general-reqmore O
# , O
# other O
# | O
# Restaurant-Inform O
# | O
# yeah O
# , O
# I O
# need O
# a O
# restaurant O
# in O
# the O
# west B-restaurant-area
# and O
# with O
# expensive B-restaurant-pricerange
# pricing O
# . O
#
# Restaurant-Inform O
# | O
# Restaurant-Request O
# , O
# Restaurant-Inform O
# | O
# Restaurant-Request O
# | O
# no O
# , O
# I O
# do O
# n't O
# have O
# a O
# preference O
# , O
# but O
# I O
# need O
# the O
# phone O
# number O
# and O
# postcode O
# . O
#
# | O
# | O
# Hotel-Inform O
# | O
# I O
# be O
# look O
# for O
# a O
# hotel O
# name O
# alyesbray B-hotel-name
# lodge I-hotel-name
# guest I-hotel-name
# house I-hotel-name
# . O
#
# Hotel-Inform O
# | O
# general-reqmore O
# | O
# Hotel-Inform O
# | O
# I O
# would O
# like O
# to O
# book O
# a O
# reservation O
# for O
# it O
# . O
# can O
# you O
# help O
# I O
# with O
# that O
# ? O
#
# Hotel-Inform O
# | O
# other O
# | O
# Hotel-Inform O
# | O
# we O
# will O
# be O
# arrive O
# on O
# Sunday B-hotel-bookday
# and O
# will O
# stay O
# for O
# 5 B-hotel-bookstay
# night O
# . O
#
# Hotel-Inform O
# | O
# other O
# | O
# Hotel-Inform O
# | O
# there O
# will O
# be O
# 8 B-hotel-bookpeople
# guest O
# . O
#
# general-thank O
# | O
# general-bye O
# | O
# Restaurant-Inform O
# | O
# can O
# you O
# actually O
# look O
# up O
# a O
# restaurant O
# for O
# I O
# as O
# well O
# ? O
#
# Restaurant-Inform O
# | O
# Restaurant-Request O
# | O
# Restaurant-Inform O
# | O
# it O
# be O
# a O
# place O
# call O
# Don B-restaurant-name
# Pasquale I-restaurant-name
# Pizzeria I-restaurant-name
# . O
#
# | O
# | O
# Restaurant-Inform O
# | O
# I O
# be O
# look O
# for O
# a O
# restaurant O
# . O
# I O
# would O
# like O
# something O
# cheap B-restaurant-pricerange
# that O
# have O
# chinese B-restaurant-food
# food O
# . O
#
# Restaurant-Inform O
# | O
# Restaurant-Inform O
# , O
# other O
# | O
# Restaurant-Inform O
# | O
# yes O
# , O
# could O
# you O
# make O
# a O
# reservation O
# for O
# 1 B-restaurant-bookpeople
# at O
# 20:00 B-restaurant-booktime
# on O
# Saturday B-restaurant-bookday
# ? O
#
# other O
# | O
# other O
# | O
# Restaurant-Inform O
# | O
# I O
# be O
# also O
# look O
# for O
# the O
# Riverside B-restaurant-name
# Brasserie I-restaurant-name
# . O
#
# Restaurant-Inform O
# | O
# Restaurant-Inform O
# , O
# other O
# | O
# Restaurant-Request O
# | O
# yes O
# , O
# I O
# would O
# like O
# to O
# book O
# it O
# and O
# get O
# a O
# reference O
# number O
# . O
#
# Restaurant-Inform O
# | O
# other O
# | O
# Restaurant-Inform O
# | O
# 6 B-restaurant-bookpeople
# people O
# will O
# be O
# dine O
#
# | O
# | O
# Restaurant-Inform O
# | O
# I O
# be O
# look O
# for O
# an O
# expensive B-restaurant-pricerange
# restaurant O
# in O
# the O
# centre B-restaurant-area
# if O
# you O
# could O
# help O
# I O
# . O
#
# Restaurant-Inform O
# | O
# Restaurant-Request O
# , O
# Restaurant-Inform O
# | O
# Restaurant-Inform O
# | O
# no O
# , O
# not B-restaurant-food
# really I-restaurant-food
# . O
# I O
# think O
# I O
# would O
# like O
# to O
# try O
# something O
# different O
# . O
# could O
# you O
# suggest O
# something O
# ? O
#
# Restaurant-Inform O
# | O
# general-reqmore O
# , O
# Restaurant-Inform O
# | O
# Restaurant-Request O
# | O
# yes O
# , O
# I O
# would O
# like O
# both O
# the O
# phone O
# number O
# and O
# the O
# postcode O
# please O
# . O
#
# Restaurant-Request O
# | O
# general-reqmore O
# , O
# Restaurant-Inform O
# | O
# Restaurant-Request O
# | O
# can O
# I O
# also O
# have O
# the O
# address O
# please O
# ? O
#
# | O
# | O
# Hotel-Inform O
# | O
# I O
# be O
# look O
# for O
# a O
# place O
# to O
# go O
# and O
# see O
# during O
# my O
# upcoming O
# trip O
# to O
# Cambridge O
# . O
#
# other O
# | O
# general-reqmore O
# , O
# other O
# | O
# Hotel-Inform O
# | O
# yes O
# , O
# I O
# would O
# like O
# an O
# expensive B-hotel-pricerange
# hotel O
# with O
# free O
# parking O
# . O
#
# Hotel-Inform O
# | O
# Hotel-Inform O
# , O
# Hotel-Recommend O
# | O
# Hotel-Inform O
# | O
# be O
# it O
# four B-hotel-stars
# star O
# ? O
#
# other O
# | O
# other O
# | O
# Restaurant-Inform O
# | O
# no O
# need O
# to O
# book O
# it O
# . O
# thank O
# . O
# but O
# can O
# you O
# help O
# I O
# find O
# a O
# cheap B-restaurant-pricerange
# restaurant O
# in O
# the O
# south B-restaurant-area
# ? O
#
# Restaurant-Inform O
# | O
# Restaurant-Select O
# , O
# Restaurant-Inform O
# | O
# Restaurant-Inform O
# | O
# the O
# Lucky B-restaurant-name
# Star I-restaurant-name
# sound O
# good O
# . O
# that O
# be O
# all O
# I O
# need O
# . O
#
# Restaurant-Inform O
# | O
# other O
# | O
# Restaurant-Request O
# | O
# can O
# you O
# also O
# tell O
# I O
# the O
# postcode O
# ? O
#
# | O
# | O
# Restaurant-Inform O
# | O
# yeah O
# , O
# could O
# you O
# recommend O
# a O
# good O
# gastropub B-restaurant-food
# ? O
#
# Restaurant-Inform O
# | O
# Restaurant-Recommend O
# , O
# Restaurant-Inform O
# | O
# Restaurant-Inform O
# | O
# I O
# would O
# like O
# to O
# book O
# a O
# table O
# at O
# the O
# Backstreet B-restaurant-name
# Bistro I-restaurant-name
# for O
# 5 B-restaurant-bookpeople
# people O
# at O
# 16:00 B-restaurant-booktime
# on O
# Thursday B-restaurant-bookday
# . O
#
# | O
# | O
# Restaurant-Request O
# , O
# Restaurant-Inform O
# | O
# I O
# want O
# to O
# find O
# an O
# expensive B-restaurant-pricerange
# restaurant O
# and O
# serve O
# european B-restaurant-food
# food O
# . O
# can O
# I O
# also O
# have O
# the O
# address O
# , O
# phone O
# number O
# and O
# its O
# area O
# . O
# ? O
#
# | O
# | O
# Restaurant-Inform O
# | O
# where O
# be O
# a O
# good O
# place O
# to O
# eat O
# crossover B-restaurant-food
# food O
# in O
# Cambridge O
# ? O

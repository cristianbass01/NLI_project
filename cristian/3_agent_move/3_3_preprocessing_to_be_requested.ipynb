# %%
#Mount Google drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#change current working directory
#%cd "/content/drive/Shareddrives/NLI"

# %%
#!pip install transformers
#!pip install accelerate
#!pip install datasets
#!python3 -m spacy download en_core_web_lg

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import torch
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, Dataset
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import recall_score, precision_score, f1_score
from torch import cuda
import re
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from seqeval.metrics import classification_report
from itertools import product
import os
import joblib
import json
import math
import nltk
from datasets import load_dataset
from datasets import DatasetDict

nltk.download('punkt')

import spacy

nlp = spacy.load("en_core_web_lg")
# Out:
# [nltk_data] Downloading package punkt to /home/mister/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /home/mister/miniconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
DATASET_DIRECTORY = "./../dataset.hf/"
TRAIN_DATA_SAVE_PATH = "preprocessed_data_to_be_requested/train.json"
TEST_DATA_SAVE_PATH = "preprocessed_data_to_be_requested/test.json"
VALID_DATA_SAVE_PATH = "preprocessed_data_to_be_requested/valid.json"

ALWAYS_LOAD_DATASET = False
SAVE_DATASET = True

# %%
import json

def save_variable_to_json(variable, file_path):
    with open(file_path, 'w') as file:
        json.dump(variable, file)

def load_variable_from_json(file_path):
    with open(file_path, 'r') as file:
        variable = json.load(file)
    return variable

# %%
# Extracting only hotel and restaurant features from the dataset
def preprocess_split(dataset, split):
    df = dataset[split].to_pandas()
    new_df = pd.DataFrame(columns = df.columns)
    for i in range(len(df)):
        # Taken from notebook, to know which lines to skip
        row = df.loc[i]
        if not any(set(row.turns['frames'][turn_id]['service']).intersection(['hotel', 'restaurant']) for turn_id,utt in enumerate(row.turns['utterance'])):
            continue

        new_df.loc[len(new_df)] = row
    return new_df

# %%
def process_service_list(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service == 'restaurant':
            services.add('restaurant')
        elif service == 'hotel':
            services.add('hotel')
        else:
            services.add('other')
        if len(services) == 3:
            break
    return list(services)

def process_dialogue_act(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service.startswith('Restaurant') or service.startswith('restaurant'):
            services.add(service)
        elif service.startswith('Hotel') or service.startswith('hotel'):
            services.add(service)
        elif service.startswith('general') or service.startswith('General'):
            services.add(service)
        elif service.startswith('Booking') or service.startswith('booking'):
            services.add(service)
        else:
            services.add('other')
    return list(services)

# %%
def parse(sentence):
    # Tokenize
    sentence = nlp(sentence)
    # Remove stop words
    sentence = " ".join([token.lemma_ for token in sentence])
    
    return sentence

# %%
def get_act_type_to_slots(dialogue_act):
    act_type_to_slots = {}

    # All the slots that are present in the current user utterance
    span_info = dialogue_act['span_info']
    act_types = span_info['act_type']
    act_slot_names = span_info['act_slot_name']
    act_slot_values = span_info['act_slot_value']

    for slot_name, act_type, slot_value in zip(act_slot_names, act_types , act_slot_values):
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            if not act_type in act_type_to_slots:
                act_type_to_slots[act_type] = []
            act_type_to_slots[act_type].append(tuple([slot_name, slot_value]))

    # All the slots that are not present in the current user utterance (slots with '?')
    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    for act_type, act_slot in zip(act_types, act_slots):
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                if slot_name != "none" and  slot_value == "?":
                    if not act_type in act_type_to_slots:
                        act_type_to_slots[act_type] = []
                    act_type_to_slots[act_type].append(tuple([slot_name, slot_value]))
    return act_type_to_slots

# %%
def get_to_be_provided_overall(dialogue_act, current_booking_service):
    
    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    to_be_provided_overall = []
    for act_type, act_slot in zip(act_types, act_slots):
        # If the domain is booking, we need to know which service is being booked
        
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel') or act_type.startswith('Booking') or act_type.startswith('general'):
            domain = act_type.split("-")[0]
            if domain == "booking" and len(current_booking_service)==1:
                domain = current_booking_service[0]
            domain = domain.lower()

            if domain in ["hotel", "restaurant", "booking", "general"]:
                # Retrieve the slots that are in the form of "something : ?"
                slots = []
                for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                    if slot_name != "none" and  slot_value != "?":
                        slots.append(domain + "-" + slot_name + ":" + slot_value)
            
                if slots and any((slot_name_value.split(":")[0] != domain + "-none" for slot_name_value in slots)) and not "-No" in dialogue_act:
                    to_be_provided = ["%s-availability:yes" % (domain)] + slots
                    to_be_provided_overall.extend(to_be_provided)
                elif "-No" in dialogue_act:
                    to_be_provided = ["%s-availability:no" % (domain)] + slots
                    to_be_provided_overall.extend(to_be_provided)
            
    to_be_provided_overall = sorted(list(set(to_be_provided_overall)))
    remove_avail_no_list = [elem for elem in to_be_provided_overall if elem.endswith("availability:no")]
    for remove_avail in remove_avail_no_list:
        remove_avail_yes = remove_avail[:-2]+"yes"
        while remove_avail_yes in to_be_provided_overall:
            del to_be_provided_overall[to_be_provided_overall.index(remove_avail_yes)]

    return to_be_provided_overall

# %%
def get_to_be_requested(dialogue_act, current_booking_service):

    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    to_be_requested = []
    for act_type, act_slot in zip(act_types, act_slots):
        # If the domain is booking, we need to know which service is being booked
        
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel') or act_type.startswith('Booking') or act_type.startswith('general'):
            domain = act_type.split("-")[0].lower()
            if domain == "booking" and len(current_booking_service)==1:
                domain = current_booking_service[0]
            domain = domain.lower()
        
            if domain in ["hotel", "restaurant", "booking", "general"]:
                
                slots = []
                for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                    if slot_name != "none" and  slot_value == "?":
                        slots.append(domain + "-" + slot_name)
                
                to_be_requested.extend(slots)
    to_be_requested = sorted(list(set(to_be_requested)))
    return to_be_requested

# %%
def concatenate_to_be_retrieved(prev_user_utterance, prev_user_act_type_to_slots, user_utterance, user_act_type_to_slots, user_booking_service):

    historical_utterance = prev_user_utterance + " | "
    for act_type in prev_user_act_type_to_slots:
        historical_utterance += act_type + " = "
        for slot_name, slot_value in prev_user_act_type_to_slots[act_type]:
            historical_utterance += slot_name + " : " + slot_value + " , "
        
        if len(prev_user_act_type_to_slots[act_type]) > 0:
            # Remove last comma
            historical_utterance = historical_utterance[:-3]

        historical_utterance += " ; "

    if len(prev_user_act_type_to_slots) > 0:
        # Remove last semicolon
        historical_utterance = historical_utterance[:-3]

    
    historical_utterance += " | "
    historical_utterance += user_utterance + " | "
    for act_type in user_act_type_to_slots:
        historical_utterance += act_type + " = "
        for slot_name, slot_value in user_act_type_to_slots[act_type]:
            historical_utterance += slot_name + " : " + slot_value + " , "
        
        if len(user_act_type_to_slots[act_type]) > 0:
            # Remove last comma
            historical_utterance = historical_utterance[:-3]

        historical_utterance += " ; "

    if len(user_act_type_to_slots) > 0:
        # Remove last semicolon
        historical_utterance = historical_utterance[:-3]

    historical_utterance += " | "
    historical_utterance += " , ".join(user_booking_service)

    return historical_utterance

# %%
def extract_to_be_requested(dataset):
    target_list = []
    training_list = []

    for i in tqdm(range(len(dataset))):
        turns = dataset.loc[i].turns

        speaker_str = {'User': 0, 'Agent': 1}
        historical_slots = []

        for j, (utterance, speaker, dialogue_act) in enumerate(zip(turns['utterance'], turns['speaker'], turns['dialogue_acts'])):
            if speaker == speaker_str['Agent']:

                prev_user = j - 1
                # The dataset is very unbalanced, so I will remove the labels that does not have also our domain
                current_act_type = dialogue_act['dialog_act']['act_type']
                current_act_type = process_dialogue_act(current_act_type)
                current_act_type = [act_type for act_type in current_act_type if act_type.endswith('Request')]
                
                if len(current_act_type) == 0:
                    continue

                services = turns['frames'][prev_user]['service']
                user_booking_service = [service for service in services if service in ["hotel", "restaurant"]]
                if len(user_booking_service) == 0:
                    continue

                # let's see if we can retrieve something from the previous previous user
                prev_user = j - 3
                if prev_user >= 0:
                    # Retrieve the previous previous user stuff
                    prev_user_dialogue_act = turns['dialogue_acts'][prev_user]
                    prev_user_act_type_to_slots = get_act_type_to_slots(prev_user_dialogue_act)
                    prev_user_utterance = parse(turns['utterance'][prev_user])
                else:
                    prev_user_utterance = ""
                    prev_user_act_type_to_slots = {}

                # The user start, so there will always be j-1 turns before
                prev_user = j - 1

                
                # Retrieve the previous user stuff
                user_dialogue_act = turns['dialogue_acts'][prev_user]
                user_act_type_to_slots = get_act_type_to_slots(user_dialogue_act)
                user_utterance = parse(turns['utterance'][prev_user])
                
                for user_act_type in user_act_type_to_slots:
                    for slot_name, slot_value in user_act_type_to_slots[user_act_type]:
                        if slot_value != "?":
                            historical_slots.append(user_act_type + "-" + slot_name)
                            
                to_be_provided = get_to_be_provided_overall(dialogue_act, user_booking_service)
                
                # HISTORY = 2
                # - 2 Previous user utterance
                # - 2 Previous user acts
                # - 2 Previous slots (also slots with '?')
                # - Previous user utterance
                # - Previous user acts
                # - Previous slots (also slots with '?')
                # - to be provided overall
                # Structure: user_utterance | user_act = slot_name : slot_value , slot_name : slot_value
                #           user_utterance | user_act = slot_name : slot_value , slot_name : slot_value
                #           user_booking_service |
                #           historical slots |
                #           to_be_provided_overall

                historical_utterance = concatenate_to_be_retrieved(prev_user_utterance, prev_user_act_type_to_slots, user_utterance, user_act_type_to_slots, user_booking_service)
                historical_utterance += " | "
                historical_utterance += " , ".join(to_be_provided)

                # Target
                targets = get_to_be_requested(dialogue_act, user_booking_service)
                
                # If there is no request why should be a question?
                if(len(targets) == 0):
                    targets.append('none')
                training_list.append(historical_utterance)
                target_list.append(targets)

    return training_list, target_list

# %%
try:
    print('Loading from json...')
    train_utterances, train_labels = load_variable_from_json(TRAIN_DATA_SAVE_PATH)
    test_utterances, test_labels = load_variable_from_json(TEST_DATA_SAVE_PATH)
    valid_utterances, valid_labels = load_variable_from_json(VALID_DATA_SAVE_PATH)
    print('Loaded from json')
except:
    print('Exception occured during loading from json')
    print('Loading dataset...')

    try:
        if ALWAYS_LOAD_DATASET:
            raise Exception('Load data always')
        # Run it only once
        dataset = DatasetDict.load_from_disk(DATASET_DIRECTORY)
        
    except:
        # Run it only once
        dataset = load_dataset("multi_woz_v22")

        if SAVE_DATASET:
            # Run it only once
            dataset.save_to_disk(DATASET_DIRECTORY)

    print('Preprocessing...')
    train = preprocess_split(dataset, 'train')
    val = preprocess_split(dataset, 'validation')
    test = preprocess_split(dataset, 'test')

    print('Extracting utterances and act types...')
    train_utterances, train_labels = extract_to_be_requested(train)
    test_utterances, test_labels = extract_to_be_requested(test)
    valid_utterances, valid_labels = extract_to_be_requested(val)

    print('Saving to json...')
    save_variable_to_json([train_utterances,train_labels] , TRAIN_DATA_SAVE_PATH)
    save_variable_to_json([test_utterances,test_labels], TEST_DATA_SAVE_PATH)
    save_variable_to_json([valid_utterances,valid_labels], VALID_DATA_SAVE_PATH)

    print('Saved to json')
# Out:
# Loading from json...
# Exception occured during loading from json
# Loading dataset...
# Preprocessing...
# Extracting utterances and act types...
# 100%|██████████| 6321/6321 [01:21<00:00, 77.82it/s]
# 100%|██████████| 745/745 [00:10<00:00, 69.55it/s]
# 100%|██████████| 762/762 [00:10<00:00, 75.49it/s]
# Saving to json...
# Saved to json

# %%
none_count = train_labels.count(['none'])
train_labels.index(['none'])
print(train_utterances[train_labels.index(['none'])]  )
print("Number of 'none' labels:", none_count)
print("Total number of labels:", len(train_labels))
# Out:
# can I get the post code for Christ 's College ? |  | I be also look for a place to stay that have 4 star and in the centre of town . | Hotel-Inform = stars : 4 , area : centre | hotel | hotel-availability:yes , hotel-name:Alexander B&B , hotel-name:University Arms Hotel] , hotel-pricerange:?]
# Number of 'none' labels: 4
# Total number of labels: 7188

# %%
for utterance, act_type in zip(train_utterances[:100], train_labels[:100]):
    print("Utterance:", utterance)
    print("Act Type:", act_type)
    print()
# Out:
# Utterance: sound good , could I get that phone number ? also , could you recommend I an expensive hotel ? | Hotel-Inform = pricerange : expensive , type : hotel ; Restaurant-Request = phone : ? | yes . can you book it for I ? |  | hotel |
# Act Type: ['hotel-bookday']
#
# Utterance: Guten Tag , I be stay overnight in Cambridge and need a place to sleep . I need free parking and internet . |  | no , but I would really like to be on the south end of the city . do any of those fit the bill ? | Hotel-Inform = area : south | hotel , restaurant |
# Act Type: ['hotel-pricerange', 'restaurant-pricerange']
#
# Utterance: no I do not care about the price . which one do you recommend ? | Hotel-Inform = pricerange : dontcare ; Restaurant-Inform = pricerange : dontcare | yes , book it for 4 people and 4 night start from tuesday . | Hotel-Inform = bookstay : 4 , bookpeople : 4 , bookday : tuesday | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance: hi there ! can you give I some info on Cityroomz ? | Hotel-Inform = name : cityroomz | yes please . I need it for 7 people for 3 night start on tuesday . | Hotel-Inform = bookpeople : 7 , bookstay : 3 , bookday : tuesday | hotel |
# Act Type: ['hotel-bookstay']
#
# Utterance: I would like to book it for 3 night begin on Tuesday . | Hotel-Inform = bookstay : 3 | yeah , I need a restaurant in the west and with expensive pricing . | Restaurant-Inform = area : west , pricerange : expensive | restaurant | restaurant-area:west , restaurant-availability:yes , restaurant-choice:9 , restaurant-pricerange:expensive
# Act Type: ['restaurant-food']
#
# Utterance: I be look for a hotel name alyesbray lodge guest house . | Hotel-Inform = name : alyesbray lodge guest house | I would like to book a reservation for it . can you help I with that ? |  | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: I would like to book a reservation for it . can you help I with that ? |  | we will be arrive on Sunday and will stay for 5 night . | Hotel-Inform = bookday : sunday , bookstay : 5 | hotel |
# Act Type: ['hotel-bookpeople']
#
# Utterance: that be it thank you . |  | can you actually look up a restaurant for I as well ? |  | restaurant |
# Act Type: ['restaurant-area', 'restaurant-name']
#
# Utterance: yes , I would like to book it and get a reference number . | Restaurant-Request = ref : ? | can you try for Saturday at 13:00 ? | Restaurant-Inform = bookday : saturday , booktime : 13:00 | restaurant |
# Act Type: ['restaurant-bookpeople']
#
# Utterance:  |  | I be look for an expensive restaurant in the centre if you could help I . | Restaurant-Inform = pricerange : expensive , area : centre | restaurant | restaurant-availability:yes , restaurant-choice:lots
# Act Type: ['restaurant-food']
#
# Utterance:  |  | I be look for a place to go and see during my upcoming trip to Cambridge . |  | hotel |
# Act Type: ['hotel-area']
#
# Utterance:  |  | I need a place to stay that have free wifi . |  | hotel | hotel-availability:yes , hotel-choice:32 , hotel-internet:yes
# Act Type: ['hotel-pricerange']
#
# Utterance: I need a place to stay that have free wifi . |  | could you provide detail for something in the cheap price range ? | Hotel-Inform = pricerange : cheap | hotel | hotel-availability:yes , hotel-choice:33 , hotel-internet:yes , hotel-pricerange:cheap , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance: actually , yes . we be travel into the northern part of town . |  | that sound nice but I would like to see about a guesthouse with free wifi . | Hotel-Inform = type : guesthouse | hotel | hotel-area:north , hotel-availability:yes , hotel-choice:10 , hotel-internet:yes , hotel-type:guest houses
# Act Type: ['hotel-pricerange']
#
# Utterance:  |  | can you help I book a table at a chinese restaurant that be in the centre of town ? | Restaurant-Inform = food : chinese , area : centre | restaurant | restaurant-availability:yes , restaurant-choice:10 , restaurant-food:Chinese
# Act Type: ['restaurant-pricerange']
#
# Utterance: I need some cheap Chop Suey , please . | Restaurant-Inform = pricerange : cheap | that sound like they will have some awesome Chop Suey . please book I a table for 2 on Tuesday at 12:45 . | Restaurant-Inform = bookpeople : 2 , bookday : tuesday , booktime : 12:45 | restaurant |
# Act Type: ['restaurant-bookday', 'restaurant-booktime']
#
# Utterance:  |  | can you help I find an expensive chinese food restaurant ? | Restaurant-Inform = pricerange : expensive , food : chinese | restaurant | restaurant-availability:yes , restaurant-choice:nine
# Act Type: ['restaurant-area']
#
# Utterance:  |  | I be plan a vacation and really could use some help find a good place to stay in town . I have never be to Cambridge before . |  | hotel |
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance:  |  | I be look to go to dinner tonight and be in the mood for some good Bistro in the centre of town , can you find I some option ? | Restaurant-Inform = food : bistro , area : centre | restaurant |
# Act Type: ['restaurant-area', 'restaurant-food']
#
# Utterance: I would like to book that train for 4 people please . |  | yeah , I be also look for a place to stay . I do not like hotel , so a guesthouse would be well . moderate in price . | Hotel-Inform = type : guesthouse , pricerange : moderate | hotel | hotel-availability:yes , hotel-choice:several , hotel-pricerange:moderate priced , hotel-type:guesthouses
# Act Type: ['hotel-area']
#
# Utterance:  |  | I be look for a restaurant . |  | restaurant |
# Act Type: ['restaurant-food', 'restaurant-pricerange']
#
# Utterance:  |  | I be look for a high price hotel in the north side of town | Hotel-Inform = area : north | hotel |
# Act Type: ['hotel-area']
#
# Utterance: it should be in the centre and be on the expensive side . | Hotel-Inform = area : centre , pricerange : expensive | can you book the one without wifi ? | Hotel-Inform = bookpeople : 1 , bookstay : 1 | hotel | hotel-availability:yes , hotel-internet:yes
# Act Type: ['hotel-bookday', 'hotel-bookpeople']
#
# Utterance: thank you for your help . |  | yes a hotel please . | Hotel-Inform = type : hotel | hotel |
# Act Type: ['hotel-area', 'hotel-pricerange', 'hotel-type']
#
# Utterance:  |  | hey , I be up south can you give I a place to eat ? | Restaurant-Inform = area : south | restaurant |
# Act Type: ['restaurant-food']
#
# Utterance: I will be stay in Cambridge . I need a hotel with wifi . | Hotel-Inform = type : hotel | I need something in the centre . | Hotel-Inform = area : centre | hotel | hotel-availability:yes , hotel-choice:7 , hotel-type:hotels
# Act Type: ['hotel-area']
#
# Utterance: I need something in the centre . | Hotel-Inform = area : centre | the north part of town | Hotel-Inform = area : north | hotel | hotel-area:north , hotel-availability:yes , hotel-choice:12 , hotel-type:Guesthouse , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance: ok great . can you book a room for 6 people and 3 night start from Saturday . | Hotel-Inform = bookstay : 3 | great , thank you . I be also in need of an indian restaurant in the cheap price range . can you find I one ? | Restaurant-Inform = food : indian , pricerange : cheap | restaurant | restaurant-availability:yes , restaurant-choice:several
# Act Type: ['restaurant-area']
#
# Utterance: I would like it to be in Centre . | Restaurant-Inform = area : centre | can you make I a reservation for Saturday please for 3 people ? | Restaurant-Inform = bookday : saturday , bookpeople : 3 | restaurant | booking-availability:yes , booking-bookday:Saturday
# Act Type: ['restaurant-booktime']
#
# Utterance: something in the same area as the restaurant . it should also be in that same price range . | Hotel-Inform = area : centre | yes , that should be perfect thank you . |  | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: I live in the centre of town and want to see if I can find a reasonable room for my parent to stay while they be visit . | Hotel-Inform = area : centre | that sound like it might work . could you check availability for two people this weekend ? | Hotel-Inform = bookpeople : 2 | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance:  |  | I be look for information in Cambridge . I need a place to dine . |  | restaurant |
# Act Type: ['restaurant-food']
#
# Utterance: crossover food would be perfect . | Restaurant-Inform = food : crossover | be there a gastropub in Centre ? | Restaurant-Inform = food : gastropub , area : centre | restaurant | restaurant-availability:yes , restaurant-choice:one , restaurant-choice:two , restaurant-pricerange:expensive , restaurant-pricerange:moderately priced
# Act Type: ['restaurant-pricerange']
#
# Utterance: do they have free parking ? be they rate 3 star ? | Hotel-Inform = stars : 3 | do you have something that fit with 3 star ? | Hotel-Inform = stars : 3 | hotel | hotel-availability:yes , hotel-stars:3 , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance:  |  | I be look for a 4 star place to stay . | Hotel-Inform = stars : 4 | hotel |
# Act Type: ['hotel-area']
#
# Utterance:  |  | I be look for a place to eat . I would like it to be an expensive restaurant in the centre . | Restaurant-Inform = pricerange : expensive , area : centre | restaurant | restaurant-area:centre , restaurant-availability:yes , restaurant-choice:33 , restaurant-pricerange:expensive
# Act Type: ['restaurant-food']
#
# Utterance: I be look for a restaurant with mediterranean food . | Restaurant-Inform = food : mediterranean | please book the One be La mimosa | Restaurant-Inform = name : la mimosa | restaurant |
# Act Type: ['restaurant-bookday', 'restaurant-bookpeople', 'restaurant-booktime']
#
# Utterance: yes that will work . I need to book it for 2 people . |  | can you find I a expensive cafe to eat at once I get off the train ? |  | restaurant |
# Act Type: ['restaurant-food']
#
# Utterance: I be look for something in the moderate price range actually . | Hotel-Inform = pricerange : moderate | yes please book the Archway House . | Hotel-Inform = name : archway house | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: I will be arrive on tuesday and I need to book the room for four night for three people . | Hotel-Inform = bookday : tuesday , bookstay : 4 , bookpeople : 3 | yes , I would also l like to find a splendid , moderately - price place to dine in the centre . that would be just wonderful if you could help I out with that ! | Restaurant-Inform = pricerange : moderate , area : centre | restaurant , hotel | restaurant-area:centre area , restaurant-availability:yes , restaurant-choice:several , restaurant-pricerange:moderately priced
# Act Type: ['restaurant-food']
#
# Utterance:  |  | hi , I need a moderate price range restaurant in the centre of town . | Restaurant-Inform = pricerange : moderate , area : centre | restaurant | restaurant-area:centre of town , restaurant-availability:yes , restaurant-choice:21 , restaurant-pricerange:moderately priced
# Act Type: ['restaurant-food']
#
# Utterance:  |  | we will be on the west side of town and would like to find a place to eat while there . | Restaurant-Inform = area : west | restaurant |
# Act Type: ['restaurant-food']
#
# Utterance: we will be on the west side of town and would like to find a place to eat while there . | Restaurant-Inform = area : west | I want some scottish food . | Restaurant-Inform = food : scottish | restaurant |
# Act Type: ['restaurant-area']
#
# Utterance: yeah , can you check the south please ? | Restaurant-Inform = area : south | what a bummer . find I a restaurant that serve british food on the West please . | Restaurant-Inform = food : british , area : west | restaurant | restaurant-availability:yes , restaurant-choice:3 , restaurant-food:British
# Act Type: ['restaurant-pricerange']
#
# Utterance:  |  | I be plan a trip in Cambridge |  | hotel |
# Act Type: ['hotel-area']
#
# Utterance: I be plan a trip in Cambridge |  | I be actually look to book a specific hotel . it be call the Alpha - Milton Guest House . | Hotel-Inform = name : alpha-milton guest house | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: I be also look for a hotel in the centre . I do not want to stay in a guesthouse . it need to be a hotel . | Hotel-Inform = type : hotel , area : centre | yes . that would be great . |  | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance: yes . that would be great . |  | I want to stay for 5 night start on Tuesday . | Hotel-Inform = bookstay : 5 , bookday : tuesday | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance:  |  | I be look for a hotel that include free wifi and free parking . |  | hotel | hotel-availability:yes , hotel-choice:lots , hotel-internet:yes , hotel-parking:yes
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance:  |  | can you help I find a place to stay that be four star and have free wifi ? | Hotel-Inform = bookstay : 4 | hotel | hotel-availability:yes , hotel-choice:Twenty one
# Act Type: ['hotel-area']
#
# Utterance: can you help I find a place to stay that be four star and have free wifi ? | Hotel-Inform = bookstay : 4 | that do not matter as long as it be cheap . | Hotel-Inform = pricerange : cheap | hotel | hotel-availability:yes , hotel-choice:21
# Act Type: ['hotel-area', 'hotel-parking']
#
# Utterance: I do not know if this be possible but can you please get I some information on the alexander bed and breakfast ? | Hotel-Inform = name : alexander bed and breakfast | ah , I just want to know it be still open . could you book I a room ? |  | hotel |
# Act Type: ['hotel-bookday']
#
# Utterance: ah , I just want to know it be still open . could you book I a room ? |  | 3 night start from friday . | Hotel-Inform = bookstay : 3 | hotel , restaurant | booking-availability:yes , booking-bookpeople:1
# Act Type: ['booking-bookpeople']
#
# Utterance: no , I would like it for 4 people . | Hotel-Inform = bookpeople : 4 | I also need to find an indian restaurant in the east please . | Restaurant-Inform = food : indian , area : east | restaurant | restaurant-availability:yes , restaurant-choice:a few , restaurant-food:Indian
# Act Type: ['restaurant-pricerange']
#
# Utterance: I also need to find an indian restaurant in the east please . | Restaurant-Inform = food : indian , area : east | in the mid - range would be fine . |  | restaurant | restaurant-availability:yes , restaurant-food:Indian , restaurant-name:Rajmahal , restaurant-pricerange:moderately priced
# Act Type: ['restaurant-bookpeople']
#
# Utterance:  |  | I need a place to eat that be expensive . | Restaurant-Inform = pricerange : expensive | restaurant , hotel | restaurant-availability:yes , restaurant-choice:57
# Act Type: ['restaurant-area']
#
# Utterance: I need a place to eat that be expensive . | Restaurant-Inform = pricerange : expensive | in the centre , please . | Restaurant-Inform = area : centre | restaurant , hotel | restaurant-availability:yes , restaurant-choice:33
# Act Type: ['restaurant-food']
#
# Utterance: in the centre , please . | Restaurant-Inform = area : centre | I want something with malaysian food . | Restaurant-Inform = food : malaysian | restaurant | restaurant-availability:yes , restaurant-food:malaysian
# Act Type: ['restaurant-food']
#
# Utterance: well , I need to know the arrival time first . |  | yeah , that work . can you recommend a 0 star hotel for I ? | Hotel-Inform = stars : 0 | hotel | hotel-availability:yes , hotel-choice:1 , hotel-choice:two , hotel-type:guesthouse , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance: if there be no 1 star guesthouse , please find I the cheap one that include free wifi . | Hotel-Inform = pricerange : cheap | yes Alexander bed and breakfast that have a star of 4 would be great . | Hotel-Inform = name : alexander bed and breakfast , stars : 4 | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: yes Alexander bed and breakfast that have a star of 4 would be great . | Hotel-Inform = name : alexander bed and breakfast , stars : 4 | there will be 7 people stay for 2 night begin on Thursday . | Hotel-Inform = bookpeople : 7 , bookstay : 2 , bookday : thursday | hotel |
# Act Type: ['hotel-bookstay']
#
# Utterance:  |  | can you help I in find a suitable guesthouse please ? | Hotel-Inform = type : guesthouse | hotel | hotel-availability:yes , hotel-choice:24 , hotel-type:guest houses
# Act Type: ['hotel-area']
#
# Utterance: I would like inexpensive turkish food . | Restaurant-Inform = food : turkish | ok , how about an italian restaurant ? | Restaurant-Inform = food : italian | restaurant | restaurant-availability:yes , restaurant-choice:5
# Act Type: ['restaurant-area']
#
# Utterance: hi ! would you please help I find a hotel to stay at ? | Hotel-Inform = type : hotel | it need to be 2 star , have free parking and free wifi . | Hotel-Inform = stars : 2 | hotel | hotel-availability:yes , hotel-choice:3
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance: I need a south restaurant with british food . | Restaurant-Inform = area : south , food : british | be there a chinese restaurant in the south part of town ? | Restaurant-Inform = food : chinese , area : south | restaurant | restaurant-area:south part of town , restaurant-availability:yes , restaurant-choice:three , restaurant-food:Chinese
# Act Type: ['restaurant-pricerange']
#
# Utterance: can you provide I the full address include postal code ? thank . | Restaurant-Request = postcode : ? | yes , I would also like to find an expensive restaurant in the same area . | Restaurant-Inform = pricerange : expensive , area : centre | restaurant |
# Act Type: ['restaurant-food', 'restaurant-pricerange']
#
# Utterance: you know what , the hotel will actually work for I . can you tell I where Cityroomz be locate ? | Hotel-Inform = type : hotel | yes , can you book that for I for 5 people and 4 night ? I need it on Sunday . | Hotel-Inform = bookpeople : 5 , bookstay : 4 , bookday : sunday | hotel |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance: good morning , I need help find a restaurant that serve bistro in the moderate price range . | Restaurant-Inform = food : bistro , pricerange : moderate | how about one with british food ? | Restaurant-Inform = food : british | restaurant | restaurant-availability:yes , restaurant-choice:5 , restaurant-food:british
# Act Type: ['restaurant-area']
#
# Utterance: how about one with british food ? | Restaurant-Inform = food : british | I do not have a preferred area . which one have a table available for 6 people at 12:30 on Tuesday ? | Restaurant-Inform = bookpeople : 6 , booktime : 12:30 , bookday : tuesday | restaurant |
# Act Type: ['restaurant-pricerange']
#
# Utterance:  |  | can you help I find a moderately price place to eat locate in the centre ? | Restaurant-Inform = pricerange : moderate , area : centre | restaurant | restaurant-availability:yes , restaurant-choice:many
# Act Type: ['restaurant-food']
#
# Utterance: yes , do any serve international food ? | Restaurant-Inform = food : international | can you check to see if either have booking for 5 people at 17:15 on monday ? | Restaurant-Inform = bookpeople : 5 , booktime : 17:15 , bookday : monday | restaurant |
# Act Type: ['restaurant-booktime']
#
# Utterance:  |  | can you help I find a place to stay that be expensive and include free parking ? | Hotel-Inform = pricerange : expensive | hotel |
# Act Type: ['hotel-area']
#
# Utterance:  |  | what be my option for cheap restaurant in the city center ? | Restaurant-Inform = pricerange : cheap , area : centre | restaurant | restaurant-availability:yes , restaurant-choice:15
# Act Type: ['restaurant-food']
#
# Utterance:  |  | I would like a guesthouse in the moderate price range . do you think you could find one for I ? | Hotel-Inform = type : guesthouse , pricerange : moderate | hotel |
# Act Type: ['hotel-area']
#
# Utterance: I have no preference , but the guesthouse should include free parking . |  | that be perfect . I would like to book it for 1 person . it need to be for 4 night begin Saturday . | Hotel-Inform = bookpeople : 1 , bookstay : 4 , bookday : saturday | hotel | booking-availability:yes , booking-bookstay:those dates , hotel-availability:yes , hotel-name:the Acorn Guest House
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance:  |  | I be look for a hotel that give I free parking and free wifi . | Hotel-Inform = type : hotel | hotel | hotel-availability:yes , hotel-choice:many
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance: I be look for a hotel that give I free parking and free wifi . | Hotel-Inform = type : hotel | oh , I would like a guesthouse that be moderately price please . | Hotel-Inform = type : guesthouse , pricerange : moderate | hotel | hotel-availability:yes , hotel-choice:many
# Act Type: ['hotel-area']
#
# Utterance: no need to book it today . I would like the price and travel time if you have it there , though . |  | I also need a hotel with free parking . |  | hotel | hotel-availability:yes , hotel-choice:29 , hotel-type:hotels
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance: I would like a guesthouse with a star of 4 , please . | Hotel-Inform = type : guesthouse , stars : 4 | yes please , I need it for 4 people , 3 night start on Wednesday . | Hotel-Inform = bookpeople : 4 , bookstay : 3 , bookday : wednesday | hotel |
# Act Type: ['hotel-bookstay']
#
# Utterance:  |  | be there any place here in the centre that serve corsica food ? | Restaurant-Inform = area : centre , food : corsica | restaurant |
# Act Type: ['restaurant-pricerange']
#
# Utterance: be there any place here in the centre that serve corsica food ? | Restaurant-Inform = area : centre , food : corsica | any price range will do . | Restaurant-Inform = pricerange : dontcare | restaurant |
# Act Type: ['restaurant-area', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: Nados serve Portuguese sound good can I get a address , food type , and phone number ? | Restaurant-Inform = name : nados ; Restaurant-Request = address : ? , food : ? , phone : ? | excellent . I also need to find a place to stay while in town . can you help I find a cheap hotel ? | Hotel-Inform = pricerange : cheap , type : hotel | restaurant , hotel |
# Act Type: ['hotel-area']
#
# Utterance: I be look for a cheap restaurant that serve scandinavian food | Restaurant-Inform = pricerange : cheap , food : scandinavian | be there any cheap restaurant that serve italian food ? | Restaurant-Inform = pricerange : cheap , food : italian | restaurant | restaurant-area:centre of town , restaurant-area:north , restaurant-area:west , restaurant-availability:yes , restaurant-choice:Three , restaurant-choice:five , restaurant-choice:one , restaurant-food:Italian , restaurant-pricerange:cheap
# Act Type: ['restaurant-area']
#
# Utterance:  |  | I be look for a place to stay . the hotel should include free wifi and should be in the type of hotel | Hotel-Inform = type : hotel | hotel | hotel-availability:yes , hotel-choice:quite a few , hotel-type:hotel
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance: yes . I want to book it for 1 person . I want to stay for 5 night start from Wednesday . | Hotel-Inform = bookpeople : 1 , bookstay : 5 , bookday : wednesday | yes please . another 3 - star hotel in the centre with free wifi . | Hotel-Inform = stars : 3 , area : centre | hotel | hotel-area:centre , hotel-availability:yes , hotel-stars:3 , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance: how about one that be in the type of museum.and make make sure you get address |  | I also need a moderate price room . | Hotel-Inform = pricerange : moderate | hotel |
# Act Type: ['hotel-area']
#
# Utterance: I also need a moderate price room . | Hotel-Inform = pricerange : moderate | I would like it to be a guest house in the north . | Hotel-Inform = area : north | hotel |
# Act Type: ['hotel-bookday']
#
# Utterance: I would like it to be a guest house in the north . | Hotel-Inform = area : north | I be not sure yet . I be really research right now . can you please recommend a guesthouse in the north in the moderate price range ? |  | hotel | hotel-availability:yes , hotel-choice:9 , hotel-pricerange:that price range , hotel-type:guesthouses
# Act Type: ['hotel-internet', 'hotel-parking']
#
# Utterance: yes , please tell I your favorite guesthouse in the north and let I know their address and whether they offer free internet and parking . | Hotel-Inform = type : guesthouse , area : north ; Hotel-Request = internet : ? , parking : ? | yes , please , I would appreciate that . |  | hotel |
# Act Type: ['hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: yes , Christ 's College . what be the entrance fee for that college ? |  | I also need a restaurant in the same area . | Restaurant-Inform = area : centre | restaurant | restaurant-availability:yes , restaurant-choice:many
# Act Type: ['restaurant-food', 'restaurant-pricerange']
#
# Utterance:  |  | I be look for a restaurant that serve international food . | Restaurant-Inform = food : international | restaurant | restaurant-availability:yes , restaurant-choice:three , restaurant-food:international
# Act Type: ['restaurant-pricerange']
#
# Utterance: I be look for a restaurant that serve international food . | Restaurant-Inform = food : international | I would like to find a moderately price place and I need a reservation for 4 people at 12:15 on a Thursday . | Restaurant-Inform = pricerange : moderate , bookpeople : 4 , booktime : 12:15 , bookday : thursday | restaurant | restaurant-availability:yes , restaurant-name:the Bloomsbury , restaurant-name:the Varsity
# Act Type: ['restaurant-booktime']
#
# Utterance: I need 1 ticket for departure on Thursday . |  | yes I want to reserve a table for 7 people at 15:00 on Thursday at an expensive african restaurant . can you help I with this ? | Restaurant-Inform = bookpeople : 7 , booktime : 15:00 , bookday : thursday , pricerange : expensive , food : african | restaurant |
# Act Type: ['restaurant-bookday', 'restaurant-booktime']
#
# Utterance: yes I want to reserve a table for 7 people at 15:00 on Thursday at an expensive african restaurant . can you help I with this ? | Restaurant-Inform = bookpeople : 7 , booktime : 15:00 , bookday : thursday , pricerange : expensive , food : african | sure . if there be no other african eatery to choose from , try the 14:00 at the Bedouin . |  | restaurant | booking-availability:yes , booking-name:bedouin
# Act Type: ['restaurant-bookday', 'restaurant-booktime']
#
# Utterance:  |  | I be look for a place to stay . |  | hotel |
# Act Type: ['hotel-area', 'hotel-internet', 'hotel-parking', 'hotel-pricerange']
#
# Utterance: I would be interested in see some interesting architecture . |  | no thank you though . I would like information on greek restaurant that would be in the same area as the church you suggest , please ? | Restaurant-Inform = food : greek , area : centre | restaurant | restaurant-area:centre , restaurant-availability:yes , restaurant-food:greek
# Act Type: ['restaurant-area']
#
# Utterance:  |  | I be look for a cheap place to stay . can you help ? | Hotel-Inform = pricerange : cheap | hotel | hotel-availability:yes , hotel-choice:a number of , hotel-pricerange:cheap , hotel-type:hotels
# Act Type: ['hotel-area']
#
# Utterance: I do not care which area the hotel be in . | Hotel-Inform = area : dontcare | any so long as it be a 2star and have wifi | Hotel-Inform = type : dontcare , stars : 2 | hotel |
# Act Type: ['hotel-pricerange']
#
# Utterance: yes please . book it for 3 people and 3 night start from friday . | Hotel-Inform = bookstay : 3 , bookpeople : 3 , bookday : friday | thank you . I be also look for a restaurant that serve vegetarian food and that be expensive . | Restaurant-Inform = food : vegetarian , pricerange : expensive | restaurant , hotel | restaurant-availability:yes , restaurant-food:vegetarian
# Act Type: ['restaurant-food']
#
# Utterance: thank you . I be also look for a restaurant that serve vegetarian food and that be expensive . | Restaurant-Inform = food : vegetarian , pricerange : expensive | Italian would be fine . | Restaurant-Inform = food : italian | restaurant | restaurant-area:around town , restaurant-availability:yes , restaurant-choice:5 , restaurant-food:Italian , restaurant-pricerange:expensive
# Act Type: ['restaurant-area']

# %%
none_count = train_labels.count(['none'])
print("Number of 'none' labels:", none_count)
print("Total number of labels:", len(train_labels))
# Out:
# Number of 'none' labels: 4
# Total number of labels: 7188

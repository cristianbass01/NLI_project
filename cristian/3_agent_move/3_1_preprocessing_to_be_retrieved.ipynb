# %%
#Mount Google drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#change current working directory
#%cd "/content/drive/Shareddrives/NLI"

# %%
#!pip install transformers
#!pip install accelerate
#!pip install datasets
#!python3 -m spacy download en_core_web_lg

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import torch
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, Dataset
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import recall_score, precision_score, f1_score
from torch import cuda
import re
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from seqeval.metrics import classification_report
from itertools import product
import os
import joblib
import json
import math
import nltk
from datasets import load_dataset
from datasets import DatasetDict

nltk.download('punkt')

import spacy

nlp = spacy.load("en_core_web_lg")
# Out:
# [nltk_data] Downloading package punkt to /home/mister/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
DATASET_DIRECTORY = "./../dataset.hf/"
TRAIN_DATA_SAVE_PATH = "preprocessed_data_to_be_retrieved/train.json"
TEST_DATA_SAVE_PATH = "preprocessed_data_to_be_retrieved/test.json"
VALID_DATA_SAVE_PATH = "preprocessed_data_to_be_retrieved/valid.json"

ALWAYS_LOAD_DATASET = False
SAVE_DATASET = True

# %%
import json

def save_variable_to_json(variable, file_path):
    with open(file_path, 'w') as file:
        json.dump(variable, file)

def load_variable_from_json(file_path):
    with open(file_path, 'r') as file:
        variable = json.load(file)
    return variable

# %%
# Extracting only hotel and restaurant features from the dataset
def preprocess_split(dataset, split):
    df = dataset[split].to_pandas()
    new_df = pd.DataFrame(columns = df.columns)
    for i in range(len(df)):
        # Taken from notebook, to know which lines to skip
        row = df.loc[i]
        if not any(set(row.turns['frames'][turn_id]['service']).intersection(['hotel', 'restaurant']) for turn_id,utt in enumerate(row.turns['utterance'])):
            continue

        new_df.loc[len(new_df)] = row
    return new_df

# %%
def process_service_list(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service == 'restaurant':
            services.add('restaurant')
        elif service == 'hotel':
            services.add('hotel')
        else:
            services.add('other')
        if len(services) == 3:
            break
    return list(services)

def process_dialogue_act(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service.startswith('Restaurant'):
            services.add(service)
        elif service.startswith('Hotel'):
            services.add(service)
        elif service.startswith('general'):
            services.add(service)
        else:
            services.add('other')
    return list(services)

# %%
def parse(sentence):
    # Tokenize
    sentence = nlp(sentence)
    # Remove stop words
    sentence = " ".join([token.lemma_ for token in sentence])
    
    return sentence

# %%
def get_act_type_to_slots(dialogue_act):
    act_type_to_slots = {}

    # All the slots that are present in the current user utterance
    span_info = dialogue_act['span_info']
    act_types = span_info['act_type']
    act_slot_names = span_info['act_slot_name']
    act_slot_values = span_info['act_slot_value']

    for slot_name, act_type, slot_value in zip(act_slot_names, act_types , act_slot_values):
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            if not act_type in act_type_to_slots:
                act_type_to_slots[act_type] = []
            act_type_to_slots[act_type].append(tuple([slot_name, slot_value]))

    # All the slots that are not present in the current user utterance (slots with '?')
    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    for act_type, act_slot in zip(act_types, act_slots):
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                if slot_name != "none" and  slot_value == "?":
                    if not act_type in act_type_to_slots:
                        act_type_to_slots[act_type] = []
                    act_type_to_slots[act_type].append(tuple([slot_name, slot_value]))
    return act_type_to_slots

# %%
def get_to_be_retrieved(dialogue_act, current_booking_service):
    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']
    
    to_be_retrieved = []
    for act_type, act_slot in zip(act_types, act_slots):
        # If the domain is booking, we need to know which service is being booked
        
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            domain = act_type.split("-")[0]
            if domain == "booking" and len(current_booking_service)==1:
                domain = current_booking_service[0]
            domain = domain.lower()

            # Retrieve the slots that are in the form of "something : ?"
            slots = []
            for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                if slot_name != "none" and  slot_value != "?":
                    slots.append(domain + "-" + slot_name)

            if slots:
                # Add the domain + "-availability" slot
                to_be_retrieved_slot = [domain + "-availability"] + slots

                # Remove domain + "-choice" if it is present (WHYYY????)
                while domain+"-choice" in to_be_retrieved_slot:
                    del to_be_retrieved_slot[to_be_retrieved_slot.index(domain+"-choice")]
                to_be_retrieved.extend(to_be_retrieved_slot)
        
    # Remove duplicates
    to_be_retrieved = sorted(list(set(to_be_retrieved)))
    return to_be_retrieved

# %%
def concatenate_to_be_retrieved(prev_user_utterance, prev_user_act_type_to_slots, user_utterance, user_act_type_to_slots, user_booking_service):

    historical_utterance = prev_user_utterance + " | "
    for act_type in prev_user_act_type_to_slots:
        historical_utterance += act_type + " = "
        for slot_name, slot_value in prev_user_act_type_to_slots[act_type]:
            historical_utterance += slot_name + " : " + slot_value + " , "
        
        if len(prev_user_act_type_to_slots[act_type]) > 0:
            # Remove last comma
            historical_utterance = historical_utterance[:-3]

        historical_utterance += " ; "

    if len(prev_user_act_type_to_slots) > 0:
        # Remove last semicolon
        historical_utterance = historical_utterance[:-3]

    
    historical_utterance += " | "
    historical_utterance += user_utterance + " | "
    for act_type in user_act_type_to_slots:
        historical_utterance += act_type + " = "
        for slot_name, slot_value in user_act_type_to_slots[act_type]:
            historical_utterance += slot_name + " : " + slot_value + " , "
        
        if len(user_act_type_to_slots[act_type]) > 0:
            # Remove last comma
            historical_utterance = historical_utterance[:-3]

        historical_utterance += " ; "

    if len(user_act_type_to_slots) > 0:
        # Remove last semicolon
        historical_utterance = historical_utterance[:-3]

    historical_utterance += " | "
    historical_utterance += " , ".join(user_booking_service)

    return historical_utterance

# %%
def extract_to_be_retrieved(dataset):
    target_list = []
    training_list = []

    for i in tqdm(range(len(dataset))):
        turns = dataset.loc[i].turns

        speaker_str = {'User': 0, 'Agent': 1}
        
        for j, (utterance, speaker, dialogue_act) in enumerate(zip(turns['utterance'], turns['speaker'], turns['dialogue_acts'])):
            if speaker == speaker_str['Agent']:
                
                prev_user = j - 1
                services = turns['frames'][prev_user]['service']
                user_booking_service = [service for service in services if service in ["hotel", "restaurant"]]
            
                if len(user_booking_service) == 0:
                    continue

                # The user start, so there will always be j-1 turns before
                # Retrieve the previous user dialogue act
                prev_user = j - 3
                if prev_user >= 0:
                    user_dialogue_act = turns['dialogue_acts'][prev_user]

                    prev_user_act_type_to_slots = get_act_type_to_slots(user_dialogue_act)

                    prev_user_utterance = parse(turns['utterance'][prev_user])
                else:
                    prev_user_utterance = ""
                    prev_user_act_type_to_slots = {}

                prev_user = j - 1

                user_dialogue_act = turns['dialogue_acts'][prev_user]

                user_act_type_to_slots = get_act_type_to_slots(user_dialogue_act)

                user_utterance = parse(turns['utterance'][prev_user])
                    
                # HISTORY = 2
                # - 2 Previous user utterance
                # - 2 Previous user acts
                # - 2 Previous slots (also slots with '?')
                # - Previous user utterance
                # - Previous user acts
                # - Previous slots (also slots with '?')
                # Structure: user_utterance | user_act = slot_name : slot_value , slot_name : slot_value ; user_act = slot_name : slot_value , slot_name : slot_value |
                #           user_utterance | user_act = slot_name : slot_value , slot_name : slot_value ; user_act = slot_name : slot_value , slot_name : slot_value |
                
                historical_utterance = concatenate_to_be_retrieved(prev_user_utterance, prev_user_act_type_to_slots, user_utterance, user_act_type_to_slots, user_booking_service)

                # Target
                targets = get_to_be_retrieved(dialogue_act, user_booking_service)

                # The dataset is very unbalanced, so I will remove the labels that does not have also our domain                
                if(len(targets) == 0):
                    targets.append('none')
                training_list.append(historical_utterance)
                target_list.append(targets)

    return training_list, target_list

# %%
try:
    print('Loading from json...')
    train_utterances, train_labels = load_variable_from_json(TRAIN_DATA_SAVE_PATH)
    test_utterances, test_labels = load_variable_from_json(TEST_DATA_SAVE_PATH)
    valid_utterances, valid_labels = load_variable_from_json(VALID_DATA_SAVE_PATH)
    print('Loaded from json')
except:
    print('Exception occured during loading from json')
    print('Loading dataset...')

    try:
        if ALWAYS_LOAD_DATASET:
            raise Exception('Load data always')
        # Run it only once
        dataset = DatasetDict.load_from_disk(DATASET_DIRECTORY)
        
    except:
        # Run it only once
        dataset = load_dataset("multi_woz_v22")

        if SAVE_DATASET:
            # Run it only once
            dataset.save_to_disk(DATASET_DIRECTORY)

    print('Preprocessing...')
    train = preprocess_split(dataset, 'train')
    val = preprocess_split(dataset, 'validation')
    test = preprocess_split(dataset, 'test')

    print('Extracting utterances and act types...')
    train_utterances, train_labels = extract_to_be_retrieved(train)
    test_utterances, test_labels = extract_to_be_retrieved(test)
    valid_utterances, valid_labels = extract_to_be_retrieved(val)

    print('Saving to json...')
    save_variable_to_json([train_utterances,train_labels] , TRAIN_DATA_SAVE_PATH)
    save_variable_to_json([test_utterances,test_labels], TEST_DATA_SAVE_PATH)
    save_variable_to_json([valid_utterances,valid_labels], VALID_DATA_SAVE_PATH)

    print('Saved to json')
# Out:
# Loading from json...
# Exception occured during loading from json
# Loading dataset...
# Preprocessing...
# Extracting utterances and act types...
# 100%|██████████| 6321/6321 [06:26<00:00, 16.36it/s]
# 100%|██████████| 745/745 [00:45<00:00, 16.41it/s]
# 100%|██████████| 762/762 [00:49<00:00, 15.49it/s]
# Saving to json...
# Saved to json

# %%
for utterance, act_type in zip(train_utterances[:100], train_labels[:100]):
    print("Utterance:", utterance)
    print("Act Type:", act_type)
    print()
# Out:
# Utterance:  |  | I need a place to dine in the center that s expensive | Restaurant-Inform = area : centre , pricerange : expensive | restaurant , hotel
# Act Type: ['restaurant-availability', 'restaurant-food']
#
# Utterance: I need a place to dine in the center that s expensive | Restaurant-Inform = area : centre , pricerange : expensive | any sort of food would be fine , as long as it be a bit expensive . could I get the phone number for your recommendation ? | Restaurant-Request = food : ? | restaurant , hotel
# Act Type: ['restaurant-area', 'restaurant-availability', 'restaurant-food', 'restaurant-name']
#
# Utterance: any sort of food would be fine , as long as it be a bit expensive . could I get the phone number for your recommendation ? | Restaurant-Request = food : ? | sound good , could I get that phone number ? also , could you recommend I an expensive hotel ? | Hotel-Inform = pricerange : expensive , type : hotel ; Restaurant-Request = phone : ? | restaurant , hotel
# Act Type: ['hotel-area', 'hotel-availability', 'hotel-name', 'restaurant-availability', 'restaurant-name', 'restaurant-phone']
#
# Utterance: sound good , could I get that phone number ? also , could you recommend I an expensive hotel ? | Hotel-Inform = pricerange : expensive , type : hotel ; Restaurant-Request = phone : ? | yes . can you book it for I ? |  | hotel
# Act Type: ['none']
#
# Utterance: yes . can you book it for I ? |  | I want to book it for 2 people and 2 night start from saturday . | Hotel-Inform = bookstay : 2 , bookpeople : 2 , bookday : saturday | hotel
# Act Type: ['none']
#
# Utterance:  |  | Guten Tag , I be stay overnight in Cambridge and need a place to sleep . I need free parking and internet . |  | hotel
# Act Type: ['hotel-availability', 'hotel-pricerange', 'hotel-type']
#
# Utterance: Guten Tag , I be stay overnight in Cambridge and need a place to sleep . I need free parking and internet . |  | no , but I would really like to be on the south end of the city . do any of those fit the bill ? | Hotel-Inform = area : south | hotel , restaurant
# Act Type: ['none']
#
# Utterance: no , but I would really like to be on the south end of the city . do any of those fit the bill ? | Hotel-Inform = area : south | no I do n't care about the price . which one do you recommend ? | Hotel-Inform = pricerange : dontcare ; Restaurant-Inform = pricerange : dontcare | hotel , restaurant
# Act Type: ['hotel-availability', 'hotel-name']
#
# Utterance: no I do n't care about the price . which one do you recommend ? | Hotel-Inform = pricerange : dontcare ; Restaurant-Inform = pricerange : dontcare | yes , book it for 4 people and 4 night start from tuesday . | Hotel-Inform = bookstay : 4 , bookpeople : 4 , bookday : tuesday | hotel
# Act Type: ['none']
#
# Utterance: yes , book it for 4 people and 4 night start from tuesday . | Hotel-Inform = bookstay : 4 , bookpeople : 4 , bookday : tuesday | how about for 3 night ? | Hotel-Inform = bookstay : 3 | hotel
# Act Type: ['none']
#
# Utterance:  |  | hi there ! can you give I some info on Cityroomz ? | Hotel-Inform = name : cityroomz | hotel
# Act Type: ['hotel-address', 'hotel-area', 'hotel-availability', 'hotel-name', 'hotel-pricerange', 'hotel-stars', 'hotel-type']
#
# Utterance: hi there ! can you give I some info on Cityroomz ? | Hotel-Inform = name : cityroomz | yes please . I need it for 7 people for 3 night start on tuesday . | Hotel-Inform = bookpeople : 7 , bookstay : 3 , bookday : tuesday | hotel
# Act Type: ['none']
#
# Utterance: yes please . I need it for 7 people for 3 night start on tuesday . | Hotel-Inform = bookpeople : 7 , bookstay : 3 , bookday : tuesday | I would like to book it for 3 night begin on Tuesday . | Hotel-Inform = bookstay : 3 | hotel
# Act Type: ['none']
#
# Utterance: I would like to book it for 3 night begin on Tuesday . | Hotel-Inform = bookstay : 3 | yeah , I need a restaurant in the west and with expensive pricing . | Restaurant-Inform = area : west , pricerange : expensive | restaurant
# Act Type: ['restaurant-area', 'restaurant-availability', 'restaurant-pricerange']
#
# Utterance: yeah , I need a restaurant in the west and with expensive pricing . | Restaurant-Inform = area : west , pricerange : expensive | no , I do n't have a preference , but I need the phone number and postcode . | Restaurant-Request = phone : ? , postcode : ? | restaurant
# Act Type: ['restaurant-availability', 'restaurant-name', 'restaurant-phone', 'restaurant-postcode']
#
# Utterance:  |  | I be look for a hotel name alyesbray lodge guest house . | Hotel-Inform = name : alyesbray lodge guest house | hotel
# Act Type: ['none']
#
# Utterance: I be look for a hotel name alyesbray lodge guest house . | Hotel-Inform = name : alyesbray lodge guest house | I would like to book a reservation for it . can you help I with that ? |  | hotel
# Act Type: ['none']
#
# Utterance: I would like to book a reservation for it . can you help I with that ? |  | we will be arrive on Sunday and will stay for 5 night . | Hotel-Inform = bookday : sunday , bookstay : 5 | hotel
# Act Type: ['none']
#
# Utterance: we will be arrive on Sunday and will stay for 5 night . | Hotel-Inform = bookday : sunday , bookstay : 5 | there will be 8 guest . | Hotel-Inform = bookpeople : 8 | hotel
# Act Type: ['none']
#
# Utterance: that be it thank you . |  | can you actually look up a restaurant for I as well ? |  | restaurant
# Act Type: ['none']
#
# Utterance: can you actually look up a restaurant for I as well ? |  | it be a place call Don Pasquale Pizzeria . | Restaurant-Inform = name : don pasquale pizzeria | restaurant
# Act Type: ['restaurant-area', 'restaurant-availability']
#
# Utterance: it be a place call Don Pasquale Pizzeria . | Restaurant-Inform = name : don pasquale pizzeria | yes , I do . I 'll need it book for the same day , same people , and we would like to eat at 19:00 . | Restaurant-Inform = bookday : sunday , bookpeople : 8 , booktime : 19:00 | restaurant
# Act Type: ['none']
#
# Utterance:  |  | I be look for a restaurant . I would like something cheap that have chinese food . | Restaurant-Inform = pricerange : cheap , food : chinese | restaurant
# Act Type: ['restaurant-availability', 'restaurant-name']
#
# Utterance: I be look for a restaurant . I would like something cheap that have chinese food . | Restaurant-Inform = pricerange : cheap , food : chinese | yes , could you make a reservation for 1 at 20:00 on Saturday ? | Restaurant-Inform = bookpeople : 1 , booktime : 20:00 , bookday : saturday | restaurant
# Act Type: ['none']
#
# Utterance: please find I a train from cambridge to stansted airport |  | Saturday leave Cambridge anytime after 20:00 please |  | restaurant
# Act Type: ['none']
#
# Utterance: can you book I 6 ticket please ? |  | I be also look for the Riverside Brasserie . | Restaurant-Inform = name : riverside brasserie | restaurant
# Act Type: ['restaurant-address', 'restaurant-area', 'restaurant-availability', 'restaurant-food', 'restaurant-name', 'restaurant-postcode']
#
# Utterance: I be also look for the Riverside Brasserie . | Restaurant-Inform = name : riverside brasserie | yes , I would like to book it and get a reference number . | Restaurant-Request = ref : ? | restaurant
# Act Type: ['none']
#
# Utterance: yes , I would like to book it and get a reference number . | Restaurant-Request = ref : ? | can you try for Saturday at 13:00 ? | Restaurant-Inform = bookday : saturday , booktime : 13:00 | restaurant
# Act Type: ['none']
#
# Utterance: can you try for Saturday at 13:00 ? | Restaurant-Inform = bookday : saturday , booktime : 13:00 | 6 people will be dine | Restaurant-Inform = bookpeople : 6 | restaurant
# Act Type: ['none']
#
# Utterance:  |  | I be look for an expensive restaurant in the centre if you could help I . | Restaurant-Inform = pricerange : expensive , area : centre | restaurant
# Act Type: ['restaurant-availability']
#
# Utterance: I be look for an expensive restaurant in the centre if you could help I . | Restaurant-Inform = pricerange : expensive , area : centre | no , not really . I think I would like to try something different . could you suggest something ? | Restaurant-Inform = food : dontcare | restaurant
# Act Type: ['restaurant-address', 'restaurant-availability', 'restaurant-food', 'restaurant-name']
#
# Utterance: no , not really . I think I would like to try something different . could you suggest something ? | Restaurant-Inform = food : dontcare | yes , I would like both the phone number and the postcode please . | Restaurant-Request = address : ? , phone : ? , postcode : ? | restaurant
# Act Type: ['restaurant-availability', 'restaurant-name', 'restaurant-phone', 'restaurant-postcode']
#
# Utterance: yes , I would like both the phone number and the postcode please . | Restaurant-Request = address : ? , phone : ? , postcode : ? | can I also have the address please ? | Restaurant-Request = address : ? | restaurant
# Act Type: ['restaurant-address', 'restaurant-availability', 'restaurant-name']
#
# Utterance:  |  | I be look for a place to go and see during my upcoming trip to Cambridge . |  | hotel
# Act Type: ['none']
#
# Utterance: that be a lot of choice , how about nightclub ? can you get I a couple of phone number for good one ? I be hope to catch DJ Squalour from Ibiza ! |  | yes , I would like an expensive hotel with free parking . | Hotel-Inform = pricerange : expensive | hotel
# Act Type: ['hotel-area', 'hotel-availability', 'hotel-name']
#
# Utterance: yes , I would like an expensive hotel with free parking . | Hotel-Inform = pricerange : expensive | be it four star ? | Hotel-Inform = stars : 4 | hotel
# Act Type: ['hotel-availability', 'hotel-internet', 'hotel-name', 'hotel-parking', 'hotel-pricerange', 'hotel-stars']
#
# Utterance: on Saturday . be there a train that will arrive by 15:15 ? |  | no need to book it . thank . but can you help I find a cheap restaurant in the south ? | Restaurant-Inform = pricerange : cheap , area : south | restaurant
# Act Type: ['restaurant-availability', 'restaurant-food', 'restaurant-name']
#
# Utterance: no need to book it . thank . but can you help I find a cheap restaurant in the south ? | Restaurant-Inform = pricerange : cheap , area : south | the Lucky Star sound good . that be all I need . | Restaurant-Inform = name : lucky star | restaurant
# Act Type: ['none']
#
# Utterance: the Lucky Star sound good . that be all I need . | Restaurant-Inform = name : lucky star | can you also tell I the postcode ? | Restaurant-Request = postcode : ? | restaurant
# Act Type: ['restaurant-availability', 'restaurant-postcode']
#
# Utterance:  |  | yeah , could you recommend a good gastropub ? | Restaurant-Inform = food : gastropub | restaurant
# Act Type: ['restaurant-availability', 'restaurant-name', 'restaurant-pricerange']
#
# Utterance: yeah , could you recommend a good gastropub ? | Restaurant-Inform = food : gastropub | I would like to book a table at the Backstreet Bistro for 5 people at 16:00 on Thursday . | Restaurant-Inform = name : backstreet bistro , bookpeople : 5 , booktime : 16:00 , bookday : thursday | restaurant
# Act Type: ['none']
#
# Utterance:  |  | I want to find an expensive restaurant and serve european food . can I also have the address , phone number and its area . ? | Restaurant-Inform = pricerange : expensive , food : european ; Restaurant-Request = address : ? , area : ? , phone : ? | restaurant
# Act Type: ['restaurant-address', 'restaurant-area', 'restaurant-availability', 'restaurant-food', 'restaurant-name', 'restaurant-phone']
#
# Utterance:  |  | where be a good place to eat crossover food in Cambridge ? | Restaurant-Inform = food : crossover | restaurant
# Act Type: ['restaurant-availability', 'restaurant-food']
#
# Utterance: where be a good place to eat crossover food in Cambridge ? | Restaurant-Inform = food : crossover | how about british restaurant in the Centre instead ? | Restaurant-Inform = food : british , area : centre | restaurant
# Act Type: ['restaurant-area', 'restaurant-availability', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: how about british restaurant in the Centre instead ? | Restaurant-Inform = food : british , area : centre | I would prefer the british food . |  | restaurant
# Act Type: ['restaurant-availability', 'restaurant-name', 'restaurant-pricerange']
#
# Utterance: I would prefer the british food . |  | yes please make a booking for 8 people at 12:30 on friday . | Restaurant-Inform = bookpeople : 8 , booktime : 12:30 , bookday : friday | restaurant
# Act Type: ['none']
#
# Utterance:  |  | I want a restaurant in the north of Cambridge that be within a moderate price range . | Restaurant-Inform = area : north , pricerange : moderate | restaurant
# Act Type: ['restaurant-availability', 'restaurant-food']
#
# Utterance: I want a restaurant in the north of Cambridge that be within a moderate price range . | Restaurant-Inform = area : north , pricerange : moderate | please book a table for 4 at the chinese place at 12:30 on Sunday and give I the reference number . | Restaurant-Inform = bookpeople : 4 , food : chinese , booktime : 12:30 , bookday : sunday ; Restaurant-Request = ref : ? | restaurant
# Act Type: ['none']
#
# Utterance: please book one . |  | just one , thank you ! please provide I with a reference number . | Restaurant-Request = ref : ? | restaurant
# Act Type: ['none']
#
# Utterance: I would like one train ticket please . |  | yes I be look for a moderate price place to eat in the east . phone # , postcode and food type please | Restaurant-Inform = pricerange : moderate , area : east ; Restaurant-Request = food : ? , phone : ? , postcode : ? | restaurant
# Act Type: ['restaurant-availability', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: yes I be look for a moderate price place to eat in the east . phone # , postcode and food type please | Restaurant-Inform = pricerange : moderate , area : east ; Restaurant-Request = food : ? , phone : ? , postcode : ? | I would prefer italian but Indian would be good as well . I will need the phone number and postcode of the restaurant . thank ! | Restaurant-Inform = food : italian ; Restaurant-Request = phone : ? , postcode : ? | restaurant
# Act Type: ['restaurant-availability', 'restaurant-name', 'restaurant-phone', 'restaurant-postcode']
#
# Utterance:  |  | I need a place to stay that have free wifi . |  | hotel
# Act Type: ['hotel-availability', 'hotel-internet']
#
# Utterance: I need a place to stay that have free wifi . |  | could you provide detail for something in the cheap price range ? | Hotel-Inform = pricerange : cheap | hotel
# Act Type: ['hotel-availability', 'hotel-internet', 'hotel-pricerange', 'hotel-type']
#
# Utterance: could you provide detail for something in the cheap price range ? | Hotel-Inform = pricerange : cheap | no , I have no preference . just pick one . that will be fine . | Hotel-Inform = area : dontcare | hotel
# Act Type: ['hotel-address', 'hotel-availability', 'hotel-name']
#
# Utterance: no , I have no preference . just pick one . that will be fine . | Hotel-Inform = area : dontcare | Perfect . I 'll need a room for myself , for five night on tuesday . | Hotel-Inform = bookstay : 5 , bookday : tuesday | hotel
# Act Type: ['none']
#
# Utterance: actaully I will be on business so not out much but I do need a train , to cambridge leave after 21:15 |  | yes , I need a train go to cambridge leave after 21:15 on tuesday depart from broxbourne . |  | hotel
# Act Type: ['none']
#
# Utterance: hi , I be travel to Cambridge soon and be look forward to see some local tourist attraction . |  | actually , yes . we be travel into the northern part of town . |  | hotel
# Act Type: ['none']
#
# Utterance: actually , yes . we be travel into the northern part of town . |  | that sound nice but I would like to see about a guesthouse with free wifi . | Hotel-Inform = type : guesthouse | hotel
# Act Type: ['hotel-area', 'hotel-availability', 'hotel-internet', 'hotel-type']
#
# Utterance: that sound nice but I would like to see about a guesthouse with free wifi . | Hotel-Inform = type : guesthouse | no , I do n't really care about price . just something in the north that include wifi . | Hotel-Inform = area : north | hotel
# Act Type: ['hotel-area', 'hotel-availability', 'hotel-internet', 'hotel-name', 'hotel-pricerange']
#
# Utterance: no , I do n't really care about price . just something in the north that include wifi . | Hotel-Inform = area : north | Groovy ! ! let get a booking for 2 people and 2 night start sunday . | Hotel-Inform = bookstay : 2 , bookpeople : 2 , bookday : sunday | hotel
# Act Type: ['hotel-address', 'hotel-availability', 'hotel-name']
#
# Utterance:  |  | can you help I book a table at a chinese restaurant that be in the centre of town ? | Restaurant-Inform = food : chinese , area : centre | restaurant
# Act Type: ['restaurant-availability', 'restaurant-food']
#
# Utterance: can you help I book a table at a chinese restaurant that be in the centre of town ? | Restaurant-Inform = food : chinese , area : centre | I need some cheap Chop Suey , please . | Restaurant-Inform = pricerange : cheap | restaurant
# Act Type: ['restaurant-area', 'restaurant-availability', 'restaurant-food', 'restaurant-name', 'restaurant-pricerange']
#
# Utterance: I need some cheap Chop Suey , please . | Restaurant-Inform = pricerange : cheap | that sound like they 'll have some awesome Chop Suey . please book I a table for 2 on Tuesday at 12:45 . | Restaurant-Inform = bookpeople : 2 , bookday : tuesday , booktime : 12:45 | restaurant
# Act Type: ['none']
#
# Utterance: that sound like they 'll have some awesome Chop Suey . please book I a table for 2 on Tuesday at 12:45 . | Restaurant-Inform = bookpeople : 2 , bookday : tuesday , booktime : 12:45 | can we try the same day for 11:45 please ? and can I have the reference number as well , thank . | Restaurant-Inform = booktime : 11:45 ; Restaurant-Request = ref : ? | restaurant
# Act Type: ['none']
#
# Utterance: I be look for some type of entertainment in the same area as the restaurant , please . |  | no , just an entertainment attraction in the same area as the restaurant . can you make a suggestion ? |  | restaurant
# Act Type: ['none']
#
# Utterance:  |  | I be look for a restaurant that be in the expensive price range and in the south part of town . | Restaurant-Inform = pricerange : expensive , area : south | restaurant
# Act Type: ['restaurant-availability', 'restaurant-food']
#
# Utterance: I be look for a restaurant that be in the expensive price range and in the south part of town . | Restaurant-Inform = pricerange : expensive , area : south | let we go with italian food . | Restaurant-Inform = food : italian ; Restaurant-Request = food : ? | restaurant
# Act Type: ['restaurant-area', 'restaurant-availability', 'restaurant-food', 'restaurant-name', 'restaurant-pricerange']
#
# Utterance: let we go with italian food . | Restaurant-Inform = food : italian ; Restaurant-Request = food : ? | address and phone number | Restaurant-Request = address : ? , phone : ? | restaurant
# Act Type: ['restaurant-address', 'restaurant-availability', 'restaurant-phone']
#
# Utterance:  |  | can you help I find an expensive chinese food restaurant ? | Restaurant-Inform = pricerange : expensive , food : chinese | restaurant
# Act Type: ['restaurant-availability']
#
# Utterance: can you help I find an expensive chinese food restaurant ? | Restaurant-Inform = pricerange : expensive , food : chinese | I be interested in restaurant locate in the East . | Restaurant-Inform = area : east | restaurant , hotel
# Act Type: ['restaurant-availability', 'restaurant-name']
#
# Utterance: I be interested in restaurant locate in the East . | Restaurant-Inform = area : east | yeah , could you book it for 8 people on Monday ? I think 16:15 be when we want to be seat . | Restaurant-Inform = bookpeople : 8 , bookday : monday , booktime : 16:15 | restaurant
# Act Type: ['none']
#
# Utterance: yeah , could you book it for 8 people on Monday ? I think 16:15 be when we want to be seat . | Restaurant-Inform = bookpeople : 8 , bookday : monday , booktime : 16:15 | thank ! I be also look for a hotel near that restaurant . | Hotel-Inform = type : hotel | hotel
# Act Type: ['hotel-availability', 'hotel-name']
#
# Utterance: thank ! I be also look for a hotel near that restaurant . | Hotel-Inform = type : hotel | if that have free wifi that 'll work . |  | hotel
# Act Type: ['hotel-availability', 'hotel-internet']
#
# Utterance: if that have free wifi that 'll work . |  | could you tell I the price , address and phone number ? | Hotel-Request = address : ? , phone : ? , pricerange : ? | hotel
# Act Type: ['hotel-address', 'hotel-availability', 'hotel-phone', 'hotel-pricerange']
#
# Utterance:  |  | I be plan a vacation and really could use some help find a good place to stay in town . I have never be to Cambridge before . |  | hotel
# Act Type: ['none']
#
# Utterance: I be plan a vacation and really could use some help find a good place to stay in town . I have never be to Cambridge before . |  | it do n't matter . what do you recommend ? | Hotel-Inform = area : dontcare | hotel
# Act Type: ['hotel-area', 'hotel-availability', 'hotel-name', 'hotel-type']
#
# Utterance: it do n't matter . what do you recommend ? | Hotel-Inform = area : dontcare | oh , ok . I really do n't want to stay at a guesthouse though . can you recommend a hotel instead ? | Hotel-Inform = type : hotel | hotel
# Act Type: ['hotel-availability', 'hotel-name']
#
# Utterance: oh , ok . I really do n't want to stay at a guesthouse though . can you recommend a hotel instead ? | Hotel-Inform = type : hotel | sound good . can you get I a room for 2 for 5 night start Sunday ? | Hotel-Inform = bookpeople : 2 , bookstay : 5 , bookday : sunday | hotel
# Act Type: ['none']
#
# Utterance: what be the train schedule from birmingham new street like ? I need to arrive at 13:45 . |  | I need the travel day to be Sunday . I 'll be go to Cambridge and arrive by 13:45 . I 'll be leave from Birmingham New street . |  | hotel
# Act Type: ['none']
#
# Utterance:  |  | I be look to go to dinner tonight and be in the mood for some good Bistro in the centre of town , can you find I some option ? | Restaurant-Inform = food : bistro , area : centre | restaurant
# Act Type: ['none']
#
# Utterance: I be look to go to dinner tonight and be in the mood for some good Bistro in the centre of town , can you find I some option ? | Restaurant-Inform = food : bistro , area : centre | hmm ... let I think . let we try maybe something italian instead . | Restaurant-Inform = food : italian | restaurant
# Act Type: ['restaurant-area', 'restaurant-availability', 'restaurant-food']
#
# Utterance: hmm ... let I think . let we try maybe something italian instead . | Restaurant-Inform = food : italian | which of those nine have the good rating ? can I please have the address and postcode . | Restaurant-Request = address : ? , postcode : ? | restaurant
# Act Type: ['restaurant-address', 'restaurant-availability', 'restaurant-name', 'restaurant-postcode']
#
# Utterance:  |  | I be look for a particular restaurant . its name be call traveller rest | Restaurant-Inform = name : travellers rest | restaurant
# Act Type: ['restaurant-area', 'restaurant-availability', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: I be look for a particular restaurant . its name be call traveller rest | Restaurant-Inform = name : travellers rest | yes , and can you book a table for 1 at 14:15 on Monday , please . | Restaurant-Inform = bookpeople : 1 , booktime : 14:15 , bookday : monday | restaurant
# Act Type: ['none']
#
# Utterance:  |  | Heya , can you find I an expensive restaurant with north african food ? | Restaurant-Inform = pricerange : expensive , food : african | restaurant
# Act Type: ['restaurant-availability', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: Heya , can you find I an expensive restaurant with north african food ? | Restaurant-Inform = pricerange : expensive , food : african | be there any expensive restaurant with gastropub food ? | Restaurant-Inform = pricerange : expensive , food : gastropub | restaurant
# Act Type: ['restaurant-area', 'restaurant-availability']
#
# Utterance: be there any expensive restaurant with gastropub food ? | Restaurant-Inform = pricerange : expensive , food : gastropub | yes , the one in the east please . | Restaurant-Inform = area : east | restaurant
# Act Type: ['restaurant-availability', 'restaurant-name']
#
# Utterance: yes , the one in the east please . | Restaurant-Inform = area : east | yes , please book it for 2 people at 13:45 on monday . | Restaurant-Inform = bookpeople : 2 , booktime : 13:45 , bookday : monday | restaurant
# Act Type: ['none']
#
# Utterance:  |  | I be plan a trip to Cambridge and I be tell the A and B Guest House be a great place to stay . can you give I information about it ? | Hotel-Inform = name : a and b guest house | hotel
# Act Type: ['hotel-area', 'hotel-availability', 'hotel-internet', 'hotel-pricerange', 'hotel-stars', 'hotel-type']
#
# Utterance: I be plan a trip to Cambridge and I be tell the A and B Guest House be a great place to stay . can you give I information about it ? | Hotel-Inform = name : a and b guest house | do you have free parking ? I refuse to pay for parking in a hotel that I be stay at . would n't you agree ? | Hotel-Request = parking : ? | hotel
# Act Type: ['hotel-availability', 'hotel-parking']
#
# Utterance: okay , sound good . also I need to get a train from Liverpool street to Cambridge . |  | oh wait , you know what ? I forgot to ask about star rating . what be the star rating on the A and B Guest House , please ? |  | hotel
# Act Type: ['hotel-availability', 'hotel-stars']
#
# Utterance: I would like to book that train for 4 people please . |  | yeah , I be also look for a place to stay . I do n't like hotel , so a guesthouse would be well . moderate in price . | Hotel-Inform = type : guesthouse , pricerange : moderate | hotel
# Act Type: ['hotel-availability', 'hotel-pricerange', 'hotel-type']
#
# Utterance: yeah , I be also look for a place to stay . I do n't like hotel , so a guesthouse would be well . moderate in price . | Hotel-Inform = type : guesthouse , pricerange : moderate | yes , the hotel should be in the east and do n't need to have free parking . | Hotel-Inform = area : east | hotel
# Act Type: ['hotel-area', 'hotel-availability', 'hotel-name', 'hotel-pricerange']
#
# Utterance: yes , the hotel should be in the east and do n't need to have free parking . | Hotel-Inform = area : east | can I have the star rating and idf they have wi fi ? | Hotel-Request = internet : ? | hotel
# Act Type: ['hotel-availability', 'hotel-internet', 'hotel-stars']
#
# Utterance:  |  | I be look for a restaurant . |  | restaurant
# Act Type: ['none']
#
# Utterance: I be look for a restaurant . |  | not sure of that , I be look for a restaurant name " ask . " | Restaurant-Inform = name : ask | restaurant
# Act Type: ['restaurant-address', 'restaurant-area', 'restaurant-availability', 'restaurant-food']
#
# Utterance: not sure of that , I be look for a restaurant name " ask . " | Restaurant-Inform = name : ask | I would like to book a table for 5 people on Sunday at 14:15 | Restaurant-Inform = bookpeople : 5 , bookday : sunday , booktime : 14:15 | restaurant
# Act Type: ['none']
#
# Utterance: I would like to book a table for 5 people on Sunday at 14:15 | Restaurant-Inform = bookpeople : 5 , bookday : sunday , booktime : 14:15 | yes , a different restaurant in the same area and with the same price range . | Restaurant-Inform = area : centre | restaurant
# Act Type: ['restaurant-availability', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: yes , a different restaurant in the same area and with the same price range . | Restaurant-Inform = area : centre | type of food do n't matter . which be the good one ? I 'll book that . | Restaurant-Inform = food : dontcare | restaurant
# Act Type: ['none']
#
# Utterance:  |  | I be look for a high price hotel in the north side of town | Hotel-Inform = area : north | hotel
# Act Type: ['none']

# %%
none_labels_length = len([label for label in train_labels if label == ['none']])
print("None labels length:", none_labels_length)
print("Total labels length:", len(train_labels))
# Out:
# None labels length: 11858
# Total labels length: 28226

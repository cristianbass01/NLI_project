# %%
#Mount Google drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#change current working directory
#%cd "/content/drive/Shareddrives/NLI"

# %%
#!pip install transformers
#!pip install accelerate
#!pip install datasets
#!python3 -m spacy download en_core_web_lg

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import torch
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, Dataset
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import recall_score, precision_score, f1_score
from torch import cuda
import re
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from seqeval.metrics import classification_report
from itertools import product
import os
import joblib
import json
import math
import nltk
from datasets import load_dataset
from datasets import DatasetDict

nltk.download('punkt')

import spacy

nlp = spacy.load("en_core_web_lg")
# Out:
# [nltk_data] Downloading package punkt to /home/mister/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /home/mister/miniconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
DATASET_DIRECTORY = "./../dataset.hf/"
TRAIN_DATA_SAVE_PATH = "preprocessed_data_to_be_requested/train.json"
TEST_DATA_SAVE_PATH = "preprocessed_data_to_be_requested/test.json"
VALID_DATA_SAVE_PATH = "preprocessed_data_to_be_requested/valid.json"

ALWAYS_LOAD_DATASET = False
SAVE_DATASET = True

# %%
import json

def save_variable_to_json(variable, file_path):
    with open(file_path, 'w') as file:
        json.dump(variable, file)

def load_variable_from_json(file_path):
    with open(file_path, 'r') as file:
        variable = json.load(file)
    return variable

# %%
# Extracting only hotel and restaurant features from the dataset
def preprocess_split(dataset, split):
    df = dataset[split].to_pandas()
    new_df = pd.DataFrame(columns = df.columns)
    for i in range(len(df)):
        # Taken from notebook, to know which lines to skip
        row = df.loc[i]
        if not any(set(row.turns['frames'][turn_id]['service']).intersection(['hotel', 'restaurant']) for turn_id,utt in enumerate(row.turns['utterance'])):
            continue

        new_df.loc[len(new_df)] = row
    return new_df

# %%
def process_service_list(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service == 'restaurant':
            services.add('restaurant')
        elif service == 'hotel':
            services.add('hotel')
        else:
            services.add('other')
        if len(services) == 3:
            break
    return list(services)

def process_dialogue_act(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service.startswith('Restaurant') or service.startswith('restaurant'):
            services.add(service)
        elif service.startswith('Hotel') or service.startswith('hotel'):
            services.add(service)
        elif service.startswith('general') or service.startswith('General'):
            services.add(service)
        elif service.startswith('Booking') or service.startswith('booking'):
            services.add(service)
        else:
            services.add('other')
    return list(services)

# %%
def parse(sentence):
    # Tokenize
    sentence = nlp(sentence)
    # Remove stop words
    sentence = " ".join([token.lemma_ for token in sentence])
    
    return sentence

# %%
def get_act_type_to_slots(dialogue_act):
    act_type_to_slots = {}

    # All the slots that are present in the current user utterance
    span_info = dialogue_act['span_info']
    act_types = span_info['act_type']
    act_slot_names = span_info['act_slot_name']
    act_slot_values = span_info['act_slot_value']

    for slot_name, act_type, slot_value in zip(act_slot_names, act_types , act_slot_values):
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            if not act_type in act_type_to_slots:
                act_type_to_slots[act_type] = []
            act_type_to_slots[act_type].append(tuple([slot_name, slot_value]))

    # All the slots that are not present in the current user utterance (slots with '?')
    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    for act_type, act_slot in zip(act_types, act_slots):
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                if slot_name != "none" and  slot_value == "?":
                    if not act_type in act_type_to_slots:
                        act_type_to_slots[act_type] = []
                    act_type_to_slots[act_type].append(tuple([slot_name, slot_value]))
    return act_type_to_slots

# %%
def get_to_be_provided_overall(dialogue_act, current_booking_service):
    
    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    to_be_provided_overall = []
    for act_type, act_slot in zip(act_types, act_slots):
        # If the domain is booking, we need to know which service is being booked
        
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel') or act_type.startswith('Booking') or act_type.startswith('general'):
            domain = act_type.split("-")[0]
            if domain == "booking" and len(current_booking_service)==1:
                domain = current_booking_service[0]
            domain = domain.lower()

            if domain in ["hotel", "restaurant", "booking", "general"]:
                # Retrieve the slots that are in the form of "something : ?"
                slots = []
                for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                    if slot_name != "none" and  slot_value != "?":
                        slots.append(domain + "-" + slot_name + ":" + slot_value)
            
                if slots and any((slot_name_value.split(":")[0] != domain + "-none" for slot_name_value in slots)) and not "-No" in dialogue_act:
                    to_be_provided = ["%s-availability:yes" % (domain)] + slots
                    to_be_provided_overall.extend(to_be_provided)
                elif "-No" in dialogue_act:
                    to_be_provided = ["%s-availability:no" % (domain)] + slots
                    to_be_provided_overall.extend(to_be_provided)
            
    to_be_provided_overall = sorted(list(set(to_be_provided_overall)))
    remove_avail_no_list = [elem for elem in to_be_provided_overall if elem.endswith("availability:no")]
    for remove_avail in remove_avail_no_list:
        remove_avail_yes = remove_avail[:-2]+"yes"
        while remove_avail_yes in to_be_provided_overall:
            del to_be_provided_overall[to_be_provided_overall.index(remove_avail_yes)]

    return sorted(to_be_provided_overall)

# %%
def get_to_be_requested(dialogue_act, current_booking_service):

    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    to_be_requested = []
    for act_type, act_slot in zip(act_types, act_slots):
        # If the domain is booking, we need to know which service is being booked
        
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel') or act_type.startswith('Booking') or act_type.startswith('general'):
            domain = act_type.split("-")[0].lower()
            if domain == "booking" and len(current_booking_service)==1:
                domain = current_booking_service[0]
            domain = domain.lower()
        
            if domain in ["hotel", "restaurant", "booking", "general"]:
                
                slots = []
                for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                    if slot_name != "none" and  slot_value == "?":
                        slots.append(domain + "-" + slot_name)
                
                to_be_requested.extend(slots)
    to_be_requested = sorted(list(set(to_be_requested)))
    return to_be_requested

# %%
def concatenate_to_be_retrieved(user_utterance, user_act_type_to_slots):
    
    historical_utterance = user_utterance + " | "
    for act_type in user_act_type_to_slots:
        historical_utterance += act_type + " = "
        for slot_name, slot_value in user_act_type_to_slots[act_type]:
            historical_utterance += slot_name + " : " + slot_value + " , "
        
        if len(user_act_type_to_slots[act_type]) > 0:
            # Remove last comma
            historical_utterance = historical_utterance[:-3]

        historical_utterance += " ; "

    if len(user_act_type_to_slots) > 0:
        # Remove last semicolon
        historical_utterance = historical_utterance[:-3]

    return historical_utterance

# %%
def extract_to_be_requested(dataset):
    target_list = []
    training_list = []

    for i in tqdm(range(len(dataset))):
        turns = dataset.loc[i].turns

        speaker_str = {'User': 0, 'Agent': 1}
        historical_slots = []

        for j, (utterance, speaker, dialogue_act) in enumerate(zip(turns['utterance'], turns['speaker'], turns['dialogue_acts'])):
            if speaker == speaker_str['Agent']:
                
                if j == 1:
                    prev_agent_utterance = ''
                    prev_agent_acts_to_slot = {}
                else:
                    # Retrieve the previous user utterance and acts
                    prev_agent_utterance = turns['utterance'][j - 2]
                    prev_agent_utterance = parse(prev_agent_utterance) # Preprocess the utterance
                    prev_agent_acts_to_slot = get_act_type_to_slots(turns['dialogue_acts'][j - 2])


                prev_user = j - 1
                # The dataset is very unbalanced, so I will remove the labels that does not have also our domain
                current_act_type = dialogue_act['dialog_act']['act_type']
                current_act_type = process_dialogue_act(current_act_type)
                current_act_type = [act_type for act_type in current_act_type if act_type.endswith('Request')]
                
                services = turns['frames'][prev_user]['service']
                user_booking_service = [service for service in services if service in ["hotel", "restaurant"]]
                if len(user_booking_service) == 0:
                    continue

                # The user start, so there will always be j-1 turns before
                prev_user = j - 1

                # Retrieve the previous user stuff
                user_dialogue_act = turns['dialogue_acts'][prev_user]
                user_act_type_to_slots = get_act_type_to_slots(user_dialogue_act)
                user_utterance = parse(turns['utterance'][prev_user])
                
                for user_act in user_act_type_to_slots.keys():
                    domain = user_act.split("-")[0]
                    for slot_name, slot_value in user_act_type_to_slots[user_act]:
                        if slot_value != "?":
                            historical_slots.append(domain + "-" + slot_name)
                historical_slots = sorted(set(historical_slots))

                if len(current_act_type) == 0:
                    continue

                to_be_provided = get_to_be_provided_overall(dialogue_act, user_booking_service)
                
                # HISTORY = 2
                # - Previous user utterance
                # - Previous user acts
                # - Previous slots (also slots with '?')
                # - to be provided overall
                # Structure: user_utterance | user_act = slot_name : slot_value , slot_name : slot_value
                #           user_booking_service |
                #           historical slots |
                #           to_be_provided_overall


                historical_utterance = concatenate_to_be_retrieved(prev_agent_utterance, prev_agent_acts_to_slot) + " | "
                historical_utterance += concatenate_to_be_retrieved(user_utterance, user_act_type_to_slots)
                historical_utterance += " | "
                historical_utterance += " , ".join(user_booking_service)
                historical_utterance += " | "
                historical_utterance += " , ".join(historical_slots)
                historical_utterance += " | "
                historical_utterance += " , ".join(to_be_provided)

                # Target
                targets = get_to_be_requested(dialogue_act, user_booking_service)
                
                # If there is no request why should be a question?
                if(len(targets) == 0):
                    targets.append('none')
                training_list.append(historical_utterance)
                target_list.append(targets)
            else:
                prev_agent = j - 1
                if prev_agent >= 0:
                    dialogue_act = turns['dialogue_acts'][prev_agent]

                    act_type_to_slots = get_act_type_to_slots(dialogue_act)

                    for act in act_type_to_slots.keys():
                        domain = act.split("-")[0]
                        for slot_name, slot_value in act_type_to_slots[act]:
                            if slot_value != "?":
                                historical_slots.append(domain + "-" + slot_name)
                    historical_slots = sorted(set(historical_slots))
                    
    return training_list, target_list

# %%
try:
    print('Loading from json...')
    train_utterances, train_labels = load_variable_from_json(TRAIN_DATA_SAVE_PATH)
    test_utterances, test_labels = load_variable_from_json(TEST_DATA_SAVE_PATH)
    valid_utterances, valid_labels = load_variable_from_json(VALID_DATA_SAVE_PATH)
    print('Loaded from json')
except:
    print('Exception occured during loading from json')
    print('Loading dataset...')

    try:
        if ALWAYS_LOAD_DATASET:
            raise Exception('Load data always')
        # Run it only once
        dataset = DatasetDict.load_from_disk(DATASET_DIRECTORY)
        
    except:
        # Run it only once
        dataset = load_dataset("multi_woz_v22")

        if SAVE_DATASET:
            # Run it only once
            dataset.save_to_disk(DATASET_DIRECTORY)

    print('Preprocessing...')
    train = preprocess_split(dataset, 'train')
    val = preprocess_split(dataset, 'validation')
    test = preprocess_split(dataset, 'test')

    print('Extracting utterances and act types...')
    train_utterances, train_labels = extract_to_be_requested(train)
    test_utterances, test_labels = extract_to_be_requested(test)
    valid_utterances, valid_labels = extract_to_be_requested(val)

    print('Saving to json...')
    save_variable_to_json([train_utterances,train_labels] , TRAIN_DATA_SAVE_PATH)
    save_variable_to_json([test_utterances,test_labels], TEST_DATA_SAVE_PATH)
    save_variable_to_json([valid_utterances,valid_labels], VALID_DATA_SAVE_PATH)

    print('Saved to json')
# Out:
# Loading from json...
# Exception occured during loading from json
# Loading dataset...
# Preprocessing...
# Extracting utterances and act types...
# 100%|██████████| 6321/6321 [07:40<00:00, 13.73it/s]
# 100%|██████████| 745/745 [00:55<00:00, 13.38it/s]
# 100%|██████████| 762/762 [00:57<00:00, 13.28it/s]
# Saving to json...
# Saved to json

# %%
none_count = train_labels.count(['none'])
train_labels.index(['none'])
print(train_utterances[train_labels.index(['none'])]  )
print("Number of 'none' labels:", none_count)
print("Total number of labels:", len(train_labels))
# Out:
# sure , it be cb23bu . be there anything else I can help you with today ? |  | I be also look for a place to stay that have 4 star and in the centre of town . | Hotel-Inform = stars : 4 , area : centre | hotel | Hotel-area , Hotel-stars | hotel-availability:yes , hotel-name:Alexander B&B , hotel-name:University Arms Hotel] , hotel-pricerange:?]
# Number of 'none' labels: 4
# Total number of labels: 7188

# %%
for utterance, act_type in zip(train_utterances[:100], train_labels[:100]):
    print("Utterance:", utterance)
    print("Act Type:", act_type)
    print()
# Out:
# Utterance: Bedouin 's phone be 01223367660 . as far as hotel go , I recommend the University Arms Hotel in the center of town . | Restaurant-Inform = name : Bedouin , phone : 01223367660 ; Hotel-Recommend = name : the University Arms Hotel , area : center of town | yes . can you book it for I ? |  | hotel | Hotel-area , Hotel-name , Hotel-pricerange , Hotel-type , Restaurant-area , Restaurant-choice , Restaurant-food , Restaurant-name , Restaurant-phone , Restaurant-pricerange |
# Act Type: ['hotel-bookday']
#
# Utterance: I have 4 different option for you . I have two cheap guesthouse and two expensive hotel . do you have a preference ? | Hotel-Inform = choice : 4 , pricerange : cheaper , type : guesthouses , pricerange : expensive , type : hotels | no , but I would really like to be on the south end of the city . do any of those fit the bill ? | Hotel-Inform = area : south | hotel , restaurant | Hotel-area , Hotel-choice , Hotel-pricerange , Hotel-type |
# Act Type: ['hotel-pricerange', 'restaurant-pricerange']
#
# Utterance: I would recommend aylesbray lodge guest house . would you like I to book that for you ? | Hotel-Inform = name : aylesbray lodge guest house | yes , book it for 4 people and 4 night start from tuesday . | Hotel-Inform = bookstay : 4 , bookpeople : 4 , bookday : tuesday | hotel | Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-type , Restaurant-pricerange |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance: Cityroomz be locate at Sleeperz Hotel , Station Road in the Centre area . it be a moderatley price hotel with a 0 star rating . would you like to book a room ? | Hotel-Inform = name : Cityroomz , address : Sleeperz Hotel, Station Road , area : Centre , pricerange : moderatley priced , stars : 0 | yes please . I need it for 7 people for 3 night start on tuesday . | Hotel-Inform = bookpeople : 7 , bookstay : 3 , bookday : tuesday | hotel | Hotel-address , Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-name , Hotel-pricerange , Hotel-stars |
# Act Type: ['hotel-bookstay']
#
# Utterance: ok , your room have be book . your reference number be CYJDAR7R . be there anything else I can help you with today ? |  | yeah , I need a restaurant in the west and with expensive pricing . | Restaurant-Inform = area : west , pricerange : expensive | restaurant | Hotel-address , Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-name , Hotel-pricerange , Hotel-stars , Restaurant-area , Restaurant-pricerange | restaurant-area:west , restaurant-availability:yes , restaurant-choice:9 , restaurant-pricerange:expensive
# Act Type: ['restaurant-food']
#
# Utterance: I have their info , what would you like to know ? |  | I would like to book a reservation for it . can you help I with that ? |  | hotel | Hotel-name |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: I sure can . first , I will need to know when you want your stay to begin and how many day you will be stay . also , how many people will be stay ? |  | we will be arrive on Sunday and will stay for 5 night . | Hotel-Inform = bookday : sunday , bookstay : 5 | hotel | Hotel-bookday , Hotel-bookstay , Hotel-name |
# Act Type: ['hotel-bookpeople']
#
# Utterance: you have a nice day then ! |  | can you actually look up a restaurant for I as well ? |  | restaurant | Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-name |
# Act Type: ['restaurant-area', 'restaurant-name']
#
# Utterance: unfortunately , I can not book it at this time . |  | can you try for Saturday at 13:00 ? | Restaurant-Inform = bookday : saturday , booktime : 13:00 | restaurant | Restaurant-address , Restaurant-area , Restaurant-bookday , Restaurant-booktime , Restaurant-food , Restaurant-name , Restaurant-postcode |
# Act Type: ['restaurant-bookpeople']
#
# Utterance:  |  | I be look for an expensive restaurant in the centre if you could help I . | Restaurant-Inform = pricerange : expensive , area : centre | restaurant | Restaurant-area , Restaurant-pricerange | restaurant-availability:yes , restaurant-choice:lots
# Act Type: ['restaurant-food']
#
# Utterance:  |  | I be look for a place to go and see during my upcoming trip to Cambridge . |  | hotel |  |
# Act Type: ['hotel-area']
#
# Utterance:  |  | I need a place to stay that have free wifi . |  | hotel |  | hotel-availability:yes , hotel-choice:32 , hotel-internet:yes
# Act Type: ['hotel-pricerange']
#
# Utterance: I have 32 place that offer wifi , do you have a price range preference ? | Hotel-Inform = choice : 32 ; Hotel-Request = pricerange : ? | could you provide detail for something in the cheap price range ? | Hotel-Inform = pricerange : cheap | hotel | Hotel-choice , Hotel-pricerange | hotel-availability:yes , hotel-choice:33 , hotel-internet:yes , hotel-pricerange:cheap , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance: if you be head north , I recommend take a ride on the Riverboat Georgina . |  | that sound nice but I would like to see about a guesthouse with free wifi . | Hotel-Inform = type : guesthouse | hotel | Hotel-type | hotel-area:north , hotel-availability:yes , hotel-choice:10 , hotel-internet:yes , hotel-type:guest houses
# Act Type: ['hotel-pricerange']
#
# Utterance:  |  | can you help I book a table at a chinese restaurant that be in the centre of town ? | Restaurant-Inform = food : chinese , area : centre | restaurant | Restaurant-area , Restaurant-food | restaurant-availability:yes , restaurant-choice:10 , restaurant-food:Chinese
# Act Type: ['restaurant-pricerange']
#
# Utterance: how do the Charlie Chan sound ? it be a cheap chinese restaurant in the centre . | Restaurant-Recommend = name : Charlie Chan , pricerange : cheap , food : Chinese , area : centre | that sound like they will have some awesome Chop Suey . please book I a table for 2 on Tuesday at 12:45 . | Restaurant-Inform = bookpeople : 2 , bookday : tuesday , booktime : 12:45 | restaurant | Restaurant-area , Restaurant-bookday , Restaurant-bookpeople , Restaurant-booktime , Restaurant-choice , Restaurant-food , Restaurant-name , Restaurant-pricerange |
# Act Type: ['restaurant-bookday', 'restaurant-booktime']
#
# Utterance:  |  | can you help I find an expensive chinese food restaurant ? | Restaurant-Inform = pricerange : expensive , food : chinese | restaurant | Restaurant-food , Restaurant-pricerange | restaurant-availability:yes , restaurant-choice:nine
# Act Type: ['restaurant-area']
#
# Utterance:  |  | I be plan a vacation and really could use some help find a good place to stay in town . I have never be to Cambridge before . |  | hotel |  |
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance:  |  | I be look to go to dinner tonight and be in the mood for some good Bistro in the centre of town , can you find I some option ? | Restaurant-Inform = food : bistro , area : centre | restaurant | Restaurant-area , Restaurant-food |
# Act Type: ['restaurant-area', 'restaurant-food']
#
# Utterance: 7g6oj8g2 be your confirmation code . may I help you far ? |  | yeah , I be also look for a place to stay . I do not like hotel , so a guesthouse would be well . moderate in price . | Hotel-Inform = type : guesthouse , pricerange : moderate | hotel | Hotel-pricerange , Hotel-type | hotel-availability:yes , hotel-choice:several , hotel-pricerange:moderate priced , hotel-type:guesthouses
# Act Type: ['hotel-area']
#
# Utterance:  |  | I be look for a restaurant . |  | restaurant |  |
# Act Type: ['restaurant-food', 'restaurant-pricerange']
#
# Utterance:  |  | I be look for a high price hotel in the north side of town | Hotel-Inform = area : north | hotel | Hotel-area |
# Act Type: ['hotel-area']
#
# Utterance: I have 2 available hotel . one be the Gonville Hotel locate on Gonville Place . the other be University Arms Hotel on Regent Street . which one would you like to book ? | Hotel-Inform = choice : 2 , type : hotels , name : Gonville Hotel , address : Gonville Place , name : University Arms Hotel , address : Regent Street | can you book the one without wifi ? | Hotel-Inform = bookpeople : 1 , bookstay : 1 | hotel | Hotel-address , Hotel-area , Hotel-bookpeople , Hotel-bookstay , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-type | hotel-availability:yes , hotel-internet:yes
# Act Type: ['hotel-bookday', 'hotel-bookpeople']
#
# Utterance: your very welcome . can I help you with anything else today ? |  | yes a hotel please . | Hotel-Inform = type : hotel | hotel | Hotel-type , Restaurant-address , Restaurant-area , Restaurant-bookday , Restaurant-bookpeople , Restaurant-booktime , Restaurant-food , Restaurant-name , Restaurant-pricerange |
# Act Type: ['hotel-area', 'hotel-pricerange', 'hotel-type']
#
# Utterance:  |  | hey , I be up south can you give I a place to eat ? | Restaurant-Inform = area : south | restaurant | Restaurant-area |
# Act Type: ['restaurant-food']
#
# Utterance: what about a and b guest house ? it be in the East . | Hotel-Recommend = name : a and b guest house ; Hotel-Inform = area : East | I need something in the centre . | Hotel-Inform = area : centre | hotel | Hotel-area , Hotel-name , Hotel-type | hotel-availability:yes , hotel-choice:7 , hotel-type:hotels
# Act Type: ['hotel-area']
#
# Utterance: there be 7 hotel which area do you prefer ? | Hotel-Inform = choice : 7 , type : hotels ; Hotel-Request = area : ? | the north part of town | Hotel-Inform = area : north | hotel | Hotel-area , Hotel-choice , Hotel-name , Hotel-type | hotel-area:north , hotel-availability:yes , hotel-choice:12 , hotel-type:Guesthouse , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance: booking be successful . reference number be : qk6kczqa |  | great , thank you . I be also in need of an indian restaurant in the cheap price range . can you find I one ? | Restaurant-Inform = food : indian , pricerange : cheap | restaurant | Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type , Restaurant-food , Restaurant-pricerange | restaurant-availability:yes , restaurant-choice:several
# Act Type: ['restaurant-area']
#
# Utterance: I would suggest midsummer house restaurant it have great food . | Restaurant-Recommend = name : midsummer house restaurant | can you make I a reservation for Saturday please for 3 people ? | Restaurant-Inform = bookday : saturday , bookpeople : 3 | restaurant | Restaurant-area , Restaurant-bookday , Restaurant-bookpeople , Restaurant-choice , Restaurant-food , Restaurant-name , Restaurant-pricerange | booking-availability:yes , booking-bookday:Saturday
# Act Type: ['restaurant-booktime']
#
# Utterance: I have get two expensive hotel in the area . both have internet and parking . university arm hotel have 4 star . do that meet your need ? | Hotel-Inform = choice : two , pricerange : expensive , type : hotels , name : university arms hotel | yes , that should be perfect thank you . |  | hotel | Hotel-area , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-type , Restaurant-area , Restaurant-bookday , Restaurant-bookpeople , Restaurant-booktime , Restaurant-choice , Restaurant-food , Restaurant-name , Restaurant-pricerange |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: how about the Alexander bed and breakfast in the centre ? it be a cheap 4 star guesthouse with free internet and wifi . | Hotel-Select = name : Alexander bed and breakfast , area : centre ; Hotel-Inform = pricerange : cheap , stars : 4 , type : guesthouse | that sound like it might work . could you check availability for two people this weekend ? | Hotel-Inform = bookpeople : 2 | hotel | Hotel-area , Hotel-bookpeople , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance:  |  | I be look for information in Cambridge . I need a place to dine . |  | restaurant |  |
# Act Type: ['restaurant-food']
#
# Utterance: unfortunately , there be not any crossover restaurant in Cambridge . be there something else you would like to try ? | Restaurant-NoOffer = food : crossover , area : in Cambridge | be there a gastropub in Centre ? | Restaurant-Inform = food : gastropub , area : centre | restaurant | Restaurant-area , Restaurant-food | restaurant-availability:yes , restaurant-choice:one , restaurant-choice:two , restaurant-pricerange:expensive , restaurant-pricerange:moderately priced
# Act Type: ['restaurant-pricerange']
#
# Utterance: yes , they do have free parking and they have 4 star . | Hotel-Inform = stars : 4 | do you have something that fit with 3 star ? | Hotel-Inform = stars : 3 | hotel | Hotel-pricerange , Hotel-stars , Hotel-type | hotel-availability:yes , hotel-stars:3 , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance:  |  | I be look for a 4 star place to stay . | Hotel-Inform = stars : 4 | hotel | Hotel-stars |
# Act Type: ['hotel-area']
#
# Utterance:  |  | I be look for a place to eat . I would like it to be an expensive restaurant in the centre . | Restaurant-Inform = pricerange : expensive , area : centre | restaurant | Restaurant-area , Restaurant-pricerange | restaurant-area:centre , restaurant-availability:yes , restaurant-choice:33 , restaurant-pricerange:expensive
# Act Type: ['restaurant-food']
#
# Utterance: I have find two restaurant . one be La mimosa , and the other be Shiraz restaurant , would you like I to book one for you ? | Restaurant-Inform = choice : two , name : La mimosa , name : Shiraz restaurant | please book the One be La mimosa | Restaurant-Inform = name : la mimosa | restaurant | Restaurant-area , Restaurant-choice , Restaurant-food , Restaurant-name , Restaurant-pricerange |
# Act Type: ['restaurant-bookday', 'restaurant-bookpeople', 'restaurant-booktime']
#
# Utterance: I have book that for you . your reference number be xhrx4ig7 . |  | can you find I a expensive cafe to eat at once I get off the train ? |  | restaurant | Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type |
# Act Type: ['restaurant-food']
#
# Utterance: Archway House be a moderately price 4 star hotel in the North . would you like to make a reservation ? | Hotel-Recommend = name : Archway House , pricerange : moderately priced , stars : 4 , type : hotel , area : North | yes please book the Archway House . | Hotel-Inform = name : archway house | hotel | Hotel-area , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: ok . I have book that guesthouse for you . your reference number be YBT4JRTR . can I help with anything else ? |  | yes , I would also l like to find a splendid , moderately - price place to dine in the centre . that would be just wonderful if you could help I out with that ! | Restaurant-Inform = pricerange : moderate , area : centre | restaurant , hotel | Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type , Restaurant-area , Restaurant-pricerange | restaurant-area:centre area , restaurant-availability:yes , restaurant-choice:several , restaurant-pricerange:moderately priced
# Act Type: ['restaurant-food']
#
# Utterance:  |  | hi , I need a moderate price range restaurant in the centre of town . | Restaurant-Inform = pricerange : moderate , area : centre | restaurant | Restaurant-area , Restaurant-pricerange | restaurant-area:centre of town , restaurant-availability:yes , restaurant-choice:21 , restaurant-pricerange:moderately priced
# Act Type: ['restaurant-food']
#
# Utterance:  |  | we will be on the west side of town and would like to find a place to eat while there . | Restaurant-Inform = area : west | restaurant | Restaurant-area |
# Act Type: ['restaurant-food']
#
# Utterance: what type of cuisine would you be look for ? | Restaurant-Request = food : ? | I want some scottish food . | Restaurant-Inform = food : scottish | restaurant | Restaurant-area , Restaurant-food |
# Act Type: ['restaurant-area']
#
# Utterance: there be no restaurant in that area . |  | what a bummer . find I a restaurant that serve british food on the West please . | Restaurant-Inform = food : british , area : west | restaurant | Restaurant-area , Restaurant-food | restaurant-availability:yes , restaurant-choice:3 , restaurant-food:British
# Act Type: ['restaurant-pricerange']
#
# Utterance:  |  | I be plan a trip in Cambridge |  | hotel |  |
# Act Type: ['hotel-area']
#
# Utterance: what area in cambridge would you like to stay ? | Hotel-Request = area : ? | I be actually look to book a specific hotel . it be call the Alpha - Milton Guest House . | Hotel-Inform = name : alpha-milton guest house | hotel | Hotel-name |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: I can book you at the university arm hotel . it have a 4 star rating , free parking and wifi . do this interest you ? | Hotel-Recommend = name : university arms hotel , stars : 4 | yes . that would be great . |  | hotel | Hotel-area , Hotel-name , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance: what will be the first day you will stay and how long will you be stay ? |  | I want to stay for 5 night start on Tuesday . | Hotel-Inform = bookstay : 5 , bookday : tuesday | hotel | Hotel-area , Hotel-bookday , Hotel-bookstay , Hotel-name , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance:  |  | I be look for a hotel that include free wifi and free parking . |  | hotel |  | hotel-availability:yes , hotel-choice:lots , hotel-internet:yes , hotel-parking:yes
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance:  |  | can you help I find a place to stay that be four star and have free wifi ? | Hotel-Inform = bookstay : 4 | hotel | Hotel-bookstay | hotel-availability:yes , hotel-choice:Twenty one
# Act Type: ['hotel-area']
#
# Utterance: twenty one accomodation meet your need . what part of town be you plan to stay in ? | Hotel-Inform = choice : Twenty one ; Hotel-Request = area : ? | that do not matter as long as it be cheap . | Hotel-Inform = pricerange : cheap | hotel | Hotel-bookstay , Hotel-choice , Hotel-pricerange | hotel-availability:yes , hotel-choice:21
# Act Type: ['hotel-area', 'hotel-parking']
#
# Utterance: sure , I have their information . what would you like to know ? |  | ah , I just want to know it be still open . could you book I a room ? |  | hotel | Hotel-name |
# Act Type: ['hotel-bookday']
#
# Utterance: sure , what day would you like it for ? |  | 3 night start from friday . | Hotel-Inform = bookstay : 3 | hotel , restaurant | Hotel-bookstay , Hotel-name | booking-availability:yes , booking-bookpeople:1
# Act Type: ['booking-bookpeople']
#
# Utterance: booking be successful . reference number be : CRLJAWX3 . |  | I also need to find an indian restaurant in the east please . | Restaurant-Inform = food : indian , area : east | restaurant | Hotel-bookpeople , Hotel-bookstay , Hotel-name , Restaurant-area , Restaurant-food | restaurant-availability:yes , restaurant-choice:a few , restaurant-food:Indian
# Act Type: ['restaurant-pricerange']
#
# Utterance: there be a few indian restaurant in the east , do you have a price range you be try to stick to ? | Restaurant-Inform = choice : a few , food : Indian ; Restaurant-Request = pricerange : ? | in the mid - range would be fine . |  | restaurant | Hotel-bookpeople , Hotel-bookstay , Hotel-name , Restaurant-area , Restaurant-choice , Restaurant-food | restaurant-availability:yes , restaurant-food:Indian , restaurant-name:Rajmahal , restaurant-pricerange:moderately priced
# Act Type: ['restaurant-bookpeople']
#
# Utterance:  |  | I need a place to eat that be expensive . | Restaurant-Inform = pricerange : expensive | restaurant , hotel | Restaurant-pricerange | restaurant-availability:yes , restaurant-choice:57
# Act Type: ['restaurant-area']
#
# Utterance: I have find 57 restaurant that match your request . be there a particular area you would like to dine in ? | Restaurant-Inform = choice : 57 ; Restaurant-Request = area : ? | in the centre , please . | Restaurant-Inform = area : centre | restaurant , hotel | Restaurant-area , Restaurant-choice , Restaurant-pricerange | restaurant-availability:yes , restaurant-choice:33
# Act Type: ['restaurant-food']
#
# Utterance: there be 33 restaurant in that area , do you have a preference of the type of restaurant ? | Restaurant-Inform = choice : 33 ; Restaurant-Request = food : ? | I want something with malaysian food . | Restaurant-Inform = food : malaysian | restaurant | Restaurant-area , Restaurant-choice , Restaurant-food , Restaurant-pricerange | restaurant-availability:yes , restaurant-food:malaysian
# Act Type: ['restaurant-food']
#
# Utterance: arrival time be 12:07 do that work for you ? |  | yeah , that work . can you recommend a 0 star hotel for I ? | Hotel-Inform = stars : 0 | hotel | Hotel-stars | hotel-availability:yes , hotel-choice:1 , hotel-choice:two , hotel-type:guesthouse , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance: Alexander bed and breakfast be a 4 star cheap guesthouse with free interenet and parking locate in the centre . do that work for you ? | Hotel-Inform = name : Alexander bed and breakfast , stars : 4 , pricerange : cheap , type : guesthouse , area : centre | yes Alexander bed and breakfast that have a star of 4 would be great . | Hotel-Inform = name : alexander bed and breakfast , stars : 4 | hotel | Hotel-area , Hotel-bookstay , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookday', 'hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: sure , I can book that for you . how many people will be stay and for how long also arrive what day ? |  | there will be 7 people stay for 2 night begin on Thursday . | Hotel-Inform = bookpeople : 7 , bookstay : 2 , bookday : thursday | hotel | Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookstay']
#
# Utterance:  |  | can you help I in find a suitable guesthouse please ? | Hotel-Inform = type : guesthouse | hotel | Hotel-type | hotel-availability:yes , hotel-choice:24 , hotel-type:guest houses
# Act Type: ['hotel-area']
#
# Utterance: I be sorry I do not show anything available . would you like to try something else ? |  | ok , how about an italian restaurant ? | Restaurant-Inform = food : italian | restaurant | Restaurant-food | restaurant-availability:yes , restaurant-choice:5
# Act Type: ['restaurant-area']
#
# Utterance: certainly , what can I use to narrow down your search ? |  | it need to be 2 star , have free parking and free wifi . | Hotel-Inform = stars : 2 | hotel | Hotel-stars , Hotel-type | hotel-availability:yes , hotel-choice:3
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance: I be sorry but I can not find any british food locate in the south part of town . |  | be there a chinese restaurant in the south part of town ? | Restaurant-Inform = food : chinese , area : south | restaurant | Restaurant-area , Restaurant-food | restaurant-area:south part of town , restaurant-availability:yes , restaurant-choice:three , restaurant-food:Chinese
# Act Type: ['restaurant-pricerange']
#
# Utterance: the address list for Old Schools be simply Trinity Lane . and their postcode be cb21tt . be there anything more I can do for you today ? |  | yes , I would also like to find an expensive restaurant in the same area . | Restaurant-Inform = pricerange : expensive , area : centre | restaurant | Restaurant-area , Restaurant-pricerange |
# Act Type: ['restaurant-food', 'restaurant-pricerange']
#
# Utterance: sure . it be in the centre on Station Road . anything else ? | Hotel-Inform = area : centre , address : Station Road | yes , can you book that for I for 5 people and 4 night ? I need it on Sunday . | Hotel-Inform = bookpeople : 5 , bookstay : 4 , bookday : sunday | hotel | Hotel-address , Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance: I could not find a restaurant with the attribute you be look for . would you like something else ? |  | how about one with british food ? | Restaurant-Inform = food : british | restaurant | Restaurant-food , Restaurant-pricerange | restaurant-availability:yes , restaurant-choice:5 , restaurant-food:british
# Act Type: ['restaurant-area']
#
# Utterance: there be 5 restaurant serve british food . do you have a preferred area ? | Restaurant-Inform = choice : 5 , food : british ; Restaurant-Request = area : ? | I do not have a preferred area . which one have a table available for 6 people at 12:30 on Tuesday ? | Restaurant-Inform = bookpeople : 6 , booktime : 12:30 , bookday : tuesday | restaurant | Restaurant-bookday , Restaurant-bookpeople , Restaurant-booktime , Restaurant-choice , Restaurant-food , Restaurant-pricerange |
# Act Type: ['restaurant-pricerange']
#
# Utterance:  |  | can you help I find a moderately price place to eat locate in the centre ? | Restaurant-Inform = pricerange : moderate , area : centre | restaurant | Restaurant-area , Restaurant-pricerange | restaurant-availability:yes , restaurant-choice:many
# Act Type: ['restaurant-food']
#
# Utterance: I have 2 . the varsity restaurant and bloomsberry . both serve international food and be in the moderate price range . do you have a preference ? | Restaurant-Inform = choice : 2 , name : The varsity restaurant , name : bloomsberry , food : international , pricerange : moderate | can you check to see if either have booking for 5 people at 17:15 on monday ? | Restaurant-Inform = bookpeople : 5 , booktime : 17:15 , bookday : monday | restaurant | Restaurant-area , Restaurant-bookday , Restaurant-bookpeople , Restaurant-booktime , Restaurant-choice , Restaurant-food , Restaurant-name , Restaurant-pricerange |
# Act Type: ['restaurant-booktime']
#
# Utterance:  |  | can you help I find a place to stay that be expensive and include free parking ? | Hotel-Inform = pricerange : expensive | hotel | Hotel-pricerange |
# Act Type: ['hotel-area']
#
# Utterance:  |  | what be my option for cheap restaurant in the city center ? | Restaurant-Inform = pricerange : cheap , area : centre | restaurant | Restaurant-area , Restaurant-pricerange | restaurant-availability:yes , restaurant-choice:15
# Act Type: ['restaurant-food']
#
# Utterance:  |  | I would like a guesthouse in the moderate price range . do you think you could find one for I ? | Hotel-Inform = type : guesthouse , pricerange : moderate | hotel | Hotel-pricerange , Hotel-type |
# Act Type: ['hotel-area']
#
# Utterance: Acorn guest house meet all your need , would you like to book that ? | Hotel-Inform = name : Acorn guest house | that be perfect . I would like to book it for 1 person . it need to be for 4 night begin Saturday . | Hotel-Inform = bookpeople : 1 , bookstay : 4 , bookday : saturday | hotel | Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-name , Hotel-pricerange , Hotel-type | booking-availability:yes , booking-bookstay:those dates , hotel-availability:yes , hotel-name:the Acorn Guest House
# Act Type: ['hotel-bookday', 'hotel-bookstay']
#
# Utterance:  |  | I be look for a hotel that give I free parking and free wifi . | Hotel-Inform = type : hotel | hotel | Hotel-type | hotel-availability:yes , hotel-choice:many
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance: we have many with those feature . do you have any other preference to narrow it down , such as price range or location ? | Hotel-Inform = choice : many ; Hotel-Request = area : ? , pricerange : ? | oh , I would like a guesthouse that be moderately price please . | Hotel-Inform = type : guesthouse , pricerange : moderate | hotel | Hotel-choice , Hotel-pricerange , Hotel-type | hotel-availability:yes , hotel-choice:many
# Act Type: ['hotel-area']
#
# Utterance: the price be 17.60 pound and travel time be 79 minute . can I assist you with anything else today ? |  | I also need a hotel with free parking . |  | hotel |  | hotel-availability:yes , hotel-choice:29 , hotel-type:hotels
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance: the archway house meet your criterion . do you need help with booking ? | Hotel-Inform = name : The archway house | yes please , I need it for 4 people , 3 night start on Wednesday . | Hotel-Inform = bookpeople : 4 , bookstay : 3 , bookday : wednesday | hotel | Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-choice , Hotel-name , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookstay']
#
# Utterance:  |  | be there any place here in the centre that serve corsica food ? | Restaurant-Inform = area : centre , food : corsica | restaurant | Restaurant-area , Restaurant-food |
# Act Type: ['restaurant-pricerange']
#
# Utterance: what price range be you look for ? | Restaurant-Request = pricerange : ? | any price range will do . | Restaurant-Inform = pricerange : dontcare | restaurant | Restaurant-area , Restaurant-food , Restaurant-pricerange |
# Act Type: ['restaurant-area', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: the address be Cambridge Leisure Park Clifton Way and the phone number be 01223327908 . | Restaurant-Inform = address : Cambridge Leisure Park Clifton Way , phone : 01223327908 | excellent . I also need to find a place to stay while in town . can you help I find a cheap hotel ? | Hotel-Inform = pricerange : cheap , type : hotel | restaurant , hotel | Hotel-pricerange , Hotel-type , Restaurant-address , Restaurant-area , Restaurant-choice , Restaurant-food , Restaurant-name , Restaurant-phone , Restaurant-pricerange |
# Act Type: ['hotel-area']
#
# Utterance: no result for your query have be find . would you like to try again ? |  | be there any cheap restaurant that serve italian food ? | Restaurant-Inform = pricerange : cheap , food : italian | restaurant | Restaurant-food , Restaurant-pricerange | restaurant-area:centre of town , restaurant-area:north , restaurant-area:west , restaurant-availability:yes , restaurant-choice:Three , restaurant-choice:five , restaurant-choice:one , restaurant-food:Italian , restaurant-pricerange:cheap
# Act Type: ['restaurant-area']
#
# Utterance:  |  | I be look for a place to stay . the hotel should include free wifi and should be in the type of hotel | Hotel-Inform = type : hotel | hotel | Hotel-type | hotel-availability:yes , hotel-choice:quite a few , hotel-type:hotel
# Act Type: ['hotel-area', 'hotel-pricerange']
#
# Utterance: I be sorry Booking be unsuccessful , can I help you find another place to stay ? |  | yes please . another 3 - star hotel in the centre with free wifi . | Hotel-Inform = stars : 3 , area : centre | hotel | Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-name , Hotel-stars , Hotel-type | hotel-area:centre , hotel-availability:yes , hotel-stars:3 , hotel-type:hotel
# Act Type: ['hotel-area']
#
# Utterance: Kettle 's yard be museum in the west part of town . it be locate on castle street . |  | I also need a moderate price room . | Hotel-Inform = pricerange : moderate | hotel | Hotel-pricerange |
# Act Type: ['hotel-area']
#
# Utterance: great ! what area of town be you think of ? | Hotel-Request = area : ? | I would like it to be a guest house in the north . | Hotel-Inform = area : north | hotel | Hotel-area , Hotel-pricerange |
# Act Type: ['hotel-bookday']
#
# Utterance: okay , I can help you with that . when be you plan your stay ? |  | I be not sure yet . I be really research right now . can you please recommend a guesthouse in the north in the moderate price range ? |  | hotel | Hotel-area , Hotel-pricerange | hotel-availability:yes , hotel-choice:9 , hotel-pricerange:that price range , hotel-type:guesthouses
# Act Type: ['hotel-internet', 'hotel-parking']
#
# Utterance: I recommend Acorn Guesthouse . they be in the moderate price range and have 4 star . they offer both free internet and parking . may I reserve you any room ? | Hotel-Recommend = name : Acorn Guesthouse , pricerange : moderate , stars : 4 | yes , please , I would appreciate that . |  | hotel | Hotel-area , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type |
# Act Type: ['hotel-bookpeople', 'hotel-bookstay']
#
# Utterance: I be sorry , I can not look up the entry fee to Christ 's College . be there anything else I can do for you today ? |  | I also need a restaurant in the same area . | Restaurant-Inform = area : centre | restaurant | Restaurant-area | restaurant-availability:yes , restaurant-choice:many
# Act Type: ['restaurant-food', 'restaurant-pricerange']
#
# Utterance:  |  | I be look for a restaurant that serve international food . | Restaurant-Inform = food : international | restaurant | Restaurant-food | restaurant-availability:yes , restaurant-choice:three , restaurant-food:international
# Act Type: ['restaurant-pricerange']
#
# Utterance: there be three international restaurant in Cambridge . do you have a price preference ? | Restaurant-Inform = choice : three , food : international ; Restaurant-Request = pricerange : ? | I would like to find a moderately price place and I need a reservation for 4 people at 12:15 on a Thursday . | Restaurant-Inform = pricerange : moderate , bookpeople : 4 , booktime : 12:15 , bookday : thursday | restaurant | Restaurant-bookday , Restaurant-bookpeople , Restaurant-booktime , Restaurant-choice , Restaurant-food , Restaurant-pricerange | restaurant-availability:yes , restaurant-name:the Bloomsbury , restaurant-name:the Varsity
# Act Type: ['restaurant-booktime']
#
# Utterance: great . I have book you one seat on the 12:09 train from Leicester and your reference number be 7ur3bfw6 . be there anything else I can do for you ? |  | yes I want to reserve a table for 7 people at 15:00 on Thursday at an expensive african restaurant . can you help I with this ? | Restaurant-Inform = bookpeople : 7 , booktime : 15:00 , bookday : thursday , pricerange : expensive , food : african | restaurant | Restaurant-bookday , Restaurant-bookpeople , Restaurant-booktime , Restaurant-food , Restaurant-pricerange |
# Act Type: ['restaurant-bookday', 'restaurant-booktime']
#
# Utterance: there be no table available at Bedouin at that time . would you like to try a different time slot or perhaps a different day ? |  | sure . if there be no other african eatery to choose from , try the 14:00 at the Bedouin . |  | restaurant | Restaurant-bookday , Restaurant-bookpeople , Restaurant-booktime , Restaurant-food , Restaurant-pricerange | booking-availability:yes , booking-name:bedouin
# Act Type: ['restaurant-bookday', 'restaurant-booktime']
#
# Utterance:  |  | I be look for a place to stay . |  | hotel |  |
# Act Type: ['hotel-area', 'hotel-internet', 'hotel-parking', 'hotel-pricerange']
#
# Utterance: there be a few place , mainly church , that have great architecture . do you want information on any of those ? |  | no thank you though . I would like information on greek restaurant that would be in the same area as the church you suggest , please ? | Restaurant-Inform = food : greek , area : centre | restaurant | Restaurant-area , Restaurant-food | restaurant-area:centre , restaurant-availability:yes , restaurant-food:greek
# Act Type: ['restaurant-area']
#
# Utterance:  |  | I be look for a cheap place to stay . can you help ? | Hotel-Inform = pricerange : cheap | hotel | Hotel-pricerange | hotel-availability:yes , hotel-choice:a number of , hotel-pricerange:cheap , hotel-type:hotels
# Act Type: ['hotel-area']
#
# Utterance: ok , would you prefer a guesthouse or a hotel ? | Hotel-Select = type : guesthouse , type : hotel | any so long as it be a 2star and have wifi | Hotel-Inform = type : dontcare , stars : 2 | hotel | Hotel-area , Hotel-choice , Hotel-pricerange , Hotel-stars , Hotel-type |
# Act Type: ['hotel-pricerange']
#
# Utterance: booking be successful . reference number be : daey6jjv . |  | thank you . I be also look for a restaurant that serve vegetarian food and that be expensive . | Restaurant-Inform = food : vegetarian , pricerange : expensive | restaurant , hotel | Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type , Restaurant-food , Restaurant-pricerange | restaurant-availability:yes , restaurant-food:vegetarian
# Act Type: ['restaurant-food']
#
# Utterance: I do not seem to have any vegetarian restaurant . do you have a second choice for cuisine ? | Restaurant-NoOffer = food : vegetarian ; Restaurant-Request = food : ? | Italian would be fine . | Restaurant-Inform = food : italian | restaurant | Hotel-area , Hotel-bookday , Hotel-bookpeople , Hotel-bookstay , Hotel-choice , Hotel-name , Hotel-pricerange , Hotel-stars , Hotel-type , Restaurant-food , Restaurant-pricerange | restaurant-area:around town , restaurant-availability:yes , restaurant-choice:5 , restaurant-food:Italian , restaurant-pricerange:expensive
# Act Type: ['restaurant-area']

# %%
none_count = train_labels.count(['none'])
print("Number of 'none' labels:", none_count)
print("Total number of labels:", len(train_labels))
# Out:
# Number of 'none' labels: 4
# Total number of labels: 7188

# %%
#Mount Google drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#change current working directory
#%cd "/content/drive/Shareddrives/NLI"

# %%
#!pip install transformers
#!pip install accelerate
#!pip install datasets
#!python3 -m spacy download en_core_web_lg

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import torch
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, Dataset
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import recall_score, precision_score, f1_score
from torch import cuda
import re
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from seqeval.metrics import classification_report
from itertools import product
import os
import joblib
import json
import math
import nltk
from datasets import load_dataset
from datasets import DatasetDict

nltk.download('punkt')

import spacy

nlp = spacy.load("en_core_web_lg")
# Out:
# [nltk_data] Downloading package punkt to /home/mister/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /home/mister/miniconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
DATASET_DIRECTORY = "./../dataset.hf/"
DATA_SAVE_PATH = "cosine_similarity/utt+values.json"
VECTORS_SAVE_PATH = "cosine_similarity/vectors.json"

ALWAYS_LOAD_DATASET = False
SAVE_DATASET = True

# %%
import json

def save_variable_to_json(variable, file_path):
    with open(file_path, 'w') as file:
        json.dump(variable, file)

def load_variable_from_json(file_path):
    with open(file_path, 'r') as file:
        variable = json.load(file)
    return variable

# %%
# Extracting only hotel and restaurant features from the dataset
def preprocess_split(dataset, split):
    df = dataset[split].to_pandas()
    new_df = pd.DataFrame(columns = df.columns)
    for i in range(len(df)):
        # Taken from notebook, to know which lines to skip
        row = df.loc[i]
        if not any(set(row.turns['frames'][turn_id]['service']).intersection(['hotel', 'restaurant']) for turn_id,utt in enumerate(row.turns['utterance'])):
            continue

        new_df.loc[len(new_df)] = row
    return new_df

# %%
def process_service_list(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service == 'restaurant':
            services.add('restaurant')
        elif service == 'hotel':
            services.add('hotel')
        else:
            services.add('other')
        if len(services) == 3:
            break
    return list(services)

def process_dialogue_act(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service.startswith('Restaurant') or service.startswith('restaurant'):
            services.add(service)
        elif service.startswith('Hotel') or service.startswith('hotel'):
            services.add(service)
        elif service.startswith('general') or service.startswith('General'):
            services.add(service)
        elif service.startswith('Booking') or service.startswith('booking'):
            services.add(service)
        else:
            services.add('other')
    return list(services)

# %%
def parse(sentence):
    # Tokenize
    sentence = nlp(sentence)
    # Remove stop words
    sentence = " ".join([token.lemma_ for token in sentence])
    
    return sentence

# %%
def get_act_type_to_slots(dialogue_act):
    act_type_to_slots = {}

    # All the slots that are present in the current user utterance
    span_info = dialogue_act['span_info']
    act_types = span_info['act_type']
    act_slot_names = span_info['act_slot_name']
    act_slot_values = span_info['act_slot_value']

    for slot_name, act_type, slot_value in zip(act_slot_names, act_types , act_slot_values):
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            if not act_type in act_type_to_slots:
                act_type_to_slots[act_type] = []
            act_type_to_slots[act_type].append(tuple([slot_name, slot_value]))

    # All the slots that are not present in the current user utterance (slots with '?')
    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    for act_type, act_slot in zip(act_types, act_slots):
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel'):
            for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                if slot_name != "none" and  slot_value == "?":
                    if not act_type in act_type_to_slots:
                        act_type_to_slots[act_type] = []
                    act_type_to_slots[act_type].append(tuple([slot_name, slot_value]))
    return act_type_to_slots

# %%
def get_to_be_provided_overall(dialogue_act, current_booking_service):
    
    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    to_be_provided_overall = []
    for act_type, act_slot in zip(act_types, act_slots):
        # If the domain is booking, we need to know which service is being booked
        
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel') or act_type.startswith('Booking') or act_type.startswith('general'):
            domain = act_type.split("-")[0]
            if domain == "booking" and len(current_booking_service)==1:
                domain = current_booking_service[0]
            domain = domain.lower()

            if domain in ["hotel", "restaurant", "booking", "general"]:
                # Retrieve the slots that are in the form of "something : ?"
                slots = []
                for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                    if slot_name != "none" and  slot_value != "?":
                        slots.append(domain + "-" + slot_name + ":" + slot_value)
            
                if slots and any((slot_name_value.split(":")[0] != domain + "-none" for slot_name_value in slots)) and not "-No" in dialogue_act:
                    to_be_provided = ["%s-availability:yes" % (domain)] + slots
                    to_be_provided_overall.extend(to_be_provided)
                elif "-No" in dialogue_act:
                    to_be_provided = ["%s-availability:no" % (domain)] + slots
                    to_be_provided_overall.extend(to_be_provided)
            
    to_be_provided_overall = sorted(list(set(to_be_provided_overall)))
    remove_avail_no_list = [elem for elem in to_be_provided_overall if elem.endswith("availability:no")]
    for remove_avail in remove_avail_no_list:
        remove_avail_yes = remove_avail[:-2]+"yes"
        while remove_avail_yes in to_be_provided_overall:
            del to_be_provided_overall[to_be_provided_overall.index(remove_avail_yes)]

    return to_be_provided_overall

# %%
def get_to_be_requested(dialogue_act, current_booking_service):

    act_types = dialogue_act['dialog_act']['act_type']
    act_slots = dialogue_act['dialog_act']['act_slots']

    to_be_requested = []
    for act_type, act_slot in zip(act_types, act_slots):
        # If the domain is booking, we need to know which service is being booked
        
        if act_type.startswith('Restaurant') or act_type.startswith('Hotel') or act_type.startswith('Booking') or act_type.startswith('general'):
            domain = act_type.split("-")[0].lower()
            if domain == "booking" and len(current_booking_service)==1:
                domain = current_booking_service[0]
            domain = domain.lower()
        
            if domain in ["hotel", "restaurant", "booking", "general"]:
                
                slots = []
                for slot_name, slot_value in zip(act_slot['slot_name'], act_slot['slot_value']):
                    if slot_name != "none" and  slot_value == "?":
                        slots.append(domain + "-" + slot_name)
                
                to_be_requested.extend(slots)
    to_be_requested = sorted(list(set(to_be_requested)))
    return to_be_requested

# %%
def concatenate_user_act_type_slots(user_act_type_to_slots):
    
    historical_utterance = ""
    for act_type in user_act_type_to_slots:
        historical_utterance += act_type + " = "
        for slot_name, slot_value in user_act_type_to_slots[act_type]:
            historical_utterance += slot_name + " : " + slot_value + " , "
        
        if len(user_act_type_to_slots[act_type]) > 0:
            # Remove last comma
            historical_utterance = historical_utterance[:-3]

        historical_utterance += " ; "

    if len(user_act_type_to_slots) > 0:
        # Remove last semicolon
        historical_utterance = historical_utterance[:-3]

    return historical_utterance

# %%
def extract_features(dataset):
    target_list = []
    training_list = []

    for i in tqdm(range(len(dataset))):
        turns = dataset.loc[i].turns

        speaker_str = {'User': 0, 'Agent': 1}

        for j, (utterance, speaker, dialogue_act) in enumerate(zip(turns['utterance'], turns['speaker'], turns['dialogue_acts'])):
            if speaker == speaker_str['Agent']:
                prev_user = j - 1
                services = turns['frames'][prev_user]['service']
                user_booking_service = [service for service in services if service in ["hotel", "restaurant"]]
                if len(user_booking_service) == 0:
                    continue

                # Target
                to_be_requested = get_to_be_requested(dialogue_act, user_booking_service)
                to_be_provided = get_to_be_provided_overall(dialogue_act, user_booking_service)
                
                to_be_requested = [request + " : ?" for request in to_be_requested]
                
                names_to_be_provided = []
                values_to_be_provided = []
                for provided in to_be_provided:
                    name = provided.split(':')[0]
                    value = provided.split(':')[1]
                    if name.endswith("availability"):
                        names_to_be_provided.append(provided)
                    
                    else:
                        names_to_be_provided.append(name)
                    values_to_be_provided.append(value)

                vector = to_be_requested + names_to_be_provided
                
                info = [utterance, values_to_be_provided]

                training_list.append(vector)
                target_list.append(info)

    return training_list, target_list

# %%
try:
    print('Loading from json...')
    utterances = load_variable_from_json(DATA_SAVE_PATH)
    vectors = load_variable_from_json(VECTORS_SAVE_PATH)
    print('Loaded from json')
except:
    print('Exception occured during loading from json')
    print('Loading dataset...')

    try:
        if ALWAYS_LOAD_DATASET:
            raise Exception('Load data always')
        # Run it only once
        dataset = DatasetDict.load_from_disk(DATASET_DIRECTORY)
        
    except:
        # Run it only once
        dataset = load_dataset("multi_woz_v22")

        if SAVE_DATASET:
            # Run it only once
            dataset.save_to_disk(DATASET_DIRECTORY)

    print('Preprocessing...')
    train = preprocess_split(dataset, 'train')
    val = preprocess_split(dataset, 'validation')
    test = preprocess_split(dataset, 'test')

    print('Extracting utterances and act types...')
    train_vectors, train_utterances= extract_features(train)
    test_vectors, test_utterances = extract_features(test)
    valid_vectors,  valid_utterances= extract_features(val)

    utterances = train_utterances + test_utterances + valid_utterances
    vectors = train_vectors + test_vectors + valid_vectors

    print('Saving to json...')
    save_variable_to_json(utterances , DATA_SAVE_PATH)
    save_variable_to_json(vectors, VECTORS_SAVE_PATH)
    
    print('Saved to json')
# Out:
# Loading from json...
# Loaded from json

# %%
for utterance, act_type in zip(utterances[:100], vectors[:100]):
    print("Utterance:", utterance)
    print("Vector:", act_type)
    print()
# Out:
# Utterance: ['I have several options for you; do you prefer African, Asian, or British food?', ['yes', 'several', 'African', 'Asian', 'British']]
# Vector: ['restaurant-availability:yes', 'restaurant-choice', 'restaurant-food', 'restaurant-food', 'restaurant-food']
#
# Utterance: ['There is an Afrian place named Bedouin in the centre. How does that sound?', ['centre', 'yes', 'Afrian', 'Bedouin']]
# Vector: ['restaurant-area', 'restaurant-availability:yes', 'restaurant-food', 'restaurant-name']
#
# Utterance: ["Bedouin's phone is 01223367660. As far as hotels go, I recommend the University Arms Hotel in the center of town.", ['center of town', 'yes', 'the University Arms Hotel', 'yes', 'Bedouin', '01223367660']]
# Vector: ['hotel-area', 'hotel-availability:yes', 'hotel-name', 'restaurant-availability:yes', 'restaurant-name', 'restaurant-phone']
#
# Utterance: ['Sure, when would you like that reservation?', []]
# Vector: ['hotel-bookday : ?']
#
# Utterance: ['Your booking was successful. Your reference number is FRGZWQL2 . May I help you further?', ['yes', 'FRGZWQL2']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ['I have 4 different options for you. I have two cheaper guesthouses and two expensive hotels. Do you have a preference?', ['yes', '4', 'cheaper', 'expensive', 'guesthouses', 'hotels']]
# Vector: ['hotel-availability:yes', 'hotel-choice', 'hotel-pricerange', 'hotel-pricerange', 'hotel-type', 'hotel-type']
#
# Utterance: ['Sure. Does price matter? We can narrow it down and find exactly what you need.', []]
# Vector: ['hotel-pricerange : ?', 'restaurant-pricerange : ?']
#
# Utterance: ['I would recommend aylesbray lodge guest house. Would you like me to book that for you?', ['yes', 'aylesbray lodge guest house']]
# Vector: ['hotel-availability:yes', 'hotel-name']
#
# Utterance: ['The booking was unsuccessful. would you like another day or a shorter stay?', []]
# Vector: ['hotel-bookday : ?', 'hotel-bookstay : ?']
#
# Utterance: ['Booked! Reference number is: 84ESP6F5', ['yes', '84ESP6F5']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ['Cityroomz is located at Sleeperz Hotel, Station Road in the Centre area. It is a moderatley priced hotel with a 0 star rating. Would you like to book a room?', ['Sleeperz Hotel', 'Station Road', 'Centre', 'yes', 'Cityroomz', 'moderatley priced', '0', 'hotel']]
# Vector: ['hotel-address', 'hotel-address', 'hotel-area', 'hotel-availability:yes', 'hotel-name', 'hotel-pricerange', 'hotel-stars', 'hotel-type']
#
# Utterance: ['How many days would you like to book it for?', []]
# Vector: ['hotel-bookstay : ?']
#
# Utterance: ['Ok, Your rooms have been booked. Your reference number is CYJDAR7R . Is there anything else I can help you with today?', ['yes', 'CYJDAR7R']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ['There are 9 expensive restaurants in the west area. Do you prefer a certain type of food?', ['west', 'yes', '9', 'expensive']]
# Vector: ['restaurant-food : ?', 'restaurant-area', 'restaurant-availability:yes', 'restaurant-choice', 'restaurant-pricerange']
#
# Utterance: ['I recommend Graffiti, the number is 01223277977 and the postcode is cb30lx. Would you like me to book a table for you?', ['yes', 'Graffiti', '01223277977', 'cb30lx']]
# Vector: ['restaurant-availability:yes', 'restaurant-name', 'restaurant-phone', 'restaurant-postcode']
#
# Utterance: ['i have their info, what would you like to know?', []]
# Vector: []
#
# Utterance: ["I sure can. First, I will need to know when you want your stay to begin and how many days you'll be staying. Also, how many people will be staying?", []]
# Vector: ['hotel-bookday : ?', 'hotel-bookpeople : ?', 'hotel-bookstay : ?']
#
# Utterance: ['Can you tell me how many guests will be staying in the room?', []]
# Vector: ['hotel-bookpeople : ?']
#
# Utterance: ['Booking was successful. Your reference number is 4UFN3SWC . Will that be all for today?', ['yes', '4UFN3SWC']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ["sure thing what's the area and or name?", []]
# Vector: ['restaurant-area : ?', 'restaurant-name : ?']
#
# Utterance: ['A very nice place in the centre. Need a reservation?', ['centre', 'yes']]
# Vector: ['restaurant-area', 'restaurant-availability:yes']
#
# Utterance: ['Booking was successful. The table will be reserved for 15 minutes. Reference number is : GVM0PAM2 .', ['yes', 'GVM0PAM2']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ["I've heard good things about the lucky star. Need a reservation?", ['yes', 'the lucky star']]
# Vector: ['restaurant-availability:yes', 'restaurant-name']
#
# Utterance: ['Your booking was successful. The table will be reserved for 15 minutes. Reference number is : FDLFKTZM .', ['yes', 'FDLFKTZM']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ['TR3128 will leave at 20:40 and arrive by 21:08. Do you need more information or would you like to book tickets?', []]
# Vector: []
#
# Utterance: ['riverside brasserie is a modern european restaurant in the centre. Its address is Doubletree by Hilton Cambridge Granta Place Mill Lane and postcode is cb21rt. Want to book it?', ['Doubletree by Hilton Cambridge Granta Place Mill Lane', 'centre', 'yes', 'modern european', 'riverside brasserie', 'cb21rt']]
# Vector: ['restaurant-address', 'restaurant-area', 'restaurant-availability:yes', 'restaurant-food', 'restaurant-name', 'restaurant-postcode']
#
# Utterance: ['Unfortunately, I cannot book it at this time.', []]
# Vector: []
#
# Utterance: ['How many people will be dining?', []]
# Vector: ['restaurant-bookpeople : ?']
#
# Utterance: ['Your booking was successful. Your reference number is 3VX3AOKS .', ['yes', '3VX3AOKS']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ['I sure can. There are lots of choices. Are you looking for a particular type of food?', ['yes', 'lots']]
# Vector: ['restaurant-food : ?', 'restaurant-availability:yes', 'restaurant-choice']
#
# Utterance: ['There is a Korean restaurant called Little Seoul located at 108 Regent Street City Centre. Would you like their phone number?', ['108 Regent Street City Centre', 'yes', 'Korean', 'Little Seoul']]
# Vector: ['restaurant-address', 'restaurant-availability:yes', 'restaurant-food', 'restaurant-name']
#
# Utterance: ['The phone number for little seoul is 01223308681, postcode cb21dp. Can I help you with anything else today?', ['yes', 'little seoul', '01223308681', 'cb21dp']]
# Vector: ['restaurant-availability:yes', 'restaurant-name', 'restaurant-phone', 'restaurant-postcode']
#
# Utterance: ['The address for Little Seoul is 108 Regent Street, City Centre. Is there anything else I can help you with?', ['108 Regent Street', 'City Centre', 'yes', 'Little Seoul']]
# Vector: ['restaurant-address', 'restaurant-address', 'restaurant-availability:yes', 'restaurant-name']
#
# Utterance: ['What area of town would you like?', []]
# Vector: ['hotel-area : ?']
#
# Utterance: ['I have places that fit that description all over town, except in the north. If area is no concern, I recommend the Gonville in the center of town.', ['all over town', 'center of town', 'except in the north', 'yes', 'the Gonville']]
# Vector: ['hotel-area', 'hotel-area', 'hotel-area', 'hotel-availability:yes', 'hotel-name']
#
# Utterance: ['No, it only 3 stars. The Huntington Marriott is 4 stars though. It is also expensive and has free parking and internet.', ['yes', 'yes', 'The Huntington Marriott', 'yes', 'expensive', '3', '4']]
# Vector: ['hotel-availability:yes', 'hotel-internet', 'hotel-name', 'hotel-parking', 'hotel-pricerange', 'hotel-stars', 'hotel-stars']
#
# Utterance: ['Sure - The Lucky Star serves Chinese food and Nandos serves Portuguese food. Do either of those sound good?', ['yes', 'Chinese', 'Portuguese', 'Lucky Star', 'Nandos']]
# Vector: ['restaurant-availability:yes', 'restaurant-food', 'restaurant-food', 'restaurant-name', 'restaurant-name']
#
# Utterance: ['Would you like to book a table?', []]
# Vector: []
#
# Utterance: ['Sure. The post code is cb17dy.', ['yes', 'cb17dy']]
# Vector: ['restaurant-availability:yes', 'restaurant-postcode']
#
# Utterance: ["Backstreet Bistro. It's expensive though. There is a moderately priced one called The Cow Pizza Kitchen and Bar if preferred.", ['yes', 'Backstreet Bistro', 'The Cow Pizza Kitchen and Bar', 'expensive', 'moderately priced']]
# Vector: ['restaurant-availability:yes', 'restaurant-name', 'restaurant-name', 'restaurant-pricerange', 'restaurant-pricerange']
#
# Utterance: ['No problem. That is booked for you and your reference number is 2VE84YC5 . Is there anything else I can book for you?', ['yes', '2VE84YC5']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ["Eraina is a European restaurant in the centre area. Their address is St. Michael's Church Trinity Street City Centre and phone number 01223 355166.", ["St. Michael's Church Trinity Street City Centre", 'centre', 'yes', 'European', 'Eraina', '01223 355166']]
# Vector: ['restaurant-address', 'restaurant-area', 'restaurant-availability:yes', 'restaurant-food', 'restaurant-name', 'restaurant-phone']
#
# Utterance: ['There are no crossover locations in Cambridge.', ['yes', 'crossover']]
# Vector: ['restaurant-availability:yes', 'restaurant-food']
#
# Utterance: ['I have 7 in the centre that serve british food. I have 4 in the moderate price range and 3 in the expensive. Did you have a preference?', ['centre', 'yes', '3', '4', '7', 'british', 'expensive', 'moderate']]
# Vector: ['restaurant-area', 'restaurant-availability:yes', 'restaurant-choice', 'restaurant-choice', 'restaurant-choice', 'restaurant-food', 'restaurant-pricerange', 'restaurant-pricerange']
#
# Utterance: ['I have cotto that serves moderate priced food. Would you like to book a table?', ['yes', 'cotto', 'moderate priced']]
# Vector: ['restaurant-availability:yes', 'restaurant-name', 'restaurant-pricerange']
#
# Utterance: ['I have made your booking here is the information:Booking was successful. The table will be reserved for 15 minutes. Reference number is : VVSOH0TQ .', ['yes', 'VVSOH0TQ']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ['There are two restaurants fitting your description, one is Chinese cuisine and one is Indian cuisine. Do you have a preference?', ['yes', '2', 'Chinese', 'Indian']]
# Vector: ['restaurant-availability:yes', 'restaurant-choice', 'restaurant-food', 'restaurant-food']
#
# Utterance: ["Okay you're all set for Sunday at 12:30. Your reference number is F5BTP63A . Can I help you find anything else?", ['yes', 'Sunday', '12', 'F5BTP63A']]
# Vector: ['booking-availability:yes', 'booking-bookday', 'booking-booktime', 'booking-ref']
#
# Utterance: ['Booking was successful, the total fee is 17.89 GBP payable at the station. Reference number is : T1FGQFDJ . Can I help with anything else today?', []]
# Vector: []
#
# Utterance: ['You have three options for moderately priced restaurants. Do you prefer indian or italian food?', ['yes', 'three', 'indian', 'italian', 'moderately priced']]
# Vector: ['restaurant-availability:yes', 'restaurant-choice', 'restaurant-food', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: ['The place is called The Curry Prince and the phone number is: 01223566388 and the post code is: cb58jj.', ['yes', 'The Curry Prince', '01223566388', 'cb58jj']]
# Vector: ['restaurant-availability:yes', 'restaurant-name', 'restaurant-phone', 'restaurant-postcode']
#
# Utterance: ['I have 32 places that offer wifi, do you have a price range preference?', ['yes', '32', 'yes']]
# Vector: ['hotel-pricerange : ?', 'hotel-availability:yes', 'hotel-choice', 'hotel-internet']
#
# Utterance: ['There are 33 cheap hotels with wifi in Cambridge. Do you have a particular area you are interested in?', ['yes', '33', 'yes', 'cheap', 'hotel']]
# Vector: ['hotel-area : ?', 'hotel-availability:yes', 'hotel-choice', 'hotel-internet', 'hotel-pricerange', 'hotel-type']
#
# Utterance: ['I recommend alexander bed and breakfast on 56 saint barnabas road would that due?', ['56 saint barnabas road', 'yes', 'alexander bed and breakfast']]
# Vector: ['hotel-address', 'hotel-availability:yes', 'hotel-name']
#
# Utterance: ['Perfect, you are all set for Alexander Bed and Breakfast on Tuesday, your reference number is 22DG5770 . Is there anything I can help with today?', ['yes', 'Tuesday', 'Alexander Bed and Breakfast', '22DG5770']]
# Vector: ['booking-availability:yes', 'booking-bookday', 'booking-name', 'booking-ref']
#
# Utterance: ['I have the TR9688, which leaves at 12:32. Would you like to book this train?', []]
# Vector: []
#
# Utterance: ["If you're heading north, I recommend taking a ride on the Riverboat Georgina.", []]
# Vector: []
#
# Utterance: ['There at 10 guest houses in the north offering free wifi. Are you looking for a particular price range?', ['north', 'yes', '10', 'yes', 'guest houses']]
# Vector: ['hotel-pricerange : ?', 'hotel-area', 'hotel-availability:yes', 'hotel-choice', 'hotel-internet', 'hotel-type']
#
# Utterance: ['Acorn Guest house is located in the north , has free wifi and is moderately priced.', ['north', 'yes', 'yes', 'Acorn Guest house', 'moderately priced']]
# Vector: ['hotel-area', 'hotel-availability:yes', 'hotel-internet', 'hotel-name', 'hotel-pricerange']
#
# Utterance: ['Your booking has been made and your reference number is O0FG9YKT . Acorn Guest House is located at 154 Chesterton Road. Is there anything else I can do for you?', ['yes', 'O0FG9YKT', '154 Chesterton Road', 'yes', 'Acorn Guest House']]
# Vector: ['booking-availability:yes', 'booking-ref', 'hotel-address', 'hotel-availability:yes', 'hotel-name']
#
# Utterance: ['Great choice! I have 10 Chinese restaurants. What is your price range and we can narrow them down.', ['yes', '10', 'Chinese']]
# Vector: ['restaurant-pricerange : ?', 'restaurant-availability:yes', 'restaurant-choice', 'restaurant-food']
#
# Utterance: ['How does the Charlie Chan sound? It is a cheap Chinese restaurant in the centre.', ['centre', 'yes', 'Chinese', 'Charlie Chan', 'cheap']]
# Vector: ['restaurant-area', 'restaurant-availability:yes', 'restaurant-food', 'restaurant-name', 'restaurant-pricerange']
#
# Utterance: ['I am sorry but charlie chan is booked for that time. Do you want to pick an earlier or later time, or a different day?', []]
# Vector: ['restaurant-bookday : ?', 'restaurant-booktime : ?']
#
# Utterance: ['Great News! I was able to reserve your table for 2 at the 11:45 time. They will hold the table for 15 minutes. Reference number is : GFIL3UG5 .', ['yes', '2', '11', 'GFIL3UG5']]
# Vector: ['booking-availability:yes', 'booking-bookpeople', 'booking-booktime', 'booking-ref']
#
# Utterance: ['What about a museum? The cambridge contemporary art is a nice one.', []]
# Vector: []
#
# Utterance: ['There are results matching your query. Would you like Mexican, Italian, Chinese, or Indian?', ['yes', 'results', 'Chinese', 'Indian', 'Italian', 'Mexican']]
# Vector: ['restaurant-availability:yes', 'restaurant-choice', 'restaurant-food', 'restaurant-food', 'restaurant-food', 'restaurant-food']
#
# Utterance: ['Frankie and Bennys is an expensive Italian eatery in the south part of town. Would you like any additional information about this restaurant?', ['south', 'yes', 'Italian', 'Frankie and Bennys', 'expensive']]
# Vector: ['restaurant-area', 'restaurant-availability:yes', 'restaurant-food', 'restaurant-name', 'restaurant-pricerange']
#
# Utterance: ['The address is Cambridge Leisure Park Clifton Way Cherry Hinton. The phone number is 01223 412430.', ['Cambridge Leisure Park Clifton Way Cherry Hinton', 'yes', '01223 412430']]
# Vector: ['restaurant-address', 'restaurant-availability:yes', 'restaurant-phone']
#
# Utterance: ['What area would you like? There are nine results.', ['yes', 'nine']]
# Vector: ['restaurant-area : ?', 'restaurant-availability:yes', 'restaurant-choice']
#
# Utterance: ['Okay, Yu Garden matches your specifications. Would you like me to book a reservation?', ['yes', 'Yu Garden']]
# Vector: ['restaurant-availability:yes', 'restaurant-name']
#
# Utterance: ['The booking went through, your table is reserved for 15 minutes starting at 16:15. Reference number is BT75STQI .', ['yes', '16', 'BT75STQI']]
# Vector: ['booking-availability:yes', 'booking-booktime', 'booking-ref']
#
# Utterance: ['I would recommend the Express by Holiday Inn Cambridge, should I book it for you?', ['yes', 'the Express by Holiday Inn Cambridge']]
# Vector: ['hotel-availability:yes', 'hotel-name']
#
# Utterance: ['Yes, there is internet there. Would you like a booking then?', ['yes', 'yes']]
# Vector: ['hotel-availability:yes', 'hotel-internet']
#
# Utterance: ['They are expensive and can be reached at 01223866800. The address is 15-17 norman way, coldhams business park. Anything else?', ['15-17 norman way', 'coldhams business park', 'yes', '01223866800', 'expensive']]
# Vector: ['hotel-address', 'hotel-address', 'hotel-availability:yes', 'hotel-phone', 'hotel-pricerange']
#
# Utterance: ['which side of town do you prefer and what is the price range?', []]
# Vector: ['hotel-area : ?', 'hotel-pricerange : ?']
#
# Utterance: ['alexander bed and breakfast is a guest house in the centre area. Would you like to book a room?', ['centre', 'yes', 'alexander bed and breakfast', 'guest house']]
# Vector: ['hotel-area', 'hotel-availability:yes', 'hotel-name', 'hotel-type']
#
# Utterance: ['The Huntingdon Marriott hotel is a very nice place.', ['yes', 'Huntingdon Marriott hotel']]
# Vector: ['hotel-availability:yes', 'hotel-name']
#
# Utterance: ['Booking was successful. Reference number is : 36N9VCAD . Is there anything else I can help with?', ['yes', '36N9VCAD']]
# Vector: ['booking-availability:yes', 'booking-ref']
#
# Utterance: ['Train TR7468 will arrive at 13:23. Will this work for you?', []]
# Vector: []
#
# Utterance: ["I'm sorry. There is no matching restaurant. Would you like to try a different food type or area?", []]
# Vector: ['restaurant-area : ?', 'restaurant-food : ?']
#
# Utterance: ['There are nine Italian restaurants in the centre of town! Are you looking for an Italian restaurant in any particular price range?', ['centre of town', 'yes', 'nine', 'restaurants']]
# Vector: ['restaurant-area', 'restaurant-availability:yes', 'restaurant-choice', 'restaurant-food']
#
# Utterance: ["I recommend Caffe Uno - it's very nice. They're at 32 Bridge Street City Centre, cb21uj. Can I help with anything else?", ['32 Bridge Street City Centre', 'yes', 'Caffe Uno', 'cb21uj']]
# Vector: ['restaurant-address', 'restaurant-availability:yes', 'restaurant-name', 'restaurant-postcode']
#
# Utterance: ['It is an expensive British restaurant on the west side of town. Would you like the address?', ['the west side', 'yes', 'British', 'expensive']]
# Vector: ['restaurant-area', 'restaurant-availability:yes', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: ["Ok. You're all set for Monday at 14:15. Have a great day.", ['yes', 'Monday', '14']]
# Vector: ['booking-availability:yes', 'booking-bookday', 'booking-booktime']
#
# Utterance: ['I actually cannot find any expensive restaurants with north african food. There is however an expensive restaurant with african food. Would that be okay?', ['yes', 'african', 'north african', 'expensive']]
# Vector: ['restaurant-availability:yes', 'restaurant-food', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: ['Yes, I have 3. Two are located in the centre and one is located in the east. Do you have a preference?', ['centre', 'east', 'yes', '3', 'Two', 'one']]
# Vector: ['restaurant-area', 'restaurant-area', 'restaurant-availability:yes', 'restaurant-choice', 'restaurant-choice', 'restaurant-choice']
#
# Utterance: ['One in the East is called Royal Standard. Can I book a table for you?', ['yes', 'Royal Standard']]
# Vector: ['restaurant-availability:yes', 'restaurant-name']
#
# Utterance: ["I'm sorry that isn't available. Can I try a different restaurant for you?", []]
# Vector: []
#
# Utterance: ['Absolutely! This is a moderately priced guest house with four stars. There is wifi included. It is located on the east. What else can I help with?', ['east', 'yes', 'yes', 'moderately priced', 'four', 'guest house']]
# Vector: ['hotel-area', 'hotel-availability:yes', 'hotel-internet', 'hotel-pricerange', 'hotel-stars', 'hotel-type']
#
# Utterance: ['Yes, I would as a matter of fact. And yes the offer free parking.', ['yes', 'yes']]
# Vector: ['hotel-availability:yes', 'hotel-parking']
#
# Utterance: ['It has four stars. Would you still like information on the train?', ['yes', 'four']]
# Vector: ['hotel-availability:yes', 'hotel-stars']
#
# Utterance: ['There are several moderate priced guesthouses do you have a preferred area that you want to stay in?', ['yes', 'several', 'moderate priced', 'guesthouses']]
# Vector: ['hotel-area : ?', 'hotel-availability:yes', 'hotel-choice', 'hotel-pricerange', 'hotel-type']
#
# Utterance: ['a and b guest house is a guesthouse in the east and it is moderate. Shall I book it ?', ['east', 'yes', 'a and b guest house', 'moderate']]
# Vector: ['hotel-area', 'hotel-availability:yes', 'hotel-name', 'hotel-pricerange']
#
# Utterance: ['The star rating is 4 and they do have free wifi.', ['yes', 'yes', '4']]
# Vector: ['hotel-availability:yes', 'hotel-internet', 'hotel-stars']
#
# Utterance: ['Is there a price range or type of food that you would prefer?', []]
# Vector: ['restaurant-food : ?', 'restaurant-pricerange : ?']
#
# Utterance: ['That is an Italian restaurant located in the centre of town. It is at 12 Bridge Street. Can I call and reserve a table for you?', ['12 Bridge Street', 'centre of town', 'yes', 'Italian']]
# Vector: ['restaurant-address', 'restaurant-area', 'restaurant-availability:yes', 'restaurant-food']
#
# Utterance: ['I am afraid that booking was unsuccessful. Would you like to try another restaurant?', []]
# Vector: []
#
# Utterance: ['Yes there are 15 restaurants that are a similar price range. Did you still want Italian?', ['yes', '15', 'Italian', 'similar price range']]
# Vector: ['restaurant-availability:yes', 'restaurant-choice', 'restaurant-food', 'restaurant-pricerange']
#
# Utterance: ['Your reservation is at the Dojo Noodle Bar at Millers Yard. The reference number is W87AKIBY and the table will be held for 15 minutes. Is that all?', ['yes', 'Dojo Noodle Bar at Millers Yard', 'W87AKIBY']]
# Vector: ['booking-availability:yes', 'booking-name', 'booking-ref']
#
# Utterance: ["I'm sorry, but there aren't any places that meet those qualifications. Would you like to try a different part of town?", []]
# Vector: ['hotel-area : ?']

# %%
requested = sorted(set([act.split('-')[1][:-4] for vector in vectors for act in vector if act.endswith('?')]))
print(len(requested))
print(requested)
# Out:
# 12
# ['area', 'bookday', 'bookpeople', 'bookstay', 'booktime', 'food', 'internet', 'name', 'parking', 'pricerange', 'stars', 'type']

# %%
provide = sorted(set([act.split('-')[1] for vector in vectors for act in vector if not act.endswith('?')]))
print(len(provide))
print(provide)
# Out:
# 18
# ['address', 'area', 'availability:yes', 'bookday', 'bookpeople', 'bookstay', 'booktime', 'choice', 'food', 'internet', 'name', 'parking', 'phone', 'postcode', 'pricerange', 'ref', 'stars', 'type']

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
import numpy as np
import os
import json

output_folder = "cosine_similarity/embeddings"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


# Sentences we want sentence embeddings for
#sentences = ['This is an example sentence', 'Each sentence is converted']
batch_size = 64
sentences = [" | ".join(vector) for vector in vectors]

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-mpnet-base-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-mpnet-base-v2')

for i in range(0,len(sentences),batch_size):
    # Tokenize sentences
    encoded_input = tokenizer(sentences[i:i+batch_size], padding=True, truncation=True, return_tensors='pt')

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Perform pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    # Normalize embeddings
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

    np.save(f"{output_folder}/embeddings_with_requests_%d.npy" % (i), sentence_embeddings)
    #print("Sentence embeddings:")
    #print(sentence_embeddings)

# %%
files = os.listdir(output_folder)
files = sorted(files, key = lambda x: int(x[:-4].split("_")[-1]))
vectors = np.load(f"{output_folder}/{files[0]}")
#print(training_vectors.shape)
for filename in files[1:]:
    print(filename)
    vectors = np.concatenate((vectors, np.load(f"{output_folder}/{filename}")), axis=0)
print(vectors.shape)
# Out:
# embeddings_with_requests_64.npy
# embeddings_with_requests_128.npy
# embeddings_with_requests_192.npy
# embeddings_with_requests_256.npy
# embeddings_with_requests_320.npy
# embeddings_with_requests_384.npy
# embeddings_with_requests_448.npy
# embeddings_with_requests_512.npy
# embeddings_with_requests_576.npy
# embeddings_with_requests_640.npy
# embeddings_with_requests_704.npy
# embeddings_with_requests_768.npy
# embeddings_with_requests_832.npy
# embeddings_with_requests_896.npy
# embeddings_with_requests_960.npy
# embeddings_with_requests_1024.npy
# embeddings_with_requests_1088.npy
# embeddings_with_requests_1152.npy
# embeddings_with_requests_1216.npy
# embeddings_with_requests_1280.npy
# embeddings_with_requests_1344.npy
# embeddings_with_requests_1408.npy
# embeddings_with_requests_1472.npy
# embeddings_with_requests_1536.npy
# embeddings_with_requests_1600.npy
# embeddings_with_requests_1664.npy
# embeddings_with_requests_1728.npy
# embeddings_with_requests_1792.npy
# embeddings_with_requests_1856.npy
# embeddings_with_requests_1920.npy
# embeddings_with_requests_1984.npy
# embeddings_with_requests_2048.npy
# embeddings_with_requests_2112.npy
# embeddings_with_requests_2176.npy
# embeddings_with_requests_2240.npy
# embeddings_with_requests_2304.npy
# embeddings_with_requests_2368.npy
# embeddings_with_requests_2432.npy
# embeddings_with_requests_2496.npy
# embeddings_with_requests_2560.npy
# embeddings_with_requests_2624.npy
# embeddings_with_requests_2688.npy
# embeddings_with_requests_2752.npy
# embeddings_with_requests_2816.npy
# embeddings_with_requests_2880.npy
# embeddings_with_requests_2944.npy
# embeddings_with_requests_3008.npy
# embeddings_with_requests_3072.npy
# embeddings_with_requests_3136.npy
# embeddings_with_requests_3200.npy
# embeddings_with_requests_3264.npy
# embeddings_with_requests_3328.npy
# embeddings_with_requests_3392.npy
# embeddings_with_requests_3456.npy
# embeddings_with_requests_3520.npy
# embeddings_with_requests_3584.npy
# embeddings_with_requests_3648.npy
# embeddings_with_requests_3712.npy
# embeddings_with_requests_3776.npy
# embeddings_with_requests_3840.npy
# embeddings_with_requests_3904.npy
# embeddings_with_requests_3968.npy
# embeddings_with_requests_4032.npy
# embeddings_with_requests_4096.npy
# embeddings_with_requests_4160.npy
# embeddings_with_requests_4224.npy
# embeddings_with_requests_4288.npy
# embeddings_with_requests_4352.npy
# embeddings_with_requests_4416.npy
# embeddings_with_requests_4480.npy
# embeddings_with_requests_4544.npy
# embeddings_with_requests_4608.npy
# embeddings_with_requests_4672.npy
# embeddings_with_requests_4736.npy
# embeddings_with_requests_4800.npy
# embeddings_with_requests_4864.npy
# embeddings_with_requests_4928.npy
# embeddings_with_requests_4992.npy
# embeddings_with_requests_5056.npy
# embeddings_with_requests_5120.npy
# embeddings_with_requests_5184.npy
# embeddings_with_requests_5248.npy
# embeddings_with_requests_5312.npy
# embeddings_with_requests_5376.npy
# embeddings_with_requests_5440.npy
# embeddings_with_requests_5504.npy
# embeddings_with_requests_5568.npy
# embeddings_with_requests_5632.npy
# embeddings_with_requests_5696.npy
# embeddings_with_requests_5760.npy
# embeddings_with_requests_5824.npy
# embeddings_with_requests_5888.npy
# embeddings_with_requests_5952.npy
# embeddings_with_requests_6016.npy
# embeddings_with_requests_6080.npy
# embeddings_with_requests_6144.npy
# embeddings_with_requests_6208.npy
# embeddings_with_requests_6272.npy
# embeddings_with_requests_6336.npy
# embeddings_with_requests_6400.npy
# embeddings_with_requests_6464.npy
# embeddings_with_requests_6528.npy
# embeddings_with_requests_6592.npy
# embeddings_with_requests_6656.npy
# embeddings_with_requests_6720.npy
# embeddings_with_requests_6784.npy
# embeddings_with_requests_6848.npy
# embeddings_with_requests_6912.npy
# embeddings_with_requests_6976.npy
# embeddings_with_requests_7040.npy
# embeddings_with_requests_7104.npy
# embeddings_with_requests_7168.npy
# embeddings_with_requests_7232.npy
# embeddings_with_requests_7296.npy
# embeddings_with_requests_7360.npy
# embeddings_with_requests_7424.npy
# embeddings_with_requests_7488.npy
# embeddings_with_requests_7552.npy
# embeddings_with_requests_7616.npy
# embeddings_with_requests_7680.npy
# embeddings_with_requests_7744.npy
# embeddings_with_requests_7808.npy
# embeddings_with_requests_7872.npy
# embeddings_with_requests_7936.npy
# embeddings_with_requests_8000.npy
# embeddings_with_requests_8064.npy
# embeddings_with_requests_8128.npy
# embeddings_with_requests_8192.npy
# embeddings_with_requests_8256.npy
# embeddings_with_requests_8320.npy
# embeddings_with_requests_8384.npy
# embeddings_with_requests_8448.npy
# embeddings_with_requests_8512.npy
# embeddings_with_requests_8576.npy
# embeddings_with_requests_8640.npy
# embeddings_with_requests_8704.npy
# embeddings_with_requests_8768.npy
# embeddings_with_requests_8832.npy
# embeddings_with_requests_8896.npy
# embeddings_with_requests_8960.npy
# embeddings_with_requests_9024.npy
# embeddings_with_requests_9088.npy
# embeddings_with_requests_9152.npy
# embeddings_with_requests_9216.npy
# embeddings_with_requests_9280.npy
# embeddings_with_requests_9344.npy
# embeddings_with_requests_9408.npy
# embeddings_with_requests_9472.npy
# embeddings_with_requests_9536.npy
# embeddings_with_requests_9600.npy
# embeddings_with_requests_9664.npy
# embeddings_with_requests_9728.npy
# embeddings_with_requests_9792.npy
# embeddings_with_requests_9856.npy
# embeddings_with_requests_9920.npy
# embeddings_with_requests_9984.npy
# embeddings_with_requests_10048.npy
# embeddings_with_requests_10112.npy
# embeddings_with_requests_10176.npy
# embeddings_with_requests_10240.npy
# embeddings_with_requests_10304.npy
# embeddings_with_requests_10368.npy
# embeddings_with_requests_10432.npy
# embeddings_with_requests_10496.npy
# embeddings_with_requests_10560.npy
# embeddings_with_requests_10624.npy
# embeddings_with_requests_10688.npy
# embeddings_with_requests_10752.npy
# embeddings_with_requests_10816.npy
# embeddings_with_requests_10880.npy
# embeddings_with_requests_10944.npy
# embeddings_with_requests_11008.npy
# embeddings_with_requests_11072.npy
# embeddings_with_requests_11136.npy
# embeddings_with_requests_11200.npy
# embeddings_with_requests_11264.npy
# embeddings_with_requests_11328.npy
# embeddings_with_requests_11392.npy
# embeddings_with_requests_11456.npy
# embeddings_with_requests_11520.npy
# embeddings_with_requests_11584.npy
# embeddings_with_requests_11648.npy
# embeddings_with_requests_11712.npy
# embeddings_with_requests_11776.npy
# embeddings_with_requests_11840.npy
# embeddings_with_requests_11904.npy
# embeddings_with_requests_11968.npy
# embeddings_with_requests_12032.npy
# embeddings_with_requests_12096.npy
# embeddings_with_requests_12160.npy
# embeddings_with_requests_12224.npy
# embeddings_with_requests_12288.npy
# embeddings_with_requests_12352.npy
# embeddings_with_requests_12416.npy
# embeddings_with_requests_12480.npy
# embeddings_with_requests_12544.npy
# embeddings_with_requests_12608.npy
# embeddings_with_requests_12672.npy
# embeddings_with_requests_12736.npy
# embeddings_with_requests_12800.npy
# embeddings_with_requests_12864.npy
# embeddings_with_requests_12928.npy
# embeddings_with_requests_12992.npy
# embeddings_with_requests_13056.npy
# embeddings_with_requests_13120.npy
# embeddings_with_requests_13184.npy
# embeddings_with_requests_13248.npy
# embeddings_with_requests_13312.npy
# embeddings_with_requests_13376.npy
# embeddings_with_requests_13440.npy
# embeddings_with_requests_13504.npy
# embeddings_with_requests_13568.npy
# embeddings_with_requests_13632.npy
# embeddings_with_requests_13696.npy
# embeddings_with_requests_13760.npy
# embeddings_with_requests_13824.npy
# embeddings_with_requests_13888.npy
# embeddings_with_requests_13952.npy
# embeddings_with_requests_14016.npy
# embeddings_with_requests_14080.npy
# embeddings_with_requests_14144.npy
# embeddings_with_requests_14208.npy
# embeddings_with_requests_14272.npy
# embeddings_with_requests_14336.npy
# embeddings_with_requests_14400.npy
# embeddings_with_requests_14464.npy
# embeddings_with_requests_14528.npy
# embeddings_with_requests_14592.npy
# embeddings_with_requests_14656.npy
# embeddings_with_requests_14720.npy
# embeddings_with_requests_14784.npy
# embeddings_with_requests_14848.npy
# embeddings_with_requests_14912.npy
# embeddings_with_requests_14976.npy
# embeddings_with_requests_15040.npy
# embeddings_with_requests_15104.npy
# embeddings_with_requests_15168.npy
# embeddings_with_requests_15232.npy
# embeddings_with_requests_15296.npy
# embeddings_with_requests_15360.npy
# embeddings_with_requests_15424.npy
# embeddings_with_requests_15488.npy
# embeddings_with_requests_15552.npy
# embeddings_with_requests_15616.npy
# embeddings_with_requests_15680.npy
# embeddings_with_requests_15744.npy
# embeddings_with_requests_15808.npy
# embeddings_with_requests_15872.npy
# embeddings_with_requests_15936.npy
# embeddings_with_requests_16000.npy
# embeddings_with_requests_16064.npy
# embeddings_with_requests_16128.npy
# embeddings_with_requests_16192.npy
# embeddings_with_requests_16256.npy
# embeddings_with_requests_16320.npy
# embeddings_with_requests_16384.npy
# embeddings_with_requests_16448.npy
# embeddings_with_requests_16512.npy
# embeddings_with_requests_16576.npy
# embeddings_with_requests_16640.npy
# embeddings_with_requests_16704.npy
# embeddings_with_requests_16768.npy
# embeddings_with_requests_16832.npy
# embeddings_with_requests_16896.npy
# embeddings_with_requests_16960.npy
# embeddings_with_requests_17024.npy
# embeddings_with_requests_17088.npy
# embeddings_with_requests_17152.npy
# embeddings_with_requests_17216.npy
# embeddings_with_requests_17280.npy
# embeddings_with_requests_17344.npy
# embeddings_with_requests_17408.npy
# embeddings_with_requests_17472.npy
# embeddings_with_requests_17536.npy
# embeddings_with_requests_17600.npy
# embeddings_with_requests_17664.npy
# embeddings_with_requests_17728.npy
# embeddings_with_requests_17792.npy
# embeddings_with_requests_17856.npy
# embeddings_with_requests_17920.npy
# embeddings_with_requests_17984.npy
# embeddings_with_requests_18048.npy
# embeddings_with_requests_18112.npy
# embeddings_with_requests_18176.npy
# embeddings_with_requests_18240.npy
# embeddings_with_requests_18304.npy
# embeddings_with_requests_18368.npy
# embeddings_with_requests_18432.npy
# embeddings_with_requests_18496.npy
# embeddings_with_requests_18560.npy
# embeddings_with_requests_18624.npy
# embeddings_with_requests_18688.npy
# embeddings_with_requests_18752.npy
# embeddings_with_requests_18816.npy
# embeddings_with_requests_18880.npy
# embeddings_with_requests_18944.npy
# embeddings_with_requests_19008.npy
# embeddings_with_requests_19072.npy
# embeddings_with_requests_19136.npy
# embeddings_with_requests_19200.npy
# embeddings_with_requests_19264.npy
# embeddings_with_requests_19328.npy
# embeddings_with_requests_19392.npy
# embeddings_with_requests_19456.npy
# embeddings_with_requests_19520.npy
# embeddings_with_requests_19584.npy
# embeddings_with_requests_19648.npy
# embeddings_with_requests_19712.npy
# embeddings_with_requests_19776.npy
# embeddings_with_requests_19840.npy
# embeddings_with_requests_19904.npy
# embeddings_with_requests_19968.npy
# embeddings_with_requests_20032.npy
# embeddings_with_requests_20096.npy
# embeddings_with_requests_20160.npy
# embeddings_with_requests_20224.npy
# embeddings_with_requests_20288.npy
# embeddings_with_requests_20352.npy
# embeddings_with_requests_20416.npy
# embeddings_with_requests_20480.npy
# embeddings_with_requests_20544.npy
# embeddings_with_requests_20608.npy
# embeddings_with_requests_20672.npy
# embeddings_with_requests_20736.npy
# embeddings_with_requests_20800.npy
# embeddings_with_requests_20864.npy
# embeddings_with_requests_20928.npy
# embeddings_with_requests_20992.npy
# embeddings_with_requests_21056.npy
# embeddings_with_requests_21120.npy
# embeddings_with_requests_21184.npy
# embeddings_with_requests_21248.npy
# embeddings_with_requests_21312.npy
# embeddings_with_requests_21376.npy
# embeddings_with_requests_21440.npy
# embeddings_with_requests_21504.npy
# embeddings_with_requests_21568.npy
# embeddings_with_requests_21632.npy
# embeddings_with_requests_21696.npy
# embeddings_with_requests_21760.npy
# embeddings_with_requests_21824.npy
# embeddings_with_requests_21888.npy
# embeddings_with_requests_21952.npy
# embeddings_with_requests_22016.npy
# embeddings_with_requests_22080.npy
# embeddings_with_requests_22144.npy
# embeddings_with_requests_22208.npy
# embeddings_with_requests_22272.npy
# embeddings_with_requests_22336.npy
# embeddings_with_requests_22400.npy
# embeddings_with_requests_22464.npy
# embeddings_with_requests_22528.npy
# embeddings_with_requests_22592.npy
# embeddings_with_requests_22656.npy
# embeddings_with_requests_22720.npy
# embeddings_with_requests_22784.npy
# embeddings_with_requests_22848.npy
# embeddings_with_requests_22912.npy
# embeddings_with_requests_22976.npy
# embeddings_with_requests_23040.npy
# embeddings_with_requests_23104.npy
# embeddings_with_requests_23168.npy
# embeddings_with_requests_23232.npy
# embeddings_with_requests_23296.npy
# embeddings_with_requests_23360.npy
# embeddings_with_requests_23424.npy
# embeddings_with_requests_23488.npy
# embeddings_with_requests_23552.npy
# embeddings_with_requests_23616.npy
# embeddings_with_requests_23680.npy
# embeddings_with_requests_23744.npy
# embeddings_with_requests_23808.npy
# embeddings_with_requests_23872.npy
# embeddings_with_requests_23936.npy
# embeddings_with_requests_24000.npy
# embeddings_with_requests_24064.npy
# embeddings_with_requests_24128.npy
# embeddings_with_requests_24192.npy
# embeddings_with_requests_24256.npy
# embeddings_with_requests_24320.npy
# embeddings_with_requests_24384.npy
# embeddings_with_requests_24448.npy
# embeddings_with_requests_24512.npy
# embeddings_with_requests_24576.npy
# embeddings_with_requests_24640.npy
# embeddings_with_requests_24704.npy
# embeddings_with_requests_24768.npy
# embeddings_with_requests_24832.npy
# embeddings_with_requests_24896.npy
# embeddings_with_requests_24960.npy
# embeddings_with_requests_25024.npy
# embeddings_with_requests_25088.npy
# embeddings_with_requests_25152.npy
# embeddings_with_requests_25216.npy
# embeddings_with_requests_25280.npy
# embeddings_with_requests_25344.npy
# embeddings_with_requests_25408.npy
# embeddings_with_requests_25472.npy
# embeddings_with_requests_25536.npy
# embeddings_with_requests_25600.npy
# embeddings_with_requests_25664.npy
# embeddings_with_requests_25728.npy
# embeddings_with_requests_25792.npy
# embeddings_with_requests_25856.npy
# embeddings_with_requests_25920.npy
# embeddings_with_requests_25984.npy
# embeddings_with_requests_26048.npy
# embeddings_with_requests_26112.npy
# embeddings_with_requests_26176.npy
# embeddings_with_requests_26240.npy
# embeddings_with_requests_26304.npy
# embeddings_with_requests_26368.npy
# embeddings_with_requests_26432.npy
# embeddings_with_requests_26496.npy
# embeddings_with_requests_26560.npy
# embeddings_with_requests_26624.npy
# embeddings_with_requests_26688.npy
# embeddings_with_requests_26752.npy
# embeddings_with_requests_26816.npy
# embeddings_with_requests_26880.npy
# embeddings_with_requests_26944.npy
# embeddings_with_requests_27008.npy
# embeddings_with_requests_27072.npy
# embeddings_with_requests_27136.npy
# embeddings_with_requests_27200.npy
# embeddings_with_requests_27264.npy
# embeddings_with_requests_27328.npy
# embeddings_with_requests_27392.npy
# embeddings_with_requests_27456.npy
# embeddings_with_requests_27520.npy
# embeddings_with_requests_27584.npy
# embeddings_with_requests_27648.npy
# embeddings_with_requests_27712.npy
# embeddings_with_requests_27776.npy
# embeddings_with_requests_27840.npy
# embeddings_with_requests_27904.npy
# embeddings_with_requests_27968.npy
# embeddings_with_requests_28032.npy
# embeddings_with_requests_28096.npy
# embeddings_with_requests_28160.npy
# embeddings_with_requests_28224.npy
# embeddings_with_requests_28288.npy
# embeddings_with_requests_28352.npy
# embeddings_with_requests_28416.npy
# embeddings_with_requests_28480.npy
# embeddings_with_requests_28544.npy
# embeddings_with_requests_28608.npy
# embeddings_with_requests_28672.npy
# embeddings_with_requests_28736.npy
# embeddings_with_requests_28800.npy
# embeddings_with_requests_28864.npy
# embeddings_with_requests_28928.npy
# embeddings_with_requests_28992.npy
# embeddings_with_requests_29056.npy
# embeddings_with_requests_29120.npy
# embeddings_with_requests_29184.npy
# embeddings_with_requests_29248.npy
# embeddings_with_requests_29312.npy
# embeddings_with_requests_29376.npy
# embeddings_with_requests_29440.npy
# embeddings_with_requests_29504.npy
# embeddings_with_requests_29568.npy
# embeddings_with_requests_29632.npy
# embeddings_with_requests_29696.npy
# embeddings_with_requests_29760.npy
# embeddings_with_requests_29824.npy
# embeddings_with_requests_29888.npy
# embeddings_with_requests_29952.npy
# embeddings_with_requests_30016.npy
# embeddings_with_requests_30080.npy
# embeddings_with_requests_30144.npy
# embeddings_with_requests_30208.npy
# embeddings_with_requests_30272.npy
# embeddings_with_requests_30336.npy
# embeddings_with_requests_30400.npy
# embeddings_with_requests_30464.npy
# embeddings_with_requests_30528.npy
# embeddings_with_requests_30592.npy
# embeddings_with_requests_30656.npy
# embeddings_with_requests_30720.npy
# embeddings_with_requests_30784.npy
# embeddings_with_requests_30848.npy
# embeddings_with_requests_30912.npy
# embeddings_with_requests_30976.npy
# embeddings_with_requests_31040.npy
# embeddings_with_requests_31104.npy
# embeddings_with_requests_31168.npy
# embeddings_with_requests_31232.npy
# embeddings_with_requests_31296.npy
# embeddings_with_requests_31360.npy
# embeddings_with_requests_31424.npy
# embeddings_with_requests_31488.npy
# embeddings_with_requests_31552.npy
# embeddings_with_requests_31616.npy
# embeddings_with_requests_31680.npy
# embeddings_with_requests_31744.npy
# embeddings_with_requests_31808.npy
# embeddings_with_requests_31872.npy
# embeddings_with_requests_31936.npy
# embeddings_with_requests_32000.npy
# embeddings_with_requests_32064.npy
# embeddings_with_requests_32128.npy
# embeddings_with_requests_32192.npy
# embeddings_with_requests_32256.npy
# embeddings_with_requests_32320.npy
# embeddings_with_requests_32384.npy
# embeddings_with_requests_32448.npy
# embeddings_with_requests_32512.npy
# embeddings_with_requests_32576.npy
# embeddings_with_requests_32640.npy
# embeddings_with_requests_32704.npy
# embeddings_with_requests_32768.npy
# embeddings_with_requests_32832.npy
# embeddings_with_requests_32896.npy
# embeddings_with_requests_32960.npy
# embeddings_with_requests_33024.npy
# embeddings_with_requests_33088.npy
# embeddings_with_requests_33152.npy
# embeddings_with_requests_33216.npy
# embeddings_with_requests_33280.npy
# embeddings_with_requests_33344.npy
# embeddings_with_requests_33408.npy
# embeddings_with_requests_33472.npy
# embeddings_with_requests_33536.npy
# embeddings_with_requests_33600.npy
# embeddings_with_requests_33664.npy
# embeddings_with_requests_33728.npy
# embeddings_with_requests_33792.npy
# embeddings_with_requests_33856.npy
# embeddings_with_requests_33920.npy
# embeddings_with_requests_33984.npy
# embeddings_with_requests_34048.npy
# embeddings_with_requests_34112.npy
# embeddings_with_requests_34176.npy
# embeddings_with_requests_34240.npy
# embeddings_with_requests_34304.npy
# embeddings_with_requests_34368.npy
# embeddings_with_requests_34432.npy
# embeddings_with_requests_34496.npy
# embeddings_with_requests_34560.npy
# embeddings_with_requests_34624.npy
# embeddings_with_requests_34688.npy
# embeddings_with_requests_34752.npy
# embeddings_with_requests_34816.npy
# (34847, 768)

# %%
def get_embedding_vector(sentence):
    encoded_input = tokenizer(sentence, padding=True, truncation=True, return_tensors='pt')

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Perform pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    # Normalize embeddings
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)
    return sentence_embeddings[0].cpu().detach().numpy()

# %%
from scipy import spatial

utterances = load_variable_from_json(DATA_SAVE_PATH)
slots = load_variable_from_json(VECTORS_SAVE_PATH)

test_slots = ['restaurant-name']

sentence = " | ".join(test_slots)

test_vec = get_embedding_vector(sentence)

worddists_array_of_arrays = spatial.distance.cdist(np.array([test_vec]),np.array(vectors), metric = "cosine")
min_dist = np.argsort(worddists_array_of_arrays[0])[:10]

for min_dist_ex_i in min_dist:
    print(worddists_array_of_arrays[0][min_dist_ex_i], min_dist_ex_i, slots[min_dist_ex_i], test_slots)
    print('Agent response:', utterances[min_dist_ex_i])
# Out:
# 0.07118623742431707 16828 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ['Yes what is the name of the restaurant you are looking for?', []]
# 0.07118623742431707 8233 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ['Ok. Is there a specific restaurant you are looking for?', []]
# 0.07118623742431707 34362 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ['No problem, are you looking for anything specific?', []]
# 0.07118623742431707 17974 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ["I didn't find any results matching your criteria. Would you like me to find another restaurant?", []]
# 0.07118623742431707 21891 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ["I'm so sorry, that booking was unsuccessful. Would you like to try another restaurant, instead?", []]
# 0.07118623742431707 1960 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ["I'm sorry could you confirm what restaurant you wanted to reserve a table for 2 at?", []]
# 0.07118623742431707 27021 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ['Do you know the name?', []]
# 0.07118623742431707 8862 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ['Booking unsuccessful. Would you like to try another restaurant?', []]
# 0.07118623742431707 25588 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ["I can help you with that. What's the name of the restaurant you're looking for?", []]
# 0.07118623742431707 27248 ['restaurant-name : ?'] ['restaurant-name']
# Agent response: ['Are you looking for something in particular?', []]

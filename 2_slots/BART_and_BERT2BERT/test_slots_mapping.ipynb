# %%
# bert2bert and BART models tested on Kaggle. This just tests the rule-based approach.
import pandas as pd
from datasets import load_dataset
from tqdm import tqdm
import numpy as np
import torch
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
from slot_filler import map_slot_value

# %%
TRANSFORMER_MODEL_NAME = 'facebook/bart-base'
save_model_name = TRANSFORMER_MODEL_NAME.split('/')[-1]
epochs = 10
batch_size = 4
learning_rate = 2e-5
patience = 2
use_history = False

# %%
def process_intent_list(intent_list):
    intents = set()
    if len(intent_list) == 0:
        intents.add('other')
    for intent in intent_list:
        if intent.startswith('Restaurant'):
            intents.add(intent)
        elif intent.startswith('Hotel'):
            intents.add(intent)
        elif intent.startswith('general'):
            intents.add(intent)
        else:
            intents.add('other')
    # print(f'Original {intent_list}')
    # print(f'Modified {list(intents)}')
    return list(intents)

def process_service_list(service_list):
    services = set()
    if len(service_list) == 0:
        services.add('other')
    for service in service_list:
        if service == 'restaurant':
            services.add('restaurant')
        elif service == 'hotel':
            services.add('hotel')
        else:
            services.add('other')
        if len(services) == 3:
            break
    return list(services)

# %%
def preprocess_split(dataset, split):
    df = dataset[split].to_pandas()
    new_df = pd.DataFrame(columns = df.columns)
    for i in range(len(df)):
        # Taken from notebook, to know which lines to skip
        row = df.loc[i]
        if not any(set(row.turns['frames'][turn_id]['service']).intersection(['hotel', 'restaurant']) for turn_id,utt in enumerate(row.turns['utterance'])):
            continue
        
        new_df.loc[len(new_df)] = row
        # new_df.loc[len(new_df) - 1]['services'] = process_service_list(new_df.loc[len(new_df) - 1]['services'])
        # for i, frame_service in [frame['service'] for frame in df.loc[i].turns['frames']]:
            # df.loc[i].turns['frames']
    return new_df

def extract_token_bio_tags(dataset):
    unmapped_string_list = []
    mapped_string_list = []
    utterance_list = []
    
    for i in tqdm(range(len(dataset))):
        turns = dataset.loc[i].turns
        for j, (utterance, speaker, dialogue_act, frames) in enumerate(zip(turns['utterance'], turns['speaker'], turns['dialogue_acts'], turns['frames'])):

            if speaker != 0:
                continue
            # Skip using dialogue act intents
            # if 'other' in process_intent_list(dialogue_act['dialog_act']['act_type']):
            #     continue
            # Skip using frame services
            if 'other' in process_service_list(frames['service']):
                continue
            
            span_info = dialogue_act['span_info']
            act_slot_names = span_info['act_slot_name']
            act_slot_values = span_info['act_slot_value']
            span_starts = span_info['span_start']
            span_ends = span_info['span_end']
            slots = {slot_name : {'start': start, 'end': end, 'value': value} for slot_name, start, end, value in zip(act_slot_names, span_starts, span_ends, act_slot_values)}


            for slot_name in slots:
                slot_start, slot_end, slot_value = slots[slot_name]['start'], slots[slot_name]['end'], slots[slot_name]['value']
                input_string = utterance[slot_start:slot_end]
                output_string = slot_value
                
                # print(input_string)
                # print(output_string)
                # print()
                
                unmapped_string_list.append(input_string)
                mapped_string_list.append(output_string)
                utterance_list.append(utterance)
            
    return unmapped_string_list, mapped_string_list, utterance_list

# %%
dataset = load_dataset('multi_woz_v22')

train = preprocess_split(dataset, 'train')
val = preprocess_split(dataset, 'validation')
test = preprocess_split(dataset, 'test')

train_unmapped, train_mapped, _ = extract_token_bio_tags(train)
val_unmapped, val_mapped, _ = extract_token_bio_tags(val)
test_unmapped, test_mapped_string, test_utterance = extract_token_bio_tags(test)
# Out:
# No config specified, defaulting to: multi_woz_v22/v2.2_active_only
# Found cached dataset multi_woz_v22 (/home/adrian/.cache/huggingface/datasets/multi_woz_v22/v2.2_active_only/2.2.0/6719c8b21478299411a0c6fdb7137c3ebab2e6425129af831687fb7851c69eb5)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 6321/6321 [00:00<00:00, 16835.72it/s]
# 100%|██████████| 762/762 [00:00<00:00, 15971.67it/s]
# 100%|██████████| 745/745 [00:00<00:00, 16484.35it/s]

# %%
# transformer = EncoderDecoderModel.from_pretrained('saved_models/MAP_' + save_model_name).cuda()

predicted_mapped_string = []
for unmapped_string in tqdm(test_unmapped):
    predicted_mapped_string.append(map_slot_value(unmapped_string))
    
test_mapped_string = [s.lower() for s in test_mapped_string]

acc = accuracy_score(predicted_mapped_string, test_mapped_string)
print(f"Accuracy: {acc:.3f}")

for pred, test, utterance in zip(predicted_mapped_string, test_mapped_string, test_utterance):
    if pred != test:
        print("Utterance:", utterance)
        print(f'pred = \"{pred}\", truth = \"{test}\"')
# Out:
# 100%|██████████| 3241/3241 [00:00<00:00, 283930.47it/s]
# Accuracy: 0.984
# Utterance: Okay. now could you help me find a restaurant in the expensive price range that is in the same area as the hotel?
# pred = "same area", truth = "north"
# Utterance: Thank you. I am also looking for a restaurant that serves Chinese and that is in the same area as the hotel.
# pred = "same area", truth = "east"
# Utterance: Yes. Same group of people, at 19:45 on the same day please.
# pred = "same group of people", truth = "5"
# Utterance: Yes. Same group of people, at 19:45 on the same day please.
# pred = "same day", truth = "thursday"
# Utterance: We are looking for a place to dine, preferably expensive Italian food in the same area as the attraction. What do you suggest? I need an address and postcode please.
# pred = "same area", truth = "centre"
# Utterance: The hotel should be in the same area as the restaurant and should include free wifi.
# pred = "same area", truth = "north"
# Utterance: I'm also looking for a place to stay. It needs to include free wifi and parking, be 3 star, and in the same area as the restaurant.
# pred = "same area", truth = "centre"
# Utterance: Yes, please. For the same number of people, 2 nights, and the same day. I will also need a reference number.
# pred = "same number of people", truth = "4"
# Utterance: Yes, please. For the same number of people, 2 nights, and the same day. I will also need a reference number.
# pred = "same day", truth = "tuesday"
# Utterance: Yes please book it for 5 people and 4 nights starting from the same day.
# pred = "same day", truth = "monday"
# Utterance: Whichever ever one has 11:00 for two people on the same day available, that one would be fine.
# pred = "same day", truth = "saturday"
# Utterance: Yes please, I need a place to stay. Preferably a cheaply priced guesthouse in the same area as the restaurant
# pred = "same area", truth = "east"
# Utterance: I would like to book it on the same day as the other reservation, for the same amount of people, for 3 nights. Can I have the reference number?
# pred = "same day", truth = "friday"
# Utterance: I would like to book it on the same day as the other reservation, for the same amount of people, for 3 nights. Can I have the reference number?
# pred = "same amount of people", truth = "7"
# Utterance: It will be the same group of people that are on the train. I'll need it to start on Sunday and go for 3 nights.
# pred = "same group of people", truth = "6"
# Utterance: Actually, that is all the information I need. I do need a place to stay in the same area.
# pred = "same area", truth = "south"
# Utterance: Let's book that one then! Super excited! Same group of people, same day, 3 nights!
# pred = "same group of people", truth = "2"
# Utterance: Let's book that one then! Super excited! Same group of people, same day, 3 nights!
# pred = "same day", truth = "monday"
# Utterance: Please make sure you reserve my table for 13:30 on the same day and I'll need a reference number.
# pred = "same day", truth = "sunday"
# Utterance: Yeah, I need a restaurant. They need to serve Indian food and be in the same area as Funky Fun House.
# pred = "same area", truth = "east"
# Utterance: Yes. Book it for the same group of people on the same day at 18:45. Can I get the reference number please?
# pred = "same group of people", truth = "6"
# Utterance: Yes. Book it for the same group of people on the same day at 18:45. Can I get the reference number please?
# pred = "same day", truth = "sunday"
# Utterance: Yes, can you please find me a good Indian restaurant in the same area as the attraction? Money is no object.
# pred = "same area", truth = "south"
# Utterance: Yes, I was also interested in a European restaurant in the same area.
# pred = "same area", truth = "centre"
# Utterance: Yes, I would like to book it for 3 people starting that same day for 4 nights.
# pred = "same day", truth = "monday"
# Utterance: The same area as the restaurant and I prefer a guesthouse.
# pred = "same area", truth = "centre"
# Utterance: I want one that is in the same area as Bedouin, please.
# pred = "same area", truth = "centre"
# Utterance: Lets see what is available cheap, same area as the restaurant makes most sense but i am open to any area.
# pred = "same area", truth = "south"
# Utterance: Yes, I'd also like to find some lodging accommodations for the same group of people, on the same day.
# pred = "same group of people", truth = "7"
# Utterance: Yes, I'd also like to find some lodging accommodations for the same group of people, on the same day.
# pred = "same day", truth = "saturday"
# Utterance: I want you to book that for the same group of people for 2 nights from the same day.
# pred = "same group of people", truth = "7"
# Utterance: I want you to book that for the same group of people for 2 nights from the same day.
# pred = "same day", truth = "saturday"
# Utterance: Yes, I'm also looking for an Indian restaurant in the same area.
# pred = "same area", truth = "east"
# Utterance: Yes I am also looking for a place in the same area as the restaurant with free parking.I want it for 3 people for 5 nights starting Tuesday.
# pred = "same area", truth = "centre"
# Utterance: Not really, pick something tasty for us and book a table, please! 11:15 on that same day, same group.
# pred = "same day", truth = "sunday"
# Utterance: I need to book a table for the same group of people at 12:30 on the same day at a mexican restaurant.
# pred = "same day", truth = "monday"
# Utterance: I'd like it to be the same area as the attraction.
# pred = "same area", truth = "east"
# Utterance: Yes, the same day. Can I get the reference number, please?
# pred = "same day", truth = "saturday"
# Utterance: Yes, please book me for 8 people at 21:00 on the same day. Thank you!
# pred = "same day", truth = "wednesday"
# Utterance: Yes, I also need a place to stay in the same area as the attraction with free parking. It should be cheaply priced and 0 stars.
# pred = "same area", truth = "centre"
# Utterance: Yes, please. 5 people for 4 nights starting the same day as the train
# pred = "same day", truth = "thursday"
# Utterance: I think Nirala sounds good. Can you book a table for the same group of people at 10:15 on the same day?
# pred = "same group of people", truth = "5"
# Utterance: I think Nirala sounds good. Can you book a table for the same group of people at 10:15 on the same day?
# pred = "same day", truth = "thursday"
# Utterance: No, I don't. Any you recommend will be fine. I'll need it booked on the same day, same people, and for 5 nights.
# pred = "same day", truth = "saturday"
# Utterance: No, I don't. Any you recommend will be fine. I'll need it booked on the same day, same people, and for 5 nights.
# pred = "same people", truth = "3"
# Utterance: That's all I needed on restaruants. Can you help me find a place to stay in the same area with a 4 star rating?
# pred = "same area", truth = "centre"
# Utterance: I don't think I'll make that reservation just yet, but can you help me find an expensive restaurant in the same areas as the hotel?
# pred = "same area", truth = "north"
# Utterance: Yes, please. It will be just me and I'd like to eat at 21:00 on the same day as my train.
# pred = "same day", truth = "sunday"
# Utterance: I would like to book rooms for the same group of people for 2 nights starting Monday.
# pred = "same group of people", truth = "3"
# Utterance: Tandoori palace has a catchy name. Could you book me a table there for the same group of people on the same day at 17:15?
# pred = "same group of people", truth = "7"
# Utterance: Tandoori palace has a catchy name. Could you book me a table there for the same group of people on the same day at 17:15?
# pred = "same day", truth = "sunday"
# Utterance: I'm also looking for a place to stay in the same area as Cambridge university botanic gardens
# pred = "same area", truth = "centre"
